# %%
import pickle

with open('data/en_infoboxes.pickle', 'rb') as f:
    en_infoboxes = pickle.load(f)

with open('data/nl_infoboxes.pickle', 'rb') as f:
    nl_infoboxes = pickle.load(f)

# %%
nl_infoboxes
# Out:
# {'A Batalha do Apocalipse': None,
#  'A Clean, Well-Lighted Place': None,
#  '334 (novel)': None,
#  '1876 (novel)': None,
#  'A Blues for Shindig': None,
#  "A Buyer's Market": None,
#  'A Change of Climate': None,
#  'A Burnt-Out Case': None,
#  '2312 (novel)': None,
#  'A Concise Treatise on the Art of Angling': None,
#  'A Certain Smile': {'titel': 'A Certain Smile<br /><small>Als een verre glimlach</small>',
#   'regie': '[[Jean Negulesco]]',
#   'producer': '[[Henry Ephron]]',
#   'schrijver': '[[Frances Goodrich]]<br />[[Albert Hackett]]<br />[[Françoise Sagan]] (roman)',
#   'spelers': '[[Rossano Brazzi]]<br />[[Joan Fontaine]]<br />[[Bradford Dillman]]',
#   'muziek': '[[Alfred Newman]]',
#   'montage': '[[Louis R. Loeffler]]',
#   'cinematografie': '[[Milton R. Krasner]]',
#   'distributeur': '[[20th Century Fox]]',
#   'première': '[[22 september]] [[1958]]',
#   'genre': 'Drama',
#   'lengte': '104 minuten',
#   'taal': '[[Engels]]',
#   'land': '{{US}}',
#   'budget': '$ 2.300.000',
#   'opbrengst': '$ 1.300.000',
#   'imdb': '0051466',
#   'moviemeter': '48099'},
#  '1632 series': None,
#  "A Clergyman's Daughter": {'naam': 'De domineesdochter',
#   'orig titel': 'A Clergyman’s Daughter',
#   'auteur': '[[George Orwell]]',
#   'vertaler': 'Elizabeth Stortenbeker',
#   'land': '[[Engeland]]',
#   'taal': '[[Nederlands]]',
#   'originele taal': '[[Engels]]',
#   'uitgever': 'Meulenhoff',
#   'uitgiftedatum origineel': '1935',
#   'paginas': '302',
#   'isbn': '90-290-0373-1'},
#  'A Book on Angling': None,
#  'A Child Called It': None,
#  'A Case of Conscience': {'naam': 'De goddeloze tuin van Eden',
#   'afbeelding': 'Cover If 195309.jpg',
#   'onderschrift': 'A Case of Conscience (omslag eerste uitgave)',
#   'auteur': '[[James Blish]]',
#   'vertaler': '[[Cornelis Andries Gerardus van den Broek]]',
#   'kaftontwerp': '[[Alex Jagtenberg]]//[[Studio Lemaire]]',
#   'land': '{{US}}',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'reeks': '[[Born SF]]',
#   'genre': '[[Sciencefiction]]',
#   'uitgever': 'Born',
#   'originele uitgever': 'Ballantine Books',
#   'uitgiftedatum': '1969',
#   'uitgiftedatum origineel': '1958',
#   'paginas': '190',
#   'grootte': '190 mm',
#   'vervolg': 'After Such Knowledge',
#   'vorigeboek': '-',
#   'volgendeboek': 'Doctor Mirabilis',
#   'extra portaal': 'Sciencefiction'},
#  '2010: Odyssey Two': {'naam': '2010: Odyssey Two',
#   'auteur': '[[Arthur C. Clarke]]',
#   'land': '{{UK}}',
#   'genre': '[[Sciencefiction]]',
#   'uitgiftedatum': '[[1982]]',
#   'film': '[[2010: The Year We Make Contact]]',
#   'voorafgegaan': '[[2001: A Space Odyssey]]<br>[[2061: Odyssey Three]]',
#   'vervolg': '[[3001: The Final Odyssey]]'},
#  'A Bend in the River': None,
#  'A Canticle for Leibowitz': None,
#  'A Brief History of Time': {'naam': 'Het heelal',
#   'orig titel': "''A Brief History of Time''",
#   'vertaler': 'Ronald Jonkers',
#   'auteur': '[[Stephen Hawking]]',
#   'taal': '[[Nederlands]]',
#   'onderwerp': '[[Kosmologie]] <br> [[Theoretische natuurkunde]]',
#   'genre': '[[Populaire wetenschap|Populairwetenschappelijk]]',
#   'uitgever': '[[Bert Bakker (uitgeverij)|Bert Bakker]]',
#   'uitgiftedatum': '1988',
#   'paginas': '231',
#   'isbn': '90 351 0611 3',
#   'portaal': 'Astronomie'},
#  '11/22/63': {'naam': "''22-11-1963''",
#   'cover-op-enwp': '11-22-63.jpg',
#   'orig titel': '11/22/63',
#   'auteur': '[[Stephen King (schrijver)|Stephen King]]',
#   'vertaler': 'Hugo Kuipers',
#   'kaftontwerp': 'DPS/Davy van der Elsken',
#   'land': '[[Verenigde Staten]]',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'onderwerp': 'Moord op de Amerikaanse president [[John F. Kennedy]]',
#   'genre': 'Sciencefiction, Amerikaanse geschiedenis, drama',
#   'uitgever': 'Uitgeverij Luitingh - Sijthoff B.V., Amsterdam',
#   'originele uitgever': 'Scribner',
#   'uitgiftedatum': 'november 2011',
#   'uitgiftedatum origineel': '8 november 2011',
#   'paginas': '879',
#   'isbn': '978 90 245 3362 6',
#   'film': "''[[11.22.63]]'' (miniserie 2016)"},
#  'A Crown of Swords': {'naam': 'Een Kroon van Zwaarden',
#   'reeks': '[[Het Rad des Tijds]]',
#   'auteur': '[[Robert Jordan (auteur)|Robert Jordan]]',
#   'vertaler': 'Jo Thomas, Johan-Martijn Flaton',
#   'uitgever': '[[Luitingh-Sijthoff]]',
#   'originele uitgever': 'Tor Books',
#   'orig titel': 'Crown of Swords',
#   'uitgiftedatum': '1998',
#   'uitgiftedatum origineel': '[[15 mei]] [[1996]]',
#   'genre': '[[Fantasy (genre)|Fantasy]]',
#   'paginas': '704 blz',
#   'isbn': '9024512689',
#   'voorafgegaan': '[[Heer van Chaos]]',
#   'vervolg': '[[Het Pad der Dolken]]'},
#  'A Clockwork Orange (novel)': {'naam': "''A Clockwork Orange",
#   'afbeelding': 'A_CLOCKWORK_ORANGE.jpg',
#   'auteur': '[[Anthony Burgess]]',
#   'land': '[[Verenigd Koninkrijk]]',
#   'taal': "[[Engels]] & ''[[Nadsat]]''",
#   'genre': '[[Toekomstroman]], [[satire]]',
#   'uitgever': 'Heinemann (VK)',
#   'uitgiftedatum': '1962',
#   'paginas': '192',
#   'isbn': '0434098000',
#   'film': "[[A Clockwork Orange (film)|''A Clockwork Orange]]"},
#  "A Connecticut Yankee in King Arthur's Court": None,
#  '1Q84': {'naam': '1Q84',
#   'vertaler': '[[Jacques Westerhoven]]',
#   'auteur': '[[Haruki Murakami]]',
#   'land': '[[Japan]]',
#   'taal': '[[Japans]]',
#   'genre': '[[Roman (literatuur)|Roman]]',
#   'uitgever': '[[Shinchosha]]',
#   'uitgiftedatum': '[[29 mei]] [[2009]]',
#   'medium': 'Boek'},
#  '86 (novel series)': None,
#  'A Daughter of the Snows': None,
#  'A Dutiful Daughter': None,
#  'A Course in Miracles': {'naam': 'Een Cursus in Wonderen',
#   'orig titel': 'A Course in Miracles',
#   'vertaler': 'Willem Glaudemans, Kaja van Grieken, Bob Hermans, Koos Janson, Thilly Mercier, William Moons, Gertje van Ramshorst',
#   'auteur': 'Niet met zekerheid vastgesteld, maar op schrift gezet door Helen Schucman en William Thetford',
#   'land': 'Verenigde Staten',
#   'taal': 'Nederlands',
#   'onderwerp': 'Persoonlijke spirituele ontwikkeling',
#   'genre': '[[Spiritualiteit]]',
#   'uitgever': 'The Foundation for Inner Peace (Nederlands taalgebied: Uitgeverij Ankh-Hermes)',
#   'uitgiftedatum': '[[1975]]',
#   'medium': 'Hardcover',
#   'paginas': '1342',
#   'isbn': '978 90 202 11641, gebonden dundrukuitgave'},
#  'A Death in the Family': None,
#  'A Far Cry From Kensington': None,
#  'A Confederacy of Dunces': {'naam': 'Een samenzwering van idioten',
#   'orig titel': 'A Confederacy of Dunces',
#   'auteur': '[[John Kennedy Toole]]',
#   'vertaler': 'Paul Syrier',
#   'land': '[[Verenigde Staten]]',
#   'taal': '[[Nederlands]]',
#   'originele taal': '[[Engels]]',
#   'uitgever': 'Lebowski',
#   'originele uitgever': 'Louisiana State University Press',
#   'uitgiftedatum': '[[2011]]',
#   'uitgiftedatum origineel': '[[1980]]',
#   'isbn': '978-90-488-0828-1'},
#  'A Fine and Private Place': None,
#  'A Fall of Moondust': {'naam': "''Scheepsramp op de maan''",
#   'orig titel': 'A Fall of Moondust',
#   'auteur': '[[Arthur C. Clarke]]',
#   'vertaler': 'B.H. Staal',
#   'land': '[[Engeland]]',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'reeks': 'Prisma P955',
#   'genre': 'sciencefiction',
#   'uitgever': '[[Het Spectrum]]',
#   'originele uitgever': 'Victor Gollancz Ltd.',
#   'uitgiftedatum': '1964',
#   'uitgiftedatum origineel': '1961',
#   'medium': '[[pocketboek]]',
#   'paginas': '192',
#   'extra portaal': 'Sciencefiction'},
#  'A Fine Balance': None,
#  'A Fable (novel)': None,
#  'A Friend of the Earth': None,
#  'A Fighting Man of Mars': {'naam': "''A Fighting Man of Mars''",
#   'auteur': '[[Edgar Rice Burroughs]]',
#   'land': '[[Verenigde Staten]]',
#   'taal': '[[Engels]]',
#   'reeks': '[[Barsoom]]',
#   'genre': 'Science fantasy',
#   'uitgever': '[[Metropolitan Books]]',
#   'uitgiftedatum': '1931',
#   'medium': 'Print',
#   'paginas': '319',
#   'vorigeboek': "''[[The Master Mind of Mars]]''",
#   'volgendeboek': "''[[Swords of Mars]]''",
#   'extra portaal': 'Sciencefiction'},
#  'A Day in the Life of Ivan Denisovich': None,
#  'A Good Man is Hard to Find': None,
#  'A Fringe of Leaves': None,
#  'A Good School': None,
#  'A Heritage and Its History': None,
#  'A Gun for Dinosaur and Other Imaginative Tales': None,
#  'A Happy Death': None,
#  "A Gathering of Days: A New England Girl's Journal": None,
#  'A Christmas Carol': {'naam': 'A Christmas Carol',
#   'orig titel': 'A Christmas Carol in Prose: Being a Ghost Story of Christmas',
#   'afbeelding': 'Charles Dickens-A Christmas Carol-Title page-First edition 1843.jpg',
#   'auteur': '[[Charles Dickens]]',
#   'land': '[[Verenigd Koninkrijk]]',
#   'taal': '[[Engels]]',
#   'genre': '[[Kerstmis]], [[spookverhaal]]',
#   'uitgever': '[[Chapman & Hall]]',
#   'uitgiftedatum': '19 december 1843'},
#  'A Hornbook for Witches': None,
#  'A Heartbreaking Work of Staggering Genius': None,
#  'A History of Fly Fishing for Trout': None,
#  'A House-Boat on the Styx': None,
#  "A Doll's House": {'naam': 'Et Dukkehjem<br>(Een poppenhuis)',
#   'afbeelding': "A_Doll's_House.jpeg",
#   'onderschrift': 'Titelpagina manuscript 1879',
#   'schrijver': '[[Henrik Ibsen]]',
#   'taal': '[[Noors]]',
#   'nederlandse vertaling door': '[[Margaretha Meijboom]]',
#   'eerste opvoering datum': '[[21 december]] [[1879]]',
#   'eerste opvoering waar': '[[Kopenhagen]]',
#   'eerste opvoering NL': '[[1906]]',
#   'soort': '[[Tendensroman]]'},
#  'A Hunger Artist': None,
#  'A House for Mr. Biswas': None,
#  'A Journey in Other Worlds': None,
#  'A Dance with Dragons': {'naam': "''Een dans met draken''",
#   'reeks': "''[[Het lied van ijs en vuur]]''",
#   'auteur': '[[George R.R. Martin]]',
#   'vertaler': 'Renée Vink',
#   'uitgever': '[[Luitingh-Sijthoff]]',
#   'orig titel': "''A Dance with Dragons''",
#   'genre': '[[High fantasy]]',
#   'voorafgegaan': '[[Een feestmaal voor kraaien]]'},
#  'A Man in Full': None,
#  'A Matter of Honour': None,
#  'A Man Called Ove (novel)': None,
#  'A Meeting at Corvallis': None,
#  'A Medicine for Melancholy': None,
#  'A Maze of Death': None,
#  'A Manual of Style': None,
#  'A Murder of Quality': None,
#  'A Mysterious Affair of Style': None,
#  'A New Earth': None,
#  'A Place So Foreign and Eight More': None,
#  'A Million Open Doors': None,
#  'A Planet for the President': None,
#  'A Night in the Lonesome October': None,
#  'A Perfect Spy': None,
#  'A Planet for Texans': None,
#  'A Painted House': None,
#  'A Pocketful of Rye': None,
#  'A Praed Street Dossier': None,
#  'A Planet Called Treason': None,
#  'A Certain Magical Index': None,
#  'A Prophetic Romance': None,
#  'A New Kind of Science (book)': None,
#  'A Promise of Romance': None,
#  'A Moveable Feast': {'naam': 'A Moveable Feast',
#   'afbeelding': 'GertrudeStein JackHemingway Paris.jpg',
#   'onderschrift': '[[Gertrude Stein]] met Jack Hemingway in [[Parijs]]',
#   'auteur': '[[Ernest Hemingway]]',
#   'land': '{{US}}',
#   'originele taal': 'Engels',
#   'genre': 'biografie',
#   'originele uitgever': "[[Scribner's]]",
#   'uitgiftedatum origineel': '[[1964]]',
#   'paginas': '211',
#   'grootte': '22 cm'},
#  'A Presumption of Death': None,
#  'A Passage to India': {'titel': 'A Passage to India',
#   'regie': '[[David Lean]]',
#   'producer': '[[John Brabourne]]<br />Richard B. Goodwin',
#   'schrijver': '[[David Lean]]',
#   'spelers': '[[Judy Davis]]<br />[[Victor Banerjee]]<br />[[Peggy Ashcroft]]<br />[[James Fox (acteur)|James Fox]]<br />[[Alec Guinness]]',
#   'muziek': '[[Maurice Jarre]]',
#   'montage': '[[David Lean]]',
#   'cinematografie': 'Ernest Day',
#   'distributeur': '[[Columbia Pictures]]',
#   'première': '[[14 december]] [[1984]]',
#   'lengte': '163 minuten',
#   'taal': 'Engels',
#   'land': '{{UK}} <br /> {{US}}',
#   'opbrengst': '$27.187.653 (VS)',
#   'imdb': '0087892',
#   'moviemeter': '2806',
#   'montager': 'David Lean',
#   'studio': '[[Thorn EMI]]<br />[[HBO]]',
#   'duur': '163 minuten'},
#  'A Question of Upbringing': None,
#  'A Prison Diary': None,
#  'A Prayer for Owen Meany': {'naam': 'Bidden wij voor Owen Meany',
#   'orig titel': 'A Prayer for Owen Meany',
#   'auteur': '[[John Irving]]',
#   'vertaler': '[[Cornelis Andries Gerardus van den Broek|C.A.G. van den Broek]]',
#   'land': '[[Verenigde Staten]]',
#   'taal': '[[Nederlands]]',
#   'originele taal': '[[Engels]]',
#   'genre': '[[Roman (literatuur) | Roman]]',
#   'uitgever': 'De Bezige Bij',
#   'uitgiftedatum': '[[2012]]',
#   'uitgiftedatum origineel': '[[1989]]',
#   'isbn': '978-90-234-3859-5',
#   'film': "''Simon Birch'' (1998)"},
#  'A Rendezvous in Averoigne': None,
#  'A Purple Place For Dying': None,
#  'A Ring of Endless Light': {'titel': 'A Ring of Endless Light',
#   'regie': '[[Greg Beeman]]',
#   'producer': 'Greg Beeman',
#   'schrijver': "Marita Giovanni<br />Bruce Graham<br />Madeleine L'Engle (roman)",
#   'spelers': '[[Mischa Barton]]<br />[[Ryan Merriman]]',
#   'distributeur': '[[Disney Channel]]',
#   'première': '[[23 augustus]] [[2002]] (VS)<br />[[26 februari]] [[2005]] (NL)',
#   'muziek': '[[Phil Marshall]] (als Philip Marshall)',
#   'cinematografie': 'Rodney Charters',
#   'genre': 'Drama',
#   'lengte': '88 minuten',
#   'taal': 'Engels',
#   'land': '{{US}}',
#   'imdb': '0282123',
#   'moviemeter': '22452'},
#  'A Portrait of the Artist as a Young Man': None,
#  'A Severed Head': None,
#  'A Solitary Grief': None,
#  'A Single Shard': None,
#  'A Room with a View': {'titel': 'A Room with a View<br /><small>Kamer met uitzicht</small>',
#   'regie': '[[James Ivory (regisseur)|James Ivory]]',
#   'producer': '[[Ismail Merchant]]',
#   'schrijver': '[[Ruth Prawer Jhabvala]]',
#   'spelers': '[[Helena Bonham Carter]]<br />[[Julian Sands]]',
#   'muziek': '[[Richard Robbins]]',
#   'montage': '[[Humphrey Dixon]]',
#   'cinematografie': '[[Tony Pierce-Roberts]]',
#   'distributeur': '[[Curzon]]',
#   'première': '[[13 december]] [[1985]]',
#   'genre': '[[Romantische komedie]]',
#   'lengte': '117 minuten',
#   'taal': '[[Engels]]',
#   'land': '{{GB}}',
#   'budget': '$ 3.000.000',
#   'opbrengst': '$ 20.966.644',
#   'imdb': '0091867',
#   'moviemeter': '891'},
#  'A Strange Manuscript Found in a Copper Cylinder': None,
#  'A Shade of Difference': None,
#  'A Small Town in Germany': None,
#  'A Tale of the Ragged Mountains': None,
#  'A Shock to the System (1990 film)': {'titel': 'A Shock to the System',
#   'première': '1990',
#   'regie': '[[Jan Egleson]]',
#   'spelers': '[[Michael Caine]]<br />[[Elizabeth McGovern]]<br />[[Peter Riegert]]<br />[[Swoosie Kurtz]]',
#   'land': '{{US}}',
#   'duur': '91 minuten',
#   'imdb': '0100602',
#   'moviemeter': '7744',
#   'taal': '[[Engels]]',
#   'lengte': '91 minuten',
#   'tagline': 'Climbing the corporate ladder can be murder.',
#   'montage': '[[William M. Anderson]]'},
#  'A Princess of Mars': {'naam': 'Prinses van Mars',
#   'afbeelding': 'Princess of Mars large.jpg',
#   'orig titel': 'A Princess of Mars',
#   'auteur': '[[Edgar Rice Burroughs]]',
#   'vertaler': 'Ton Stam',
#   'land': '{{US}}',
#   'taal': 'Nederlands',
#   'originele taal': '[[Engels]]',
#   'reeks': '[[Barsoom]]',
#   'genre': 'Sciencefiction',
#   'uitgever': 'Hoorn, West-Friesland',
#   'originele uitgever': 'A. C. McClurg',
#   'uitgiftedatum': '1971',
#   'uitgiftedatum origineel': '1917',
#   'medium': 'Print',
#   'paginas': '160',
#   'isbn': 'ISBN 90-205-0588-2',
#   'film': '[[Princess of Mars]]<br />[[John Carter (film)|John Carter]]',
#   'volgendeboek': '[[Goden van Mars]]',
#   'extra portaal': 'Sciencefiction'},
#  'A Stranger in the Mirror': None,
#  'A Short History of Nearly Everything': {'naam': "''Een kleine geschiedenis van bijna alles''",
#   'orig titel': "''A short history of nearly everything''",
#   'auteur': '[[Bill Bryson]]',
#   'vertaler': 'Servaas Goddijn',
#   'land': '{{GB}}',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'onderwerp': '[[Natuurwetenschap]]<br />[[Geschiedenis]]',
#   'genre': '[[Non-fictie]]',
#   'uitgever': '{{NL-VLAG}} [[Atlas (uitgeverij)|Atlas]]',
#   'originele uitgever': '{{GB-VLAG}} Doubleday<br /> {{US-VLAG}} Broadway Books',
#   'uitgiftedatum': '2004',
#   'uitgiftedatum origineel': '2003',
#   'paginas': '512',
#   'isbn': '978-90-450-0970-4',
#   'isbntoelichting': '[[Paperback]]'},
#  "A Midwinter's Tale": None,
#  'A Scanner Darkly': {'titel': 'A Scanner Darkly',
#   'tagline': 'Everything Is Not Going To Be OK<br/>What Does A Scanner See?',
#   'regie': '[[Richard Linklater]]',
#   'producer': '[[Tommy Pallotta]]<br/>[[Anne Walker-McBay]]<br/>[[Palmer West]]<br/>[[Jonah Smith]]<br/>[[Erwin Stoff]]',
#   'schrijver': '[[Richard Linklater]]',
#   'spelers': '[[Keanu Reeves]]<br/>[[Robert Downey Jr.]]<br/>[[Woody Harrelson]]<br/>[[Winona Ryder]]',
#   'muziek': '[[Graham Reynolds]]',
#   'montage': '[[Sandra Adair]]',
#   'cinematografie': '[[Shane F. Kelly]]',
#   'distributeur': '[[Warner Home Video]]',
#   'première': '7 juli 2006',
#   'genre': '[[Sciencefictionfilm]], [[Animatiefilm]]',
#   'lengte': '100 minuten',
#   'taal': '[[Engels]]',
#   'land': '{{US}}',
#   'budget': '8,7 miljoen dollar',
#   'imdb': '0405296',
#   'moviemeter': '28490'},
#  'A Summons to Memphis': None,
#  'A Taste of Honey (novella)': None,
#  'A Tenured Professor': None,
#  'A Time for Judas': None,
#  'A Swiftly Tilting Planet': None,
#  'A Time of Changes': None,
#  'A Vicious Circle': None,
#  'A Thousand Acres': None,
#  'A Thousand Days (book)': None,
#  'A Theory of Justice': None,
#  'A Transatlantic Tunnel, Hurrah!': None,
#  'A Traveler from Altruria': None,
#  'A Universal History of Infamy': None,
#  'A Series of Unfortunate Events': {'naam': 'Ellendige avonturen',
#   'orig titel': 'A series of Unfortunate Events',
#   'vertaler': '[[Huberte Vriesendorp]]',
#   'afbeelding': 'A_Series_of_Unfortunate_Events_logo.png',
#   'auteur': '[[Daniel Handler]] aka [[Lemony Snicket]]',
#   'kaftontwerp': '[[Brett Helquist]]',
#   'land': '[[Verenigde Staten]]',
#   'taal': '[[Engels]]',
#   'genre': '[[Jeugdliteratuur|Jeugd]], [[zwarte humor]], [[steampunk]]',
#   'uitgever': '[[HarperCollins]] / [[Uitgeverij Ploegsma]]',
#   'uitgiftedatum': '[[30 september]] [[1999]]'},
#  "A Sister's All You Need": None,
#  'A Walking Tour of the Shambles': None,
#  "A Visit to William Blake's Inn": None,
#  'A Widow for One Year': None,
#  'A Town like Alice': None,
#  'A Year in the Merde': None,
#  'A Voyage to Arcturus': None,
#  'A Thousand Splendid Suns': {'naam': 'Duizend schitterende zonnen',
#   'orig titel': 'A Thousand Splendid Suns',
#   'vertaler': 'W. Hansen',
#   'auteur': '[[Khaled Hosseini]]',
#   'uitgever': 'Riverhead Books <small>(Verenigde Staten)</small><br />De Bezige Bij <small>(Nederland)</small>',
#   'uitgiftedatum': '[[2007]]',
#   'paginas': '397 <small>(Nederland)</small>',
#   'isbn': '9789023426066'},
#  'A Study in Scarlet': {'naam': "''Een studie in rood''",
#   'orig titel': "''A Study in Scarlet''",
#   'afbeelding': 'ArthurConanDoyle AStudyInScarlet annual.jpg',
#   'auteur': '[[Arthur Conan Doyle]]',
#   'land': '[[Verenigd Koninkrijk]]',
#   'taal': '[[Engels]]',
#   'reeks': '[[Sherlock Holmes]]',
#   'genre': '[[detectiveverhaal|detective]], misdaad, mysterie',
#   'uitgiftedatum': '1887',
#   'medium': 'print ([[hardcover]] & [[paperback]]) en [[luisterboek]]',
#   'paginas': '96',
#   'vervolg': '[[Het teken van de vier]]'},
#  'A Tale of Two Cities': None,
#  'A Year Down Yonder': None,
#  'A Wind in the Door': None,
#  'A World Out of Time': {'naam': 'Buiten de tijd',
#   'cover-op-enwp': 'WRLDTFTMZW1977.jpg',
#   'orig titel': "''A World Out of Time''",
#   'vertaler': '[[Pon Ruiter]]',
#   'auteur': '[[Larry Niven]]',
#   'originele taal': '[[Engels]]',
#   'taal': '[[Nederlands]]',
#   'genre': '[[Sciencefiction]]',
#   'uitgever': '[[Elsevier (uitgeverij)|Elsevier]]',
#   'uitgiftedatum': '1977',
#   'medium': 'Boek',
#   'paginas': '256',
#   'isbn': '9789010018915',
#   'vervolg': '[[De integraalbomen]]'},
#  'Above the Veil': None,
#  'A World Transformed': None,
#  'Acacia: The War With The Mein': None,
#  'Absurdistan (novel)': None,
#  'Absolute Power (novel)': None,
#  'A Wrinkle in Time': {'naam': 'Een rimpel in de tijd',
#   'orig titel': 'A Wrinkle in Time',
#   'auteur': "[[Madeleine L'Engle]]",
#   'illustraties': 'Ellen Raskin',
#   'land': '{{US}}',
#   'taal': '[[Nederlands]]',
#   'originele taal': '[[Engels]]',
#   'genre': '[[Jeugdliteratuur]]<br />[[Science fantasy]]',
#   'uitgever': '[[Luitingh-Sijthoff]]',
#   'originele uitgever': 'Ariel Books',
#   'uitgiftedatum': '5 maart 2018',
#   'uitgiftedatum origineel': '1 januari 1962',
#   'medium': '[[Paperback]]',
#   'paginas': '160',
#   'isbn': '9789024580606',
#   'NUR-code': '283',
#   'volgendeboek': '[[Een scheur in de ruimte]] (1973)'},
#  'Acidity (novelette)': None,
#  'Abhorsen Trilogy': None,
#  'Absolute Boy': None,
#  'Absolution Gap': None,
#  'A Song of Ice and Fire': None,
#  'Across The Zodiac': None,
#  'Accident (novel)': None,
#  'Adding a Dimension': None,
#  'Adventures in Time and Space': None,
#  'Across the Wall: A Tale of the Abhorsen and Other Stories': None,
#  'Adventures in Two Worlds': None,
#  'Across the Universe (novel)': None,
#  'Accelerando (book)': None,
#  'Account of Corsica': None,
#  'Adventures of Wim': None,
#  'Across the River and Into the Trees': None,
#  'Adam of the Road': None,
#  'A Wizard of Earthsea': None,
#  'Absolute Duo': None,
#  'Aenir': None,
#  'Advertisements for Myself': None,
#  'After Doomsday': None,
#  'After Worlds Collide': None,
#  'After the Hole': None,
#  'After Many a Summer': None,
#  'Against the Fall of Night': None,
#  'Adventures of Huckleberry Finn (novel)': None,
#  'Air and Angels': None,
#  'Agent of Vega': None,
#  'Against the Day': None,
#  'Aladore': None,
#  'Airport (novel)': None,
#  'Advise and Consent': {'titel': 'Advise and Consent<br><small>Storm over Washington</small>',
#   'afbeelding': 'Advise-&-Consent-(1).jpg',
#   'onderschrift': "Aanplakbiljet voor ''Advise and Consent''",
#   'regie': '[[Otto Preminger]]',
#   'producer': '[[Otto Preminger]]',
#   'schrijver': '[[Wendell Mayes]]<br />[[Allen Drury]] (roman)',
#   'spelers': '[[Franchot Tone]]<br />[[Lew Ayres]]<br />[[Henry Fonda]]',
#   'muziek': '[[Jerry Fielding]]',
#   'montage': '[[Louis R. Loeffler]]',
#   'cinematografie': '[[Sam Leavitt]]',
#   'distributeur': '[[Columbia Pictures]]',
#   'première': '[[6 juni]] [[1962]]',
#   'genre': 'Drama',
#   'lengte': '139 minuten',
#   'taal': '[[Engels]]',
#   'land': '{{US}}',
#   'imdb': '0055728',
#   'moviemeter': '7962'},
#  'Air (novel)': None,
#  'After the Funeral': {'naam': 'Na de begrafenis',
#   'orig titel': "''After the Funeral''",
#   'auteur': '[[Agatha Christie]]',
#   'originele taal': '[[Engels (hoofdbetekenis)|Engels]]',
#   'genre': '[[Detectiveverhaal|detective]]',
#   'uitgever': '[[Luitingh-Sijthoff]]',
#   'originele uitgever': '[[Dodd, Mead and Company]]',
#   'uitgiftedatum': '1953',
#   'uitgiftedatum origineel': '1953',
#   'vorigeboek': '[[Gebroken verhouding]]',
#   'volgendeboek': '[[Een handvol rogge]]'},
#  'Aesthetica of a Rogue Hero': None,
#  'Akata Witch': None,
#  'Akata Warrior': None,
#  'Adventures of Huckleberry Finn': {'naam': 'De lotgevallen van Huckleberry Finn',
#   'orig titel': 'Adventures of Huckleberry Finn',
#   'afbeelding': 'E. W. Kemble - Adventures of Huckleberry Finn Cover.jpg',
#   'auteur': '[[Mark Twain]]',
#   'land': '[[Verenigde Staten]]',
#   'taal': '[[Engels]]',
#   'uitgiftedatum': '1884',
#   'paginas': '366',
#   'isbn': '0-553-21079-3',
#   'voorafgegaan': '[[De lotgevallen van Tom Sawyer]]',
#   'vervolg': 'Tom Sawyer Abroad'},
#  'Aleriel, or A Voyage to Other Worlds': None,
#  'Akikan!': None,
#  'Alas, Babylon': None,
#  'Alaska (novel)': None,
#  'Accel World': None,
#  'Aeneid': {'naam': "Aeneis<br />(''Eneïde'')",
#   'afbeelding': 'Aeneas bij de sibylle Arcana, RP-P-OB-42.318.jpg',
#   'onderschrift': 'Prent "Aeneas bij de sibylle Arcana", tussen 1651 en 1682 door François Bourlier (vermeld op object) naar ontwerp van François Perrier.',
#   'cover-op-enwp': 'Cristoforo_Majorana_-_Leaf_from_Eclogues,_Georgics_and_Aeneid_-_Walters_W40055R_-_Open_Obverse.jpg',
#   'auteur': '[[Vergilius]]',
#   'land': '[[Romeinse Republiek]]',
#   'taal': '[[Latijn]]',
#   'onderwerp': 'heldendaden van [[Aeneas]], oorsprong van de [[Romeinse Rijk|Romeinse]] beschaving',
#   'genre': '[[heldendicht]]',
#   'uitgiftedatum origineel': '[[19 v.Chr.]]'},
#  'Alice Adams (novel)': None,
#  'Ai no Kusabi': None,
#  'All Around the Town': None,
#  'Alias Grace': None,
#  'All Families Are Psychotic': None,
#  "Ali's Smile/Naked Scientology": None,
#  'All Quiet on the Orient Express': None,
#  'Alone with the Horrors: The Great Short Fiction of Ramsey Campbell 1961-1991': None,
#  'All the Light We Cannot See': None,
#  'Alphabet of Thorn': None,
#  'Alderamin on the Sky': None,
#  'Akashic Records of Bastard Magic Instructor': None,
#  'Alphabetical Africa': None,
#  'Almanac of the Dead': None,
#  'Almost like a Whale': None,
#  'Allison (novel series)': None,
#  'Always Comes Evening': None,
#  'All My Sons': None,
#  'All You Need Is Kill': None,
#  'Alice in Wonderland': None,
#  'Allegiant (novel)': {'naam': "''Samensmelting''.<br />''Haar keuze bepaalt alles.''",
#   'orig titel': '\'\'Allegiant".<br />\'\'One choice will define you.\'\'',
#   'vertaler': '[[Maria Postema]]',
#   'auteur': '[[Veronica Roth]]',
#   'kaftontwerp': '[[Joel Tippie]]',
#   'land': '{{US}}',
#   'taal': '[[Nederlands]]',
#   'originele taal': '[[Engels]]',
#   'reeks': 'Divergent-trilogie',
#   'genre': 'young adult',
#   'uitgever': '[[Uitgeverij Unieboek|Van Goor]]',
#   'originele uitgever': 'Katherine Tegen Books',
#   'uitgiftedatum': '19 februari 2014',
#   'uitgiftedatum origineel': '22 oktober 2013',
#   'medium': 'boek',
#   'paginas': '380',
#   'gewicht': '649 gram',
#   'isbn': '9789000334797',
#   'voorafgegaan': '[[Opstand (Veronica Roth)|Opstand]]'},
#  'America (The Book)': None,
#  'Ammonite (novel)': None,
#  'Amped (novel)': None,
#  'Altered Carbon': {'titel': 'Altered Carbon',
#   'cover-op-enwp': 'Altered_Carbon_title.jpg',
#   'genre': '[[Cyberpunk]]',
#   'speelduur': '46-66 minuten',
#   'spelers': '[[Joel Kinnaman]] <br> [[James Purefoy]] <br> [[Martha Higareda]] <br> [[Chris Conner]] <br> [[Dichen Lachman]] <br> [[Ato Essandoh]] <br> [[Kristin Lehman]] <br> [[Trieu Tran]] <br> [[Renée Elise Goldsberry]]',
#   'orkestratie': '[[Jeff Russo]]',
#   'land': '{{VS}}',
#   'producer': '[[John G. Lenic]]',
#   'productiebedrijf': 'Virago Productions <br> [[Mythology Entertainment]] <br> [[Phoenix Pictures]] <br> [[Skydance Television]]',
#   'distributeur': '[[Netflix]]',
#   'start': '2 februari 2018',
#   'afleveringen': '18',
#   'seizoenen': '2',
#   'beeldformaat': '[[4K]] ([[Ultra HD]]) <br> [[High dynamic range]]',
#   'audioformaat': '[[Dolby Digital|5.1]] <br> [[Dolby Atmos]]',
#   'imdb': '2261227'},
#  'All Quiet on the Western Front': {'naam': "''Van het westelijk front geen nieuws''",
#   'orig titel': "''Im Westen nichts Neues''",
#   'vertalers': '[[Annie Salomons]] en Ronald Jonkers',
#   'afbeelding': 'Remarque_All_Quiet_NL_9e_druk_a.jpg',
#   'auteur': '[[Erich Maria Remarque]]',
#   'land': '{{NL}}',
#   'taal': '[[Nederlands]]',
#   'onderwerp': '[[Eerste Wereldoorlog]]',
#   'genre': '[[Oorlogsroman]]',
#   'uitgever': '[[Erven J. Bijleveld]], [[Utrecht (stad)|Utrecht]]',
#   'uitgiftedatum': '[[1929]]',
#   'medium': 'Boek',
#   'vertaler': '[[Annie Salomons]] en Ronald Jonkers'},
#  'Among Others': None,
#  'American Pastoral': None,
#  'Among the Thugs': None,
#  "All the President's Men": {'titel': "''All the President's Men''",
#   'regie': '[[Alan J. Pakula]]',
#   'producer': '[[Jon Boorstin]]<br />[[Michael Britton]]<br />[[Walter Coblenz]]',
#   'schrijver': '[[William Goldman]]<br />[[Carl Bernstein]] (boek)<br />[[Bob Woodward]] (boek)',
#   'spelers': '[[Dustin Hoffman]]<br />[[Robert Redford]]<br />[[Jack Warden]]',
#   'muziek': '[[David Shire]]',
#   'montage': '[[Robert L. Wolfe]]',
#   'cinematografie': '[[Gordon Willis]]',
#   'distributeur': '[[Warner Bros.]]',
#   'première': '[[4 april]] [[1976]]',
#   'genre': 'Drama',
#   'lengte': '138 minuten',
#   'taal': '[[Engels]]<br />[[Spaans]]',
#   'land': '{{US}}',
#   'budget': '$ 8.500.000',
#   'opbrengst': '$ 70.600.000',
#   'imdb': '0074119',
#   'moviemeter': '1097'},
#  'Amerika (novel)': None,
#  'Amos Fortune, Free Man': None,
#  'An Age': None,
#  "Alice's Adventures in Wonderland": {'naam': "''Alice in Wonderland''",
#   'onderschrift': 'Tekening van Alice, het konijn en de Mad Hatter tijdens het [[theekransje]].',
#   'orig titel': "''Alice's Adventures in Wonderland",
#   'vertaler': '[[Sofia Engelsman]]',
#   'afbeelding': 'Alice par John Tenniel 25.png',
#   'auteur': '[[Lewis Carroll]]',
#   'illustraties': '[[John Tenniel]], [[Rie Cramer]], [[Floor Rieder]]',
#   'land': '[[Verenigd Koninkrijk]]',
#   'taal': 'Engels',
#   'genre': 'Sprookje, psychologisch',
#   'originele uitgever': 'Macmillan & Co.',
#   'uitgiftedatum': '1865',
#   'paginas': '192',
#   'film': "''[[Alice in Wonderland (1903)]]''<br />''[[Alice in Wonderland (1915)]]''<br />''[[Alice in Wonderland (1933)]]''<br />''[[Alice in Wonderland (1949)]]''<br />''[[Alice in Wonderland (1951)]]''<br />''[[Alice in Wonderland (televisiefilm)|Alice in Wonderland (1966)]]''<br />''[[Alice in Wonderland or What's a Nice Kid Like You Doing in a Place Like This?]] (1966)''<br />''[[Alice in Wonderland: An X-Rated Musical Fantasy]]'' (1976)<br />''[[Alice in Wonderland (1985)]]''<br />''[[Alice (1988)]]''<br />''[[Alice in Wonderland (1988)]]''<br />''[[Alice in Wonderland (1995)]]''<br />''[[Alice in Wonderland (1999)]]''<br />''[[Alice in Wonderland: What's the Matter with Hatter?]]''<br />''[[Malice in Wonderland (2009)|Malice in Wonderland]]'' (2009)<br />''[[Alice in Wonderland (2010)]]''<br />''[[Malice in Lalaland]]'' (2010)",
#   'vervolg': '[[Through the Looking-Glass]] (1871)',
#   'extra portaal': 'Film'},
#  'An Australian Grammar': None,
#  "An Archdemon's Dilemma: How to Love Your Elf Bride": None,
#  'Amsterdam (novel)': None,
#  'An Anthropologist on Mars': None,
#  'An Enquiry Concerning Human Understanding': None,
#  'An Elephant for Aristotle': None,
#  'American Gods': None,
#  'American Psycho': {'naam': 'American Psycho',
#   'auteur': '[[Bret Easton Ellis]]',
#   'vertaler': '[[Balt Lenders]]',
#   'land': '[[Verenigde Staten]]',
#   'originele taal': '[[Engels]]',
#   'onderwerp': '[[Bdsm]], [[kannibalisme]], [[necrofilie]], [[psychopathie]], [[seriemoord]], [[consumptiemaatschappij]], [[prostitutie]]',
#   'genre': '[[Psychologische thriller]], [[satire]], [[postmodernisme]]',
#   'originele uitgever': 'Vintage Books',
#   'uitgiftedatum': '1991',
#   'paginas': '399',
#   'film': "''[[American Psycho (film)|American Psycho]]''"},
#  'An Imaginary Life': None,
#  'An Inconvenient Woman': None,
#  'An Old Captivity': None,
#  'An Ember in the Ashes': None,
#  'Amagi Brilliant Park': None,
#  'An Eye for an Eye: The Untold Story of Jewish Revenge Against Germans in 1945': None,
#  'An Artist of the Floating World': None,
#  'An American Tragedy': {'titel': 'An American Tragedy<br /><small>Een Amerikaansche tragedie</small>',
#   'afbeelding': 'An_American_Tragedy_Theodore_Dreiser_dust_jacket.jpeg',
#   'onderschrift': "Stofkaft van de uitgave van ''An American Tragedy''",
#   'regie': '[[Josef von Sternberg]]',
#   'producer': '[[Josef von Sternberg]]',
#   'schrijver': '[[Samuel Hoffenstein]]<br />[[Josef von Sternberg]]<br />[[Theodore Dreiser]] (roman)',
#   'spelers': '[[Phillips Holmes]]<br />[[Sylvia Sidney]]<br />[[Frances Dee]]',
#   'muziek': '[[John Leipold]]<br />[[Ralph Rainger]]',
#   'montage': '[[Hans Dreier]]',
#   'cinematografie': '[[Lee Garmes]]',
#   'distributeur': '[[Paramount Pictures]]',
#   'première': '[[5 augustus]] [[1931]]',
#   'genre': 'Drama',
#   'lengte': '96 minuten',
#   'taal': '[[Engels]]',
#   'land': '{{US}}',
#   'imdb': '0021607',
#   'moviemeter': '75512'},
#  'An Indecent Obsession': None,
#  'An Unusual Angle': None,
#  'An Unsuitable Job for a Woman': None,
#  'And Chaos Died': None,
#  'Ancient Shores': None,
#  'And Afterward, the Dark': None,
#  'Andymon': None,
#  'And Then There Was No One': None,
#  'And Now Miguel': None,
#  'Andersonville (novel)': None,
#  'Andromeda (novel)': None,
#  'Ancient Ruins and Archaeology': None,
#  'And The Band Played On (book)': None,
#  'And The Ass Saw The Angel': None,
#  'Anansi Boys': None,
#  'An Essay on the Principle of Population': {'naam': "''An Essay on the Principle of Population''",
#   'afbeelding': 'An Essay on the Principle of Population.jpg',
#   'onderschrift': 'Titelpagina van de 1e druk uit 1798',
#   'auteur': '[[Thomas Malthus|Thomas Robert Malthus]]',
#   'land': '{{EN}}',
#   'originele taal': '[[Engels]]',
#   'uitgever': 'J. Johnson, [[Londen]]',
#   'uitgiftedatum origineel': '[[1798]]',
#   'extra portaal': 'Mens & maatschappij'},
#  'Anatomy of a Murder': {'titel': 'Anatomy of a Murder<br /><small>Analyse van een moord</small>',
#   'afbeelding': 'AnatomyMurder2.jpg',
#   'onderschrift': 'Filmposter',
#   'regie': '[[Otto Preminger]]',
#   'producer': '[[Otto Preminger]]',
#   'schrijver': '[[Wendell Mayes]]',
#   'spelers': '[[James Stewart (acteur)|James Stewart]]<br />[[Lee Remick]]<br />[[Ben Gazzara]]',
#   'muziek': '[[Duke Ellington]]',
#   'montage': '[[Louis R. Loeffler]]',
#   'production design': '[[Boris Leven]]',
#   'cinematografie': '[[Sam Leavitt]]',
#   'distributeur': '[[Columbia Pictures]]',
#   'première': '[[1 juli]] [[1959]]',
#   'genre': 'Drama',
#   'lengte': '160 minuten',
#   'taal': '[[Engels]]',
#   'land': '{{US}}',
#   'imdb': '0052561',
#   'moviemeter': '2544'},
#  'Anna of the Five Towns': None,
#  'Annals of the Twenty-Ninth Century': None,
#  'Angle of Repose': None,
#  "Angela's Ashes": {'naam': 'De as van mijn moeder',
#   'orig titel': "Angela's Ashes",
#   'vertaler': 'Christien Jonkheer',
#   'auteur': 'Frank McCourt',
#   'uitgever': '[[Barnes and Noble]] <small>(Verenigde Staten)</small><br />[[Prometheus (uitgeverij)]] <small>(Nederland)</small>',
#   'uitgiftedatum': '[[1997]]',
#   'paginas': '408 <small>(Nederland)</small>',
#   'grootte_gewicht': '11,5 cm bij 17,6 ; 267 gram',
#   'isbn': '904614089X',
#   'vervolg': 'Tis'},
#  'Another Country (novel)': None,
#  'And You Thought There Is Never a Girl Online?': None,
#  'Aniara': {'naam': "''Aniara''",
#   'titelweergave': "''Aniara''",
#   'orde': '[[Kevers|Coleoptera]] (Kevers)',
#   'familie': '[[Loopkevers|Carabidae]] (Loopkevers)',
#   'onderfamilie': '[[Zandloopkevers (onderfamilie)|Cicindelinae]] (Zandloopkevers)',
#   'taxon': '[[Geslacht (biologie)|Geslacht]]',
#   'w-naam': "''Aniara''",
#   'auteur': '[[Frederick William Hope|Hope]]',
#   'datum': '1838'},
#  'Animorphs': None,
#  'And Then There Were None': {'naam': 'Tien kleine negertjes',
#   'orig titel': "''Ten little niggers''",
#   'auteur': '[[Agatha Christie]]',
#   'land': '[[Verenigd Koninkrijk]]',
#   'taal': '[[Nederlands]]',
#   'originele taal': '[[Engels]]',
#   'genre': '[[misdaadgenre]]',
#   'uitgever': '[[Luitingh-Sijthoff]]',
#   'originele uitgever': 'Dodd, Mead and Company',
#   'uitgiftedatum origineel': '6 november 1939',
#   'medium': 'Pocket',
#   'paginas': '229',
#   'vorigeboek': '[[Het Regatta-mysterie]]',
#   'volgendeboek': '[[Schuldig in eigen ogen]]'},
#  'Animal Liberation (book)': None,
#  'Antarctic Conquest': None,
#  'Angels and Demons': {'titel': 'Angels & Demons',
#   'tagline': 'The holiest event of our time. Perfect for their return.<br />The path is alive!',
#   'regie': '[[Ron Howard]]',
#   'producer': '[[Brian Grazer]]<br />[[John Calley]]',
#   'schrijver': '[[Dan Brown]] (boek)<br />[[Akiva Goldsman]] (script)',
#   'spelers': '[[Tom Hanks]]<br />[[Ewan McGregor]]<br />[[Slim Khezri]]<br />[[Armin Mueller-Stahl]]',
#   'muziek': '[[Hans Zimmer]]',
#   'montage': '[[Daniel P. Hanley]]<br />[[Mike Hill]]',
#   'cinematografie': '[[Salvatore Totino]]',
#   'distributeur': '[[Sony Pictures Entertainment]]<br />[[Columbia Pictures]]',
#   'première': '{{US-VLAG}} [[15 mei]] [[2009]]<br /> {{BE-VLAG}} [[13 mei]] 2009<br /> {{NL-VLAG}} [[13 mei]] 2009',
#   'genre': '[[Mystery]]<br />[[Thriller (genre)|Thriller]]',
#   'lengte': '145 min',
#   'taal': '[[Engels (hoofdbetekenis)|Engels]]',
#   'land': '{{US}}',
#   'budget': '$150,000,000',
#   'opbrengst': '$485,930,816',
#   'voorloper': '[[The Da Vinci Code (film)|The Da Vinci Code]]',
#   'vervolg': '[[Inferno (2016)|Inferno]]',
#   'imdb': '0808151',
#   'moviemeter': '49002'},
#  'Anohana': None,
#  'Anvil of Stars': None,
#  'Anthropology: And a Hundred Other Stories': None,
#  'Angel Beats!': {'titel': 'Angel Beats!',
#   'afbeelding': 'Angel Beats game logo.svg',
#   'genre': 'Actie<br />[[Fantasy (genre)|Fantasy]]',
#   'bedenker': '[[Jun Maeda]]',
#   'stemmen (oorspr.)': 'Harumi Sakurai<br />Hiroshi Kamiya<br />Kana Hanazawa',
#   'stemmen (NL)': 'Niet beschikbaar',
#   'muziek': 'Jun Maeda<br />[[Anant-Garde Eyes]]',
#   'intromuziek': '"My Soul, Your Beats!" door Lia',
#   'land': '[[Japan]]',
#   'taal': '[[Japans]]<br />[[Engels]]<br />[[Duits]]',
#   'producer': '[[Kenji Horikawa]]<br />[[Hiro Maruyama]]<br />[[Hironori Toba]]',
#   'afleveringen': '13',
#   'seizoenen': '1'},
#  'Anna Karenina': {'naam': 'Anna Karenina',
#   'afbeelding': 'AnnaKareninaTitle.jpg',
#   'afbeeldingbreedte': '220px',
#   'onderschrift': 'Titelblad eerste boekuitgave 1878',
#   'auteur': '[[Lev Tolstoj]]',
#   'land': '{{RU}}',
#   'originele taal': 'Russisch',
#   'genre': 'Roman',
#   'uitgiftedatum origineel': '1877'},
#  'Aqui comienca un vocabulario en la lengua castellana y mexicana': None,
#  'Apologia Pro Vita Sua': None,
#  'Apollyon (Left Behind)': None,
#  'Anthony Ryan (writer)': None,
#  'Ape and Essence': None,
#  'Archangel (Shinn novel)': None,
#  'Arafel (Cherryh)': None,
#  'Arabian Nights and Days': None,
#  'Anthem (novel)': None,
#  "Arkham's Masters of Horror": None,
#  'Ares Express': None,
#  'Anthem (novella)': None,
#  "Are You There God? It's Me, Margaret": None,
#  'Aristotle and the Gun and Other Stories': None,
#  'Animal Farm': {'naam': "''Boerderij der Dieren''",
#   'orig titel': "''Animal Farm''",
#   'vertaler': 'Anthony Ross',
#   'afbeelding': 'Animal Farm - 1st edition.jpg',
#   'auteur': '[[George Orwell]]',
#   'taal': 'Engels',
#   'uitgever': 'Uitgeverij Phoenix (1947)<br />de Arbeiderspers (1956)',
#   'uitgiftedatum': '1945',
#   'isbn': '0-8488-0120-2'},
#  'Arrow in the Blue': None,
#  'Anne of Green Gables': {'naam': 'Anne van het Groene Huis',
#   'orig titel': 'Anne of Green Gables',
#   'vertaler': 'E.R. Kuitenbrouwer-Dickson en Hermine Vermeulen-Smit<br />later ook: Martha Heesen',
#   'afbeelding': 'FirstPageGreenGables.gif',
#   'auteur': '[[Lucy Maud Montgomery]]',
#   'illustraties': 'M.A. en W.A.J. Claus',
#   'land': '[[Canada]]',
#   'taal': '[[Engels]]',
#   'reeks': 'Anne van het Groene Huis',
#   'genre': 'fictie',
#   'uitgever': 'L. C. Page & Co.<br />in Nederland: [[De Fontein (uitgeverij)|De Fontein]]',
#   'uitgiftedatum': 'juni [[1908]]',
#   'paginas': '429 (eerste druk)'},
#  'Arte de la lengua mexicana y castellana': None,
#  'Arming America, The Origins of a National Gun Culture': None,
#  'Around the Moon': {'naam': "''De reis om de maan''",
#   'orig titel': "''Autour de la Lune''",
#   'afbeelding': "'Around the Moon' by Bayard and Neuville 36.jpg",
#   'auteur': '[[Jules Verne]]',
#   'illustraties': 'Émile-Antoine Bayard<br> Alphonse-Marie de Neuville',
#   'land': '[[Frankrijk]]',
#   'taal': '[[Frans]]',
#   'reeks': "''Voyages extraordinaires'' #7",
#   'genre': '[[Sciencefiction]]',
#   'uitgever': '[[Pierre-Jules Hetzel]]',
#   'uitgiftedatum': '[[1870]]',
#   'medium': 'Print ([[Hardcover|Hardback]] & [[Paperback]])',
#   'paginas': '212',
#   'voorafgegaan': '[[Van de aarde naar de maan]]',
#   'vervolg': '[[Een schot in de lucht]]'},
#  'Artemis (novel)': None,
#  'Arthur & George': None,
#  'Arkham House: The First 20 Years': None,
#  'Arrowsmith (book)': None,
#  "Arifureta: From Commonplace to World's Strongest": None,
#  'Artemis Fowl: The Arctic Incident': None,
#  'Armies of the Night': None,
#  'Artemis Fowl and the Lost Colony': {'naam': 'Artemis Fowl: De verloren kolonie',
#   'orig titel': 'Artemis Fowl: The Lost Colony',
#   'auteur': '[[Eoin Colfer]]',
#   'land': '[[Ierland (land)|Ierland]]',
#   'taal': '[[Engels]]',
#   'reeks': '[[Artemis Fowl (serie)|Artemis Fowl]]',
#   'genre': 'Fantasy',
#   'uitgever': '[[Puffin Books]]',
#   'uitgiftedatum': '2 augustus 2006',
#   'medium': 'Print ([[Hardcover|Hardback]] & [[Paperback]])',
#   'paginas': '384',
#   'isbn': '0141382686',
#   'voorafgegaan': '[[Artemis Fowl: Het bedrog van Opal]]',
#   'vervolg': '[[Artemis Fowl en de tijdparadox]]'},
#  'Artemis Fowl: The Eternity Code': {'naam': 'Artemis Fowl: De eeuwige code',
#   'orig titel': 'Artemis Fowl: The Eternity Code',
#   'auteur': '[[Eoin Colfer]]',
#   'land': '[[Ierland (land)|Ierland]]',
#   'taal': '[[Engels]]',
#   'reeks': '[[Artemis Fowl (serie)|Artemis Fowl]]',
#   'genre': 'Fantasy',
#   'uitgever': '[[Viking Press]]',
#   'uitgiftedatum': '27 april 2003',
#   'medium': 'Print ([[Hardcover|Hardback]] & [[Paperback]])',
#   'paginas': '352',
#   'isbn': '0670913529',
#   'voorafgegaan': '[[Artemis Fowl: De Russische connectie]]',
#   'vervolg': '[[Artemis Fowl: Het bedrog van Opal]]'},
#  'Arthur Mervyn': None,
#  'Artemis Fowl: The Opal Deception': None,
#  'Aru Shah and the End of Time': None,
#  'Artificial Intelligence: A Modern Approach': None,
#  'Aspects of Love (novel)': None,
#  'Around the World in Eighty Days (novel)': None,
#  'As the Green Star Rises': None,
#  'Artemis Fowl (book)': None,
#  "Asimov's Mysteries": {'naam': "''De sprekende steen''",
#   'orig titel': "''Asimov's Mysteries''",
#   'auteur': '[[Isaac Asimov]]',
#   'vertaler': 'Henk Bouwman',
#   'land': '{{US}}',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'genre': '[[Sciencefiction]]',
#   'uitgever': '[[A.W. Bruna Uitgevers]]',
#   'originele uitgever': 'Doubleday',
#   'uitgiftedatum': '1970',
#   'uitgiftedatum origineel': '1968',
#   'medium': '[[pocketboek]]',
#   'extra portaal': 'Sciencefiction'},
#  'Assassins (novel)': None,
#  'Artemis Fowl series': None,
#  'As I Lay Dying': {'naam': 'Terwijl ik al heenging',
#   'afbeelding': 'AsILayDying.jpg',
#   'orig titel': 'As I Lay Dying',
#   'auteur': '[[William Faulkner]]',
#   'vertaler': 'Rien Verhoef',
#   'land': '[[Verenigde Staten]]',
#   'originele taal': '[[Engels]]',
#   'genre': '[[Roman (literatuur)|Roman]]',
#   'uitgever': 'Eldorado',
#   'originele uitgever': 'Jonathan Cape and Harrison Smith, New York',
#   'uitgiftedatum': '2007',
#   'uitgiftedatum origineel': '[[1930]]',
#   'medium': 'Paperback',
#   'paginas': '255',
#   'isbn': '9047100298'},
#  "Assassin's Quest": {'naam': 'Vermogen en Wijsheid',
#   'orig titel': "Assassin's Quest",
#   'Schrijfster': '[[Robin Hobb]]',
#   'vertaler': '[[Peter Cuijpers]]',
#   'auteur': '[[Robin Hobb]]',
#   'kaftontwerp': '[[John Howe]] (UK)',
#   'land': '[[Nederland]]',
#   'taal': '[[Nederlands]]',
#   'reeks': '[[De boeken van de Zieners]]',
#   'genre': '[[Fantasy (genre)|Fantasy]]',
#   'uitgever': '[[Uitgeverij M]]',
#   'uitgiftedatum': '2003',
#   'medium': 'Gebonden (Hardcover)',
#   'paginas': '640 blz (gebonden)',
#   'grootte_gewicht': '223 x 161 x 50 [[millimeter|mm]] <br /> 834 [[Gram (eenheid)|gram]]',
#   'isbn': '9022536041',
#   'voorafgegaan': '[[Moordenaar des konings]]'},
#  'At the Back of the North Wind': None,
#  'Asylums (book)': None,
#  'Assignment in Eternity': None,
#  'Arabian Nights': None,
#  "At Lady Molly's": None,
#  "At the Earth's Core (novel)": None,
#  'Assassins Pride': None,
#  "Assassin's Apprentice": {'naam': 'Leerling en Meester',
#   'orig titel': "Assassin's Apprentice",
#   'vertaler': '[[Erica Feberwee]] en [[Peter Cuijpers]]',
#   'auteur': '[[Robin Hobb]]',
#   'kaftontwerp': '[[John Howe]] (UK)',
#   'land': '[[Nederland]]',
#   'taal': '[[Nederlands]]',
#   'reeks': '[[De boeken van de Zieners]]',
#   'genre': '[[Fantasy (genre)|Fantasy]]',
#   'uitgever': "''M''",
#   'uitgiftedatum': '1998',
#   'medium': 'Gebonden (Hardcover)',
#   'paginas': '352 blz (gebonden)',
#   'grootte_gewicht': '568 [[Gram (eenheid)|gram]]',
#   'isbn': '9022536025',
#   'vervolg': '[[Moordenaar des konings]]'},
#  'Aria the Scarlet Ammo': None,
#  'At the Mountains of Madness and Other Novels': None,
#  'Atlantis Found': None,
#  'At Swim-Two-Birds': None,
#  "Asura Cryin'": None,
#  'Atomised': None,
#  'Attack from Atlantis': None,
#  'Author, Author (novel)': None,
#  'Auntie Mame': {'titel': "''Auntie Mame''",
#   'poster-op-enwp': 'Auntie Mame Poster.jpg',
#   'regie': '[[Morton DaCosta]]',
#   'producer': 'Morton DaCosta',
#   'schrijver': '[[Betty Comden en Adolph Green]]',
#   'spelers': '[[Rosalind Russell]]<br />[[Forrest Tucker]]<br />[[Coral Browne]]<br />[[Roger Smith (acteur)|Roger Smith]]<br />[[Peggy Cass]]<br />Jan Handzlik',
#   'muziek': '[[Bronisław Kaper]]',
#   'montage': '[[William Ziegler]]',
#   'cinematografie': '[[Harry Stradling]]',
#   'distributeur': '[[Warner Bros Pictures]]',
#   'première': '[[4 december]] [[1958]]',
#   'lengte': '143 minuten',
#   'taal': '[[Engels]]',
#   'land': '{{VS}}',
#   'imdb': '0051383'},
#  'Avalon High': None,
#  'Aura: Maryūinkōga Saigo no Tatakai': None,
#  'Atonement (novel)': {'naam': 'Boetekleed',
#   'orig titel': 'Atonement',
#   'auteur': '[[Ian McEwan]]',
#   'vertaler': 'Rien Verhoef',
#   'land': '[[Verenigd Koninkrijk|Engeland]]',
#   'taal': '[[Nederlands]]',
#   'originele taal': '[[Engels]]',
#   'uitgever': 'De Harmonie',
#   'uitgiftedatum': '2002',
#   'uitgiftedatum origineel': '2001',
#   'isbn': '978-90-761-6820-3',
#   'film': '[[Atonement (film)|Atonement]] (2007)'},
#  'Ascendance of a Bookworm': None,
#  'Back When We Were Grownups': None,
#  'Babyji': None,
#  'Autobiography of a Geisha': None,
#  'Bad Bug Book': None,
#  'Babel-17': None,
#  'Banana Republicans': None,
#  'Attack on Titan: Before the Fall': None,
#  'Baka to Test to Shōkanjū': None,
#  'Ball Four': None,
#  'Bard: The Odyssey Of the Irish': None,
#  'Band of Brothers (book)': {'naam': 'Band of Brothers: van Normandië tot [[Adolf Hitler|Hitlers]] [[Kehlsteinhaus|Adelaarsnest]]: de Easy-compagnie, 506de Regiment, 101ste Luchtlandingsdivisie',
#   'orig titel': "Band of Brothers: E Company, 506th Regiment, 101st Airborne from Normandy to Hitler's Eagle's Nest",
#   'vertaler': '[[Jeske Nelissen]]',
#   'auteur': '[[Stephen Ambrose]]',
#   'land': '[[Verenigde Staten]]',
#   'taal': '[[Engels]]',
#   'onderwerp': '[[Tweede Wereldoorlog]]<br />[[United States Army]]',
#   'uitgever': '[[BZZTôH]]',
#   'uitgiftedatum': '[[1993]]',
#   'paginas': '304',
#   'grootte_gewicht': '25 x 16 x 2 cm<br />678 gram',
#   'isbn': 'ISBN 9055019887'},
#  'Barnyard Dance': None,
#  'Banglapedia': None,
#  'Barchester Towers': None,
#  'Atlas Shrugged': {'naam': 'Atlas in staking',
#   'orig titel': 'Atlas Shrugged',
#   'vertaler': 'J. de Voogt',
#   'afbeelding': 'Atlas Shrugged (1957 1st ed) - Ayn Rand.jpg',
#   'onderschrift': 'Kaft van de eerste druk (1957)',
#   'auteur': '[[Ayn Rand]]',
#   'land': '[[Verenigde Staten]]',
#   'taal': '[[Engels]]',
#   'genre': '[[Toekomstroman]]',
#   'uitgever': 'Johannes Multimedia',
#   'uitgiftedatum': '1957 (origineel)<br />2007 (vertaling)',
#   'medium': 'Print',
#   'paginas': '1168 (origineel)<br />1003 (vertaling)',
#   'isbn': '9789077564943',
#   'film': 'Atlas Shrugged: Part I'},
#  'Bag of Bones': None,
#  'Baccano!': {'titel': 'Baccano!',
#   'genre': '[[Actiefilm|Actie]], [[Drama (kunst en cultuur)|drama]], [[Komedie]]',
#   'bedenker': '[[Takahiro Omori]]',
#   'stemmen (oorspr.)': 'Sanae Koboyashi, Mitsuru Miyamoto, Hiroyuki Yoshino en anderen',
#   'stemmen (NL)': 'Niet beschikbaar',
#   'intromuziek': "Gun's & Roses door Paradise Lunch",
#   'land': '[[Japan]]',
#   'taal': '[[Japans]]',
#   'afleveringen': '13 + 3 extra OVA’s',
#   'seizoenen': '1'},
#  'Ballad of a Shinigami': None,
#  'Barnaby Rudge': {'naam': 'Barnaby Rudge',
#   'orig titel': 'Barnaby Rudge: A Tale of the Riots of Eighty',
#   'afbeelding': 'Masterclock serial cover.jpg',
#   'onderschrift': "Cover van de serie ''Master Humphrey's Clock'' uit 1890",
#   'auteur': '[[Charles Dickens]]',
#   'illustraties': '[[George Cattermole]]<br>[[Hablot Knight Browne]]',
#   'land': '[[Verenigd Koninkrijk]]',
#   'taal': '[[Engels]]',
#   'uitgiftedatum': '1841'},
#  "Banished from the Heroes' Party": None,
#  'Beautiful Darkness (novel)': None,
#  'Beauty: A Retelling of the Story of Beauty and the Beast': None,
#  'Baudolino': {'naam': 'Baudolino',
#   'afbeelding': 'Umberto Eco 01.jpg',
#   'onderschrift': 'Umberto Eco',
#   'auteur': '[[Umberto Eco]]',
#   'vertaler': 'Yond Boeke',
#   'land': '[[Byzantijnse Rijk]]',
#   'taal': '[[Nederlands]]',
#   'originele taal': '[[Italiaans (taal)|Italiaans]]',
#   'genre': '[[Schelmenroman]]',
#   'uitgever': 'Bert Bakker',
#   'uitgiftedatum': '[[2001]]',
#   'isbn': '978-90-351-2288-8'},
#  'Beautiful Creatures (book)': None,
#  'Battlefield Earth (novel)': None,
#  'Bare-faced Messiah': None,
#  'Behind the lines (book)': None,
#  'Bakemonogatari': None,
#  'Behind That Curtain': None,
#  'Beggarman, Thief': None,
#  'Battle Angel Alita': None,
#  'Bedelia (novel)': None,
#  'Because of Winn-Dixie': {'titel': 'Because of Winn-Dixie',
#   'regie': '[[Wayne Wang]]',
#   'producer': 'Trevor Albert<br/>Joan Singleton',
#   'schrijver': '[[Joan Singleton]]<br/>[[Kate DiCamillo]] (roman)',
#   'voice-over': 'AnnaSophia Robb',
#   'spelers': '[[AnnaSophia Robb]]<br />[[Jeff Daniels]]',
#   'distributeur': '[[20th Century Fox]]',
# ...
#   'genre': '[[Fantasy (genre)|Fantasy]]',
#   'uitgever': '[[Mynx|Uitgeverij M]]',
#   'originele uitgever': 'Tor Books',
#   'uitgiftedatum': '[[2006]]',
#   'uitgiftedatum origineel': '[[2005]]',
#   'medium': 'Boek',
#   'paginas': '543',
#   'isbn': '978-90-225-4522-5'},
#  'Earthsea': None,
#  'Eloise (book)': None,
#  'Emergence (Palmer novel)': None,
#  'Eldest': {'naam': 'Oudste',
#   'orig titel': 'Eldest',
#   'auteur': '[[Christopher Paolini]]',
#   'land': '[[Verenigde Staten]]',
#   'taal': '[[Engels]]',
#   'reeks': '[[Het erfgoed]]',
#   'genre': '[[Fantasy (genre)|Fantasy]]',
#   'uitgever': '[[Random House]] <small>(De Verenigde Staten)</small><br />[[Mynx]] <small>(Nederland en België)</small>',
#   'uitgiftedatum': '[[2005]], [[2007]]',
#   'paginas': '566',
#   'isbn': '978-90-225-4258-3',
#   'voorafgegaan': '[[Eragon (boek)|Eragon]]',
#   'vervolg': '[[Brisingr (boek)|Brisingr]]'},
#  'Emotionally Weird': None,
#  'Dune (novel)': {'naam': 'Dune',
#   'auteur': 'Frank Herbert',
#   'kaftontwerp': 'John Schoenherr',
#   'land': 'Verenigde Staten',
#   'originele taal': 'Engels',
#   'genre': 'Science fiction',
#   'originele uitgever': 'Chilton Books',
#   'uitgiftedatum origineel': 'Augustus 1965',
#   'medium': 'Hardcover & paperback',
#   'paginas': '412',
#   'vervolg': 'Dune Messiah'},
#  'Emergency Response Guidebook': None,
#  'Emphyrio': {'naam': 'Emphyrio',
#   'auteur': '[[Jack Vance]]',
#   'vertaler': 'Mark Carpentier Alting',
#   'uitgever': '[[Meulenhoff & Co|Meulenhoff]]',
#   'orig titel': 'Emphyrio',
#   'uitgiftedatum': '1969, 1973',
#   'genre': '[[Sciencefiction]]',
#   'paginas': '255 blz',
#   'isbn': '9029000074'},
#  'Elric of Melnibone': {'naam': 'Storm over Melniboné',
#   'orig titel': "''Elric of Melniboné''",
#   'auteur': '[[Michael Moorcock]]',
#   'land': '{{GB}}',
#   'taal': 'Nederlands',
#   'originele taal': '[[Engels]]',
#   'reeks': '[[Scala SF]]',
#   'onderwerp': 'Elric Saga',
#   'genre': '[[Sciencefiction]]',
#   'uitgever': 'Scala',
#   'uitgiftedatum': '1976',
#   'uitgiftedatum origineel': '1972',
#   'medium': '[[pocketboek]]',
#   'grootte': '180 x 115',
#   'isbn': '90-6221-271-9',
#   'extra portaal': 'Sciencefiction'},
#  'Empress Orchid': None,
#  'En Iniya Iyanthira': None,
#  'Encyclopedia of public health': None,
#  'Encyclopaedia Iranica': None,
#  'Encyclopedia of Mormonism': None,
#  'Empire of the Atom': {'naam': 'Het rijk van het atoom',
#   'cover-op-enwp': 'Empire of the atom.jpg',
#   'orig titel': "''The Empire of the Atom''",
#   'auteur': '[[A.E. van Vogt]]',
#   'vertaler': 'L. Schimmelpenninck',
#   'land': '{{CA}}',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'reeks': '[[Scala SF]]',
#   'genre': '[[Sciencefiction]]',
#   'uitgever': 'Scala',
#   'originele uitgever': 'Shasta Publishers',
#   'uitgiftedatum': '1975',
#   'uitgiftedatum origineel': '1947',
#   'medium': '[[pocketboek]]',
#   'paginas': '155',
#   'isbn': '90-6221-001-5',
#   'volgendeboek': '[[De tovenaar van Linn]]',
#   'extra portaal': 'Sciencefiction'},
#  'Empire (2006 novel)': None,
#  'England, England': None,
#  "Engines (children's book)": None,
#  'Empire of the Sun': None,
#  'Energy and Power': None,
#  'Endgame (play)': None,
#  'Empire Falls': None,
#  'Engines of Creation': {'titel': 'Engines of Creation',
#   'soort': 'Album',
#   'artiest': '[[Galleon (Zweedse band)|Galleon]]',
#   'opname': 'juli 2006 / mei 2007',
#   'datum': 'november',
#   'jaar': '[[:Categorie:Muziekalbum uit 2007|2007]]',
#   'genre': '[[progressieve rock]]',
#   'duur': '57 minuten',
#   'label': '[[Progress Records]]',
#   'vorige album': '[[:Categorie:Muziekalbum uit 2003|2003]]<br /> [[From land to ocean]]',
#   'volgende album': '[[:Categorie:Muziekalbum uit 2010|2010]] <br /> [[In the wake of the moon]]'},
#  'Eon (novel)': None,
#  'Eon: Dragoneye Reborn': None,
#  "Ender's Game": None,
#  'Esperanza Rising': None,
#  'Evan Winter': None,
#  'Equal Rites': {'naam': 'Meidezeggenschap',
#   'reeks': '[[Schijfwereld]]',
#   'auteur': '[[Terry Pratchett]]',
#   'vertaler': '[[Venugopalan Ittekot]]',
#   'uitgever': '[[Het Spectrum]]',
#   'orig titel': 'Equal Rites',
#   'uitgiftedatum': '1992 (Origineel: 1987)',
#   'genre': '[[Fantasy (genre)|Fantasy]]',
#   'paginas': '183 blz',
#   'isbn': '9027429014',
#   'voorafgegaan': '[[Dat wonderbare licht]]',
#   'vervolg': '[[Dunne Hein]]'},
#  'Eternity Road (novel)': None,
#  'Escape to Nowhere': None,
#  'Everfree': None,
#  'Erewhon': None,
#  'Evermore (anthology)': None,
#  'Est Playing the Game': None,
#  'Escape to Witch Mountain': None,
#  'Ernest Cline': {'naam': 'Ernest Cline',
#   'afbeelding': 'Ernest Cline (35355088274).jpg',
#   'onderschrift': "Ernest Cline op ''2017 Comic-Con International'', San Diego",
#   'volledige naam': 'Ernest Christy Cline',
#   'geboren': '[[29 maart]] [[1972]]',
#   'geboorteplaats': '[[Ashland (Ohio)]]',
#   'land': '{{US}}',
#   'beroep': '[[Schrijver]]',
#   'jaren-actief': '1996-heden',
#   'genre': '[[Sciencefiction]]',
#   'portaal2': 'Sciencefiction'},
#  'Evening in Byzantium': None,
#  'Eugènie Grandet': None,
#  "Every Day is Mother's Day": None,
#  'Eragon': {'naam': 'Eragon',
#   'orig titel': 'Eragon',
#   'auteur': '[[Christopher Paolini]]',
#   'land': '[[Verenigde Staten]]',
#   'taal': '[[Engels]]',
#   'reeks': '[[Het erfgoed]]',
#   'genre': '[[Fantasy (genre)|Fantasy]]',
#   'uitgever': '[[Random House]] <small>(De Verenigde Staten)</small><br />[[Mynx]] <small>(Nederland en België)</small> [[CORGI BOOKS]] <small>(Nederland)</small>',
#   'uitgiftedatum': '[[2003]]',
#   'paginas': '447',
#   'isbn': '978-90-225-4828-8',
#   'film': '[[Eragon (film)]]',
#   'vervolg': '[[Oudste (boek)|Oudste]]'},
#  'Eromanga Sensei': None,
#  'Essais': {'naam': 'Essais',
#   'afbeelding': 'Essays (Montaigne).jpg',
#   'onderschrift': 'Titelpagina van de Essais',
#   'auteur': '[[Michel de Montaigne]]',
#   'land': 'Frankrijk',
#   'originele taal': 'Middelfrans',
#   'genre': '[[Essay]]',
#   'originele uitgever': 'Simon Millanges (maart 1580)',
#   'uitgiftedatum origineel': '1580',
#   'extra portaal': 'Filosofie'},
#  'Eureka Seven': None,
#  'Everyone Worth Knowing': None,
#  'Excalibur (novel)': None,
#  'Epic of Gilgamesh': None,
#  'Encyclopædia Britannica': {'naam': 'Encyclopædia Britannica',
#   'afbeelding': 'Encyclopaedia Britannica 15 with 2002.jpg',
#   'onderschrift': 'De 15e editie van Encyclopædia Britannica',
#   'auteur': '4.411 (2008)',
#   'land': '[[Schotland]] (1768-1900) <br />[[Verenigde Staten]] (1901-)',
#   'taal': '[[Engels]]',
#   'onderwerp': 'Algemeen',
#   'genre': '[[Encyclopedie|Encyclopedisch]] [[naslagwerk]]',
#   'uitgever': 'Encyclopædia Britannica, Inc.',
#   'uitgiftedatum': '1768-2012',
#   'medium': '32 gebonden delen (2008)',
#   'isbn': '1-59339-292-3'},
#  'Expecting Someone Taller': None,
#  'Excellent Women': None,
#  'Everything You Always Wanted to Know About Sex* (*But Were Afraid to Ask) (book)': None,
#  'Exegesis (book)': None,
#  'Expendable': None,
#  'Everything and Nothing': None,
#  'Executive Orders': None,
#  'Expedition Venus': None,
#  'Excession': None,
#  'Expanded Universe (Heinlein)': None,
#  "Euclid's Elements": None,
#  'Eye of Cat': None,
#  'Facing Mount Kenya': None,
#  'Explosive Eighteen': None,
#  'Fablehaven': {'titel': 'Fabelhaven',
#   'orig titel': 'Fablehaven',
#   'land': '[[Verenigde Staten]]',
#   'taal': '[[Engels]]',
#   'genre': '[[Fantasy (genre)|Fantasy]]',
#   'volgnummer': '5, 2 vertaald',
#   'schrijver': '[[Brandon Mull]]',
#   'uitgever': '[[De Boekerij]]',
#   'medium': 'Paperback',
#   'status': 'Actief',
#   'jaren-actief': '2010 - 2011',
#   'eerste': '2010',
#   'laatste': '2011',
#   'website': 'http://www.brandonmull.com/fablehaven/',
#   'lijst': "1: Fabelhaven<br />2: De Opkomst Van De Avondster<br />(3: Gevangen Door De Schaduwplaag)<br />(4: ''Secrets Of The Dragon Sanctuary'')<br />(5: ''Keys To The Demon Prison'')"},
#  'Fablehaven: Rise of the Evening Star': None,
#  'Faded Sun Trilogy': None,
#  'Eucalyptus': {'type': 'plant',
#   'titelweergave': "''Eucalyptus''",
#   'naam': "''Eucalyptus''",
#   'afbeelding': 'Eucalyptus tree.jpg',
#   'rijk': "''[[Planten|Plantae]]'' (Planten)",
#   'stam': "''[[Embryophyta]]'' (Landplanten)",
#   'klasse': "''[[Spermatopsida]]'' (Zaadplanten)",
#   'clade1': '[[Bedektzadigen]]',
#   'clade2': "[['nieuwe' Tweezaadlobbigen]]",
#   'clade4': '[[Rosiden]]',
#   'orde': "''[[Myrtales]]''",
#   'familie': "''[[Myrtaceae]]'' (Mirtefamilie)",
#   'onderfamilie': "''[[Myrtoideae]]''",
#   'tribus': "''[[Eucalypteae]]''",
#   'taxon': '[[Geslacht (biologie)|Geslacht]]',
#   'w-naam': "''Eucalyptus''",
#   'auteur': "[[Charles Louis L'Héritier de Brutelle|L'Her.]]",
#   'datum': '1789'},
#  'Faerie Tale': None,
#  'Fail-Safe (novel)': None,
#  'Family Matters (novel)': None,
#  'Faery in Shadow': None,
#  'Face the Fire': None,
#  'Fair Stood the Wind for France': None,
#  'Erasmus': {'naam': 'Desiderius Erasmus Roterodamus',
#   'afbeelding': 'Holbein-erasmus.jpg',
#   'onderschrift': 'Desiderius Erasmus door [[Hans Holbein de Jonge]]',
#   'volledige naam': 'Desiderius Erasmus Roterodamus',
#   'geboren': '[[28 oktober]] [[1466]]/[[1467]]/[[1469]]',
#   'overleden': '[[12 juli]] [[1536]]',
#   'land': '[[Bourgondische Nederlanden|Bourgondische]] en [[Habsburgse Nederlanden]]',
#   'beroep': '[[Filosoof]], [[Renaissance-humanisme|humanist]], [[auteur]], [[theoloog]]',
#   'belangrijkste ideeën': '[[Bestand:Open book nae 02.svg|25px]] [[Lof der zotheid]]',
#   'religie': 'Christelijk'},
#  'Falling Free': {'naam': 'Falling Free',
#   'orig titel': 'Falling Free',
#   'auteur': '[[Lois McMaster Bujold]]',
#   'kaftontwerp': '[[Alan Gutierrez]]',
#   'land': '[[Verenigde Staten]]',
#   'originele taal': '[[Engels]]',
#   'reeks': '[[Vorkosigan Saga]]',
#   'genre': '[[Sciencefiction]]',
#   'originele uitgever': '[[Baen Books]]',
#   'uitgiftedatum origineel': 'april 1988',
#   'medium': '[[Paperback]]',
#   'paginas': '307',
#   'isbn': '0-671-65398-9',
#   'voorafgegaan': '[[Ethan of Athos]]',
#   'vervolg': '[[Brothers in Arms (Bujold)|Brothers in Arms]]',
#   'extra portaal': 'Sciencefiction'},
#  'Fafhrd and the Gray Mouser': None,
#  'Fantastic Voyage II: Destination Brain': None,
#  'Fatal Voyage': None,
#  "Farnham's Freehold": None,
#  'Farmer in the Sky': None,
#  'Farewell to Manzanar': None,
#  'Farewell, My Lovely': None,
#  'Fantastic Voyage': None,
#  'Fantastic Beasts and Where to Find Them': {'naam': 'Fabeldieren en Waar Ze Te Vinden',
#   'orig titel': "''Fantastic Beasts and Where to Find Them''",
#   'auteur': '[[J.K. Rowling]]',
#   'taal': 'Engels',
#   'uitgever': 'Bloomsbury',
#   'uitgiftedatum': '2001',
#   'paginas': '128 pagina’s'},
#  'Fearful Symmetries (Swann Novel)': None,
#  'Fashionable Nonsense': None,
#  'Favorite Flies and Their Histories': None,
#  'Fearful Pleasures': None,
#  'Fearless, a novel of Sarah Bowman': None,
#  'Fast Food Nation': {'titel': 'Fast Food Nation',
#   'regie': '[[Richard Linklater]]',
#   'producer': '[[Jeremy Thomas]], [[Malcolm McLaren]]',
#   'schrijver': 'Boek: [[Eric Schlosser]] Scenario: Richard Linklater en Eric Schlosser',
#   'spelers': '[[Patricia Arquette]]<br />[[Luis Guzmán]]<br />[[Ethan Hawke]]<br />[[Ashley Johnson]]<br />[[Greg Kinnear]]<br />[[Kris Kristofferson]]<br />[[Catalina Sandino Moreno]]<br />[[Ana Claudia Talancón]]<br />[[Wilmer Valderrama]]',
#   'muziek': '[[Friends of Dean Martinez]]',
#   'montage': 'Sandra Adair',
#   'cinematografie': '[[Lee Daniel]]',
#   'distributeur': '[[Fox Searchlight Pictures]] (VS)<br />[[Tartan Films]] (Groot Brittannië)',
#   'première': '[[2006]]',
#   'genre': 'Drama',
#   'lengte': '116 minuten',
#   'taal': 'Engels',
#   'land': '{{US}} <br /> {{GB}}',
#   'imdb': '0460792',
#   'moviemeter': '37050'},
#  'Fanny Hill': {'naam': 'Fanny Hill',
#   'afbeelding': 'Fanny Hill 1910 cover.jpg',
#   'onderschrift': 'De [[omslag]] van een Engelstalige uitgave',
#   'orig titel': "''Memoirs of a Woman of Pleasure''",
#   'auteur': '[[John Cleland]]',
#   'illustraties': '[[Édouard-Henri Avril]]',
#   'land': '[[Verenigd Koninkrijk]]',
#   'originele taal': '[[Engels]]',
#   'genre': '[[Erotisch|Erotische]] [[Roman (literatuur)|roman]]',
#   'originele uitgever': 'G. Fenton',
#   'uitgiftedatum origineel': '[[1748]]',
#   'paginas': '256'},
#  'Faust, Part 2': None,
#  'Fear of Flying (novel)': None,
#  'Fate/strange fake': None,
#  'Faust, Part 1': None,
#  "Fear and Loathing on the Campaign Trail '72": None,
#  'Feersum Endjinn': None,
#  'Fearsome Creatures of the Lumberwoods': None,
#  'Fahrenheit 451': None,
#  'Fear and Loathing in Las Vegas': None,
#  'Fatherland (novel)': {'naam': 'Fatherland',
#   'orig titel': 'Fatherland',
#   'vertaler': 'Ronald Beek',
#   'auteur': '[[Robert Harris (schrijver)|Robert Harris]]',
#   'land': '[[Verenigde Staten]]',
#   'taal': 'Nederlands',
#   'genre': '[[Thriller (genre)|Thriller]]',
#   'uitgever': '[[De Boekerij]]',
#   'uitgiftedatum': '1992',
#   'medium': '[[paperback]]',
#   'paginas': '318',
#   'isbn': '9046120961'},
#  'Fate/Apocrypha': None,
#  'Fate/Zero': None,
#  'Fifth Business': None,
#  'Feuchtgebiete': {'titel': "''Feuchtgebiete''<br /><small>''Vochtige streken''</small>",
#   'poster-op-enwp': 'Wetlands poster.jpg',
#   'regie': '[[David Wnendt]]',
#   'producer': 'Peter Rommel',
#   'schrijver': 'Claus Falkenberg<br />David Wnendt',
#   'bronmateriaal': "''Feuchtgebiete''<br />van [[Charlotte Roche]]",
#   'spelers': '[[Carla Juri]]',
#   'muziek': 'Enis Rotthoff',
#   'montage': 'Andreas Wodraschke',
#   'cinematografie': 'Jakub Bejnarowicz',
#   'prodmaatschappij': 'Rommel Film',
#   'distributeur': 'Majestic Filmverleih',
#   'première': '11 augustus 2013 <small>([[Internationaal filmfestival van Locarno|Locarno]])</small><br /> {{NL-VLAG}} 10 April 2014',
#   'genre': '[[Komedie (genre)|Komedie]], [[Drama (genre)|drama]], [[Coming of age (genre)|coming of age]]',
#   'lengte': '109 minuten',
#   'taal': '[[Duits]]',
#   'land': '{{DE}}',
#   'opbrengst': 'US$ 10,5 miljoen',
#   'imdb': '2524674',
#   'moviemeter': '90193'},
#  'Ficciones': None,
#  'Fifty Shades Freed': {'naam': "''Vijftig tinten vrij''",
#   'orig titel': "''Fifty Shades Freed''",
#   'auteur': 'Erika Leonard',
#   'land': '{{UK}}',
#   'taal': '[[Nederlands]]',
#   'originele taal': '[[Engels]]',
#   'onderwerp': '[[bdsm]]',
#   'genre': 'Thriller',
#   'uitgever': 'Prometheus',
#   'uitgiftedatum': '31 juli 2012',
#   'medium': 'Paperback',
#   'paginas': '460',
#   'grootte_gewicht': '213 mm × 136 mm × 43 mm; 650 g',
#   'isbn': '9789044621860',
#   'voorafgegaan': '[[Vijftig tinten donkerder]]'},
#  'Fifty Shades Darker': {'naam': 'Vijftig tinten donkerder',
#   'orig titel': "''Fifty Shades Darker",
#   'auteur': 'Erika Leonard',
#   'land': '{{UK}}',
#   'taal': '[[Nederlands]]',
#   'originele taal': '[[Engels]]',
#   'onderwerp': '[[bdsm]]',
#   'genre': 'roman',
#   'uitgever': 'Prometheus',
#   'uitgiftedatum': '18 juni 2012',
#   'medium': 'Paperback',
#   'paginas': '550',
#   'grootte_gewicht': '213 mm x 137 mm x 38 mm; 598 g',
#   'isbn': '9789044621853',
#   'voorafgegaan': '[[Vijftig tinten grijs]]',
#   'vervolg': '[[Vijftig tinten vrij]]'},
#  'Ezra Pound': None,
#  'Fine Things': None,
#  'Fences (play)': None,
#  'Fire and Sleet and Candlelight': None,
#  'FLCL': None,
#  'Five Against Venus': None,
#  'Five Days In Paris': None,
#  'Five Children and It': None,
#  'Fingersmith (novel)': None,
#  'Five Quarters of the Orange': None,
#  'First Man: The Life of Neil A. Armstrong': None,
#  'Fifty Shades of Grey': {'naam': "''Vijftig tinten grijs''",
#   'afbeelding': 'Shades of Grey - Geheimes Verlangen (E. L. James, 2012).jpg',
#   'onderschrift': "Duitse hardcovereditie van ''Vijftig tinten grijs''",
#   'orig titel': "''Fifty Shades of Grey''",
#   'auteur': 'Erika Leonard',
#   'land': '{{UK}}',
#   'originele taal': '[[Engels]]',
#   'onderwerp': '[[Bdsm]]',
#   'genre': 'Erotische thriller',
#   'uitgever': 'Prometheus',
#   'uitgiftedatum': '24 mei 2012',
#   'medium': 'Paperback',
#   'paginas': '526',
#   'grootte_gewicht': '213 x 140 x 36 mm; 561 g',
#   'isbn': '9789044621846',
#   'vervolg': '[[Vijftig tinten donkerder]]'},
#  'Fifty Shades trilogy': None,
#  'Five Point Someone': None,
#  'Flesh and Fire': None,
#  'Flare (science fiction novel)': None,
#  'Flaws in the Glass': None,
#  'First Men in the Moon': None,
#  'Floodtide': None,
#  'Fledgling (novel)': None,
#  "Flaubert's Parrot": None,
#  'Floating Flies and How to Dress Them': None,
#  'Fool on the Hill (novel)': None,
#  'Fludd (novel)': None,
#  'Flush (novel)': None,
#  ...}

# %%
import re

clean = {
    '[': ' ',
    ']': ' ',
    '{': ' ',
    '}': ' ',
    '|': ' ',
}

translation = str.maketrans(clean)
WHITESPACE_PATTERN = re.compile(r'\W+')
TAG_PATTERN = re.compile(r'<[^>]+>')

def clean_str(string):
    # remove brackets
    string = string.translate(translation)
    # remove html tags
    string = re.sub(TAG_PATTERN, ' ', string)
    # Collapse whitespace
    string = re.sub(WHITESPACE_PATTERN, ' ', string)
    return string.strip()

# %%
def unpack_iterables(item):
    if (type(item) in (int, float)):
        return item
    elif type(item) == str:
        return clean_str(item)
    elif len(item) > 0 and all(type(a) not in (list, tuple, set) for a in item):
        return item
    
    return unpack_iterables(item[0])

# %%
for k, v in en_infoboxes.items():
    if type(v) == dict:
        for k1, v1 in v.items():
            en_infoboxes[k][k1] = unpack_iterables(v1)
en_infoboxes
# Out:
# {'A Batalha do Apocalipse': {'name': 'A Batalha do Apocalipse Da Queda dos Anjos ao Crepúsculo do Mundo The Battle of Apocalypse From the Fall of Angels to the Twilight of the World',
#   'image': 'A Batalha do Apocalipse jpg',
#   'author': 'Eduardo Spohr',
#   'country': 'Brazil',
#   'language': 'Portuguese language Portuguese',
#   'genre': 'Fiction Fantastic Literature Angels',
#   'publisher': 'Verus',
#   'release_date': '2010',
#   'pages': '586',
#   'isbn': '9788576860761'},
#  'A Clean, Well-Lighted Place': {'name': 'A Clean Well Lighted Place',
#   'author': 'Ernest Hemingway',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Short story',
#   'publication_type': 'Periodical',
#   'media_type': 'Print',
#   'pub_date': '1933'},
#  '334 (novel)': {'name': '334',
#   'image': '334 novel book cover jpg',
#   'caption': 'Dust jacket from the first edition hardcover by Michael Hasted',
#   'author': 'Thomas M Disch',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Dystopian novel Dystopian science fiction',
#   'published': '1972 MacGibbon Kee',
#   'media_type': 'Print hardback',
#   'pages': '201',
#   'isbn': '0 261 63283 3',
#   'dewey': '813 5 4',
#   'congress': 'PZ4 D615 Th3 PS3554 I8',
#   'oclc': '707750'},
#  '1876 (novel)': {'name': '1876',
#   'image': '1876Novel jpg',
#   'caption': 'Cover of the first edition',
#   'author': 'Gore Vidal',
#   'country': 'United States',
#   'language': 'English',
#   'series': 'Narratives of Empire',
#   'genre': 'Historical novel',
#   'publisher': 'Random House',
#   'release_date': '1976',
#   'media_type': 'Print Hardback Paperback',
#   'pages': '364 pp',
#   'isbn': '0 394 49750 3',
#   'dewey': '813 5 4',
#   'congress': 'PS3543 I26 A6214 1976',
#   'oclc': '1859740',
#   'preceded_by': 'Lincoln novel Lincoln',
#   'followed_by': 'Empire Vidal novel Empire'},
#  'A Blues for Shindig': {'name': 'A Blues for Shindig',
#   'image': 'Mo Foster A blues for Shindig jpeg',
#   'author': 'Mo Foster',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'genre': 'Novel',
#   'publisher': 'PaperBooks',
#   'release_date': 'June 2006',
#   'pages': '304',
#   'isbn': '978 0 9551094 2 3',
#   'oclc': '69486792',
#   'followed_by': 'Wordsfly'},
#  "A Buyer's Market": {'name': 'A Buyer s Market',
#   'image': 'image BuyersMarket jpg',
#   'caption': 'First edition',
#   'author': 'Anthony Powell',
#   'cover_artist': 'James Broom Lynne',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'series': 'A Dance to the Music of Time',
#   'genre': 'Satirical Philosophical novel',
#   'publisher': 'Heinemann book publisher Heinemann',
#   'release_date': '1952',
#   'media_type': 'Print Hardcover Hardback Paperback',
#   'preceded_by': 'A Question of Upbringing',
#   'followed_by': 'The Acceptance World',
#   'dewey': '823 91',
#   'oclc': '54031610',
#   'congress': 'PR6031 O74'},
#  'A Change of Climate': {'name': 'A Change of Climate',
#   'image': 'File ChangeOfClimate JPG',
#   'caption': 'First edition UK',
#   'author': 'Hilary Mantel',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'publisher': 'Viking Books UK Owl Books US',
#   'release_date': '1994 UK 1997 US',
#   'media_type': 'Print',
#   'pages': '352 UK 336 US',
#   'isbn': '0 670 83051 8',
#   'isbn_note': 'UK ISBN 0 8050 5205 4 US'},
#  'A Burnt-Out Case': {'name': 'A Burnt Out Case',
#   'image': 'image BurntOutCase jpg',
#   'caption': 'First edition cover',
#   'cover_artist': 'Lacey Everett',
#   'author': 'Graham Greene',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'genre': 'Novel',
#   'publisher': 'Heinemann book publisher Heinemann',
#   'published': '1960',
#   'media_type': 'Print hardback paperback'},
#  '2312 (novel)': {'name': '2312',
#   'image': 'Kim Stanley Robinson 2312 jpeg',
#   'caption': 'First edition',
#   'author': 'Kim Stanley Robinson',
#   'cover_artist': 'Kirk Benshoff',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Science fiction',
#   'publisher': 'Orbit',
#   'release_date': 'May 23 2012',
#   'media_type': 'Print hardcover and electronic book and Compact disc audio CD',
#   'pages': '576',
#   'isbn': '978 0 316 09812 0',
#   'awards': 'Nebula Award for Best Novel'},
#  'A Concise Treatise on the Art of Angling': {'name': 'A Concise Treatise on the Art of Angling',
#   'image': 'TitlePageAConciseTreatise JPG',
#   'caption': 'Title Page 7th Edition 1807',
#   'author': 'Thomas Best',
#   'country': 'England',
#   'language': 'English',
#   'subject': 'Fly fishing',
#   'publisher': 'B Crosby and Co London',
#   'pub_date': '1787',
#   'pages': '186'},
#  'A Certain Smile': {'name': 'A Certain Smile',
#   'title_orig': 'Un Certain Sourire',
#   'translator': 'Anne Green',
#   'image': 'ACertainSmile jpg',
#   'caption': 'First US edition',
#   'author': 'Françoise Sagan',
#   'cover_artist': 'Catherine Denvir',
#   'country': 'France',
#   'language': 'French language French',
#   'genre': 'Romance novel',
#   'publisher': 'E P Dutton US',
#   'english_pub_date': '1956',
#   'preceded_by': 'Bonjour Tristesse',
#   'followed_by': 'Dans un mois dans un an'},
#  '1632 series': {'name': '1632 series',
#   'image': '1632 Eric Flint 2000 cover jpg',
#   'image_caption': '1632 the first novel in the series',
#   'author': 'Eric Flint and others',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Alternate history',
#   'publisher': 'Baen Books Eric Flint s Ring of Fire Press',
#   'pub_date': 'February 2000 ongoing',
#   'media_type': 'Print hardcover and paperback audiobook e book',
#   'number_of_books': '60'},
#  "A Clergyman's Daughter": {'name': 'A Clergyman s Daughter',
#   'image': 'File A Clergyman s Daughter 1st US edition cover art jpg',
#   'caption': 'First US edition cover the novel published in America with a slight change of title as The Clergyman s Daughter',
#   'author': 'George Orwell',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'published': '1935 Victor Gollancz',
#   'media_type': 'Print hardback paperback',
#   'preceded_by': 'Burmese Days',
#   'followed_by': 'Keep the Aspidistra Flying'},
#  'A Book on Angling': {'name': 'A Book on Angling Being a complete treatise on the art of angling in every branch',
#   'image': 'FrancisFrancis1876 JPG',
#   'caption': 'Frontispiece from 4th Edition 1876 The Author and His Gillie',
#   'author': 'Francis Francis',
#   'country': 'Great Britain',
#   'language': 'English',
#   'subject': 'Fishing Fly fishing',
#   'publisher': 'Longman Longmans Green and Company London',
#   'pub_date': '1867',
#   'pages': '508'},
#  'A Child Called It': {'name': 'David Pelzer',
#   'image': 'Dave Pelzer USAF jpg',
#   'alt': 'Profile view of Author Dave Pelzer facing left',
#   'caption': 'Pelzer speaking to Airmen while visiting troops in Southwest Asia',
#   'birth_date': 'Birth date and age 1960 12 29',
#   'birth_place': 'Daly City California',
#   'occupation': 'Autobiographer motivational speaker',
#   'nationality': 'United States American',
#   'notableworks': 'A Child Called It Help Yourself',
#   'website': 'URL http www davepelzer com'},
#  'A Case of Conscience': {'name': 'A Case of Conscience',
#   'image': 'ACaseOfConscience novel jpg',
#   'caption': 'Paperback first edition',
#   'author': 'James Blish',
#   'country': 'United States',
#   'language': 'English',
#   'series': 'James Blish Career After Such Knowledge trilogy',
#   'genre': 'Science fiction',
#   'published': '1958 Ballantine Books',
#   'media_type': 'Print paperback',
#   'pages': '192',
#   'isbn': '0 345 43835 3',
#   'ISBN_note': 'later paperback printing',
#   'dewey': '813 54 21',
#   'congress': 'PS3503 L64 C37 2000',
#   'oclc': '45074320',
#   'followed_by': 'Doctor Mirabilis novel Doctor Mirabilis Black Easter The Day After Judgment'},
#  '2010: Odyssey Two': {'name': '2010 Odyssey Two',
#   'image': 'ArthurCClarke 2010OdysseyTwo jpg',
#   'caption': 'First Edition cover 1982',
#   'author': 'Arthur C Clarke',
#   'cover_artist': 'Michael Whelan',
#   'country': 'United States',
#   'series': 'The Space Odyssey series Space Odyssey',
#   'genre': 'Science fiction',
#   'publisher': 'Ballantine Books',
#   'release_date': 'December 1982',
#   'media_type': 'Print Hardcover Paperback',
#   'pages': '291 first edition hardback',
#   'isbn': '0 345 30305 9',
#   'ISBN_note': 'first edition hardback',
#   'preceded_by': '2001 A Space Odyssey novel 2001 A Space Odyssey',
#   'followed_by': '2061 Odyssey Three'},
#  'A Bend in the River': {'name': 'A Bend in the River',
#   'image': 'File BendInTheRiver JPG',
#   'caption': 'First edition',
#   'author': 'V S Naipaul',
#   'country': 'Trinidad and Tobago',
#   'language': 'English',
#   'publisher': 'Alfred A Knopf',
#   'release_date': 'May 1979',
#   'media_type': 'Print',
#   'pages': '278 pages',
#   'isbn': '0 394 50573 5',
#   'dewey': '823 9 14',
#   'congress': 'PZ4 N155 Be 1979 PR9272 9 N32',
#   'oclc': '4494403'},
#  'A Canticle for Leibowitz': {'name': 'A Canticle for Leibowitz',
#   'image': 'A Canticle for Leibowitz cover 1st ed jpg',
#   'alt': 'A man in monk s garb surrounded by stone ruins',
#   'caption': 'First edition dust jacket Illustration by George Sottung',
#   'author': 'Walter M Miller Jr',
#   'cover_artist': 'George Sottung',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Science fiction',
#   'published': 'October 1959 J B Lippincott Co',
#   'media_type': 'Print hardback paperback',
#   'pages': '320',
#   'oclc': '1451434',
#   'followed_by': 'Saint Leibowitz and the Wild Horse Woman'},
#  'A Brief History of Time': {'name': 'A Brief History of Time',
#   'image': 'BriefHistoryTime jpg',
#   'caption': 'First edition',
#   'author': 'Stephen Hawking',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'subject': 'Cosmology',
#   'publisher': 'Bantam Books Bantam Dell Publishing Group',
#   'pub_date': '1988',
#   'media_type': 'Print Hardcover and Paperback',
#   'pages': '256',
#   'isbn': '978 0 553 10953 5',
#   'dewey': '523 1 21',
#   'congress': 'QB981 H377 1998',
#   'oclc': '39256652',
#   'followed_by': 'Black Holes and Baby Universes and Other Essays'},
#  '11/22/63': {'name': '11 22 63',
#   'image': '11 22 63 jpg',
#   'caption': 'First edition cover',
#   'author': 'Stephen King',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Science fiction Alternate history',
#   'publisher': 'Charles Scribner s Sons Scribner',
#   'release_date': 'November 8 2011',
#   'media_type': 'Print hardcover',
#   'pages': '849',
#   'isbn': '978 1 4516 2728 2'},
#  'A Crown of Swords': {'name': 'A Crown of Swords',
#   'image': 'WoT07 ACrownOfSwords jpg',
#   'caption': 'Original cover of A Crown of Swords showing Rand al Thor standing in Shadar Logoth',
#   'author': 'Robert Jordan',
#   'cover_artist': 'Darrell K Sweet Tyler Jacobson 2013 Edition',
#   'country': 'United States',
#   'language': 'English',
#   'series': 'The Wheel of Time',
#   'genre': 'Fantasy literature Fantasy',
#   'published': '1996 Tor Books U S and Orbit UK',
#   'media_type': 'Print hardback paperback',
#   'pages': '881 U S paperback edition 720 U S hardback edition',
#   'isbn': '0 312 85767 5',
#   'isbn_note': 'US hardback edition',
#   'dewey': '813 54 20',
#   'congress': 'PS3560 O7617 C76 1996',
#   'oclc': '33819178',
#   'preceded_by': 'Lord of Chaos',
#   'followed_by': 'The Path of Daggers'},
#  'A Clockwork Orange (novel)': {'name': 'A Clockwork Orange',
#   'image': 'Clockwork orange jpg',
#   'caption': 'Dust jacket from the first edition',
#   'cover_artist': 'Barry Trengove',
#   'author': 'Anthony Burgess',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'genre': 'Science fiction dystopian fiction satire black comedy',
#   'published': '1962 Heinemann book publisher William Heinemann UK',
#   'media_type': 'Print hardback paperback audio book Compact audio cassette cassette Compact Disc CD',
#   'pages': '192 pages hardback edition 176 pages paperback edition',
#   'isbn': '0 434 09800 0',
#   'oclc': '4205836'},
#  "A Connecticut Yankee in King Arthur's Court": {'name': 'A Connecticut Yankee in King Arthur s Court',
#   'image': 'Connecticut Yankee4 new jpg',
#   'caption': '1889 frontispiece by Daniel Carter Beard restored',
#   'author': 'Mark Twain',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'alternate history fiction alternate history fantasy humor satire science fiction time travel',
#   'published': '1889 Charles L Webster and Co',
#   'wikisource': 'A Connecticut Yankee in King Arthur s Court'},
#  '1Q84': {'name': '1Q84',
#   'translator': 'Jay Rubin Philip Gabriel',
#   'image': '1Q84bookcover jpg',
#   'caption': 'Cover of Book 1',
#   'author': 'Haruki Murakami',
#   'country': 'Japan',
#   'language': 'Japanese',
#   'genre': 'Alternate history Parallel universe fiction parallel worlds',
#   'publisher': 'Shinchosha',
#   'release_date': 'May 29 2009 small Books 1 and 2 April 16 2010 small Book 3',
#   'english_pub_date': 'October 25 2011',
#   'media_type': 'Print hardcover',
#   'pages': '928',
#   'isbn': '978 0 307 59331 3',
#   'oclc': '701017688'},
#  '86 (novel series)': {'name': '86',
#   'image': '86 light novel volume 1 cover jpg',
#   'caption': 'Light novel volume 1 cover featuring Shinei Nouzen left and Vladilena Milizé right',
#   'ja_kanji': '86 エイティシックス',
#   'ja_romaji': 'Eiti Shikkusu',
#   'genre': 'ubl Mecha anime and manga Mecha ref cite web first Kim last Morrissy url https www animenewsnetwork com feature 2018 06 06 the best light novels not yet in english 132523 title The Best Light Novels Not Yet In English quote Special mention must go to the creative mecha designs which are based on spiders and other multi legged creatures work Anime News Network date June 6 2018 access date December 29 2020 Military science fiction ref cite web first Theron last Martin url https www animenewsnetwork com review eighty six novel 1 145708 title Review quote This novel is probably going to be most commonly classified as a military science fiction story but it should be considered at least as much a horror story date April 19 2019 work Anime News Network access date March 15 2021 Romance novel Romance ref cite web first Olive last St Sauver url https butwhythopodcast com 2020 09 25 review 86 eighty six volume 5 death be not proud title REVIEW 86 Eighty Six Volume 5 Death Be Not Proud work butwhythopodcast com quote The moments of awkward romance feel less forced and more of a comedic reminder that these characters are still teens they just have never been allowed to imagine a life for themselves outside war date September 25 2020 access date March 15 2021'},
#  'A Daughter of the Snows': {'name': 'A Daughter of the Snows',
#   'image': 'ADaughterOfTheSnows jpg',
#   'caption': 'First edition',
#   'author': 'Jack London',
#   'illustrator': 'Frederick C Yohn',
#   'country': 'United States',
#   'language': 'English',
#   'published': '1902 J B Lippincott Co J B Lippincott Company',
#   'media_type': 'Print hardcover',
#   'pages': '334 pp',
#   'oclc': '25651256'},
#  'A Dutiful Daughter': {'name': 'A Dutiful Daughter',
#   'image': 'A Dutiful Daughter jpg',
#   'caption': 'First edition',
#   'author': 'Thomas Keneally',
#   'country': 'Australia',
#   'language': 'English language English',
#   'genre': 'Fiction',
#   'publisher': 'Angus and Robertson',
#   'release_date': '1971',
#   'media_type': 'Print',
#   'pages': '183 pp',
#   'isbn': '0207954232',
#   'preceded_by': 'The Survivor Keneally novel The Survivor',
#   'followed_by': 'The Chant of Jimmie Blacksmith'},
#  'A Course in Miracles': {'name': 'A Course in Miracles',
#   'image': 'ACIM3COVER jpg',
#   'caption': 'A Course in Miracles Combined Volume Third Edition as published by the Foundation for Inner Peace',
#   'author': 'There is no author attributed to ACIM although it was scribed by Helen Schucman',
#   'editor': 'Helen Schucman Bill Thetford Kenneth Wapnick',
#   'country': 'United States',
#   'subject': 'Spiritual transformation Transformation',
#   'publisher': '1976 New York Viking The Foundation for Inner Peace 2007 The Foundation for Inner Peace 3rd ed',
#   'media_type': 'Print hardback and paperback',
#   'pages': '1333',
#   'isbn': '978 1 883360 24 5',
#   'oclc': '190860865'},
#  'A Death in the Family': {'name': 'A Death in the Family',
#   'image': 'ADeathintheFamily1stEd png',
#   'caption': 'First edition cover',
#   'author': 'James Agee',
#   'country': 'United States',
#   'language': 'English',
#   'published': '1957 McDowell Obolensky',
#   'media_type': 'Print hardcover',
#   'pages': '339 pp',
#   'oclc': '123180486'},
#  'A Far Cry From Kensington': {'name': 'A Far Cry from Kensington',
#   'image': 'File FarCryFromKensington jpg',
#   'border': 'yes',
#   'caption': 'First edition UK',
#   'author': 'Muriel Spark',
#   'cover_artist': 'Pat Doyle',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'publisher': 'Constable Robinson Constable UK Houghton Mifflin US',
#   'release_date': '1988',
#   'media_type': 'Print',
#   'pages': '189',
#   'isbn': '0 09 468290 9'},
#  'A Confederacy of Dunces': {'name': 'A Confederacy of Dunces',
#   'image': 'Confederacy of dunces cover jpg',
#   'image_size': '200px',
#   'author': 'John Kennedy Toole',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Comedy tragicomedy',
#   'published': '1980 Louisiana State University Press',
#   'media_type': 'Print hardback paperback audiobook e book',
#   'pages': '405 pp paperback sfn Toole 1980',
#   'isbn': '0 8071 0657 7',
#   'oclc': '5336849',
#   'dewey': '813 5 4',
#   'congress': 'PS3570 O54 C66 1980'},
#  'A Fine and Private Place': {'name': 'A Fine and Private Place',
#   'image': 'A Fine and Private Place jpg',
#   'caption': 'Dust cover of first edition',
#   'author': 'Peter S Beagle',
#   'cover_artist': 'George Salter',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Fantasy novel',
#   'published': '1960 Viking Press',
#   'media_type': 'Print Hardcover',
#   'pages': '272'},
#  'A Fall of Moondust': {'name': 'A Fall of Moondust',
#   'image': 'File A Fall of Moondust first edition jpg',
#   'caption': 'Cover of the first edition',
#   'author': 'Arthur C Clarke',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'genre': 'Science fiction',
#   'publisher': 'Victor Gollancz Ltd Gollancz',
#   'release_date': '1961',
#   'media_type': 'Print Hardcover Hardback',
#   'pages': '224',
#   'isbn': '0 575 07317 9',
#   'isbn_note': 'reprint',
#   'oclc': '59497789'},
#  'A Fine Balance': {'name': 'A Fine Balance',
#   'image': 'A Fine Balance jpg',
#   'caption': 'First edition',
#   'author': 'Rohinton Mistry',
#   'cover_artist': 'Dario Mitidieri',
#   'country': 'Canada',
#   'language': 'English language English',
#   'genre': 'Historical novel',
#   'published': '1995 McClelland and Stewart',
#   'media_type': 'Print Paperback',
#   'isbn': '0 679 44608 7',
#   'dewey': '813 54 20',
#   'congress': 'PR9199 3 M494 F56 1996',
#   'oclc': '33819149'},
#  'A Fable (novel)': {'name': 'A Fable',
#   'image': 'Fable jpg',
#   'caption': 'First edition cover',
#   'author': 'William Faulkner',
#   'cover_artist': 'Riki Levinson',
#   'country': 'United States',
#   'language': 'English',
#   'published': '1954 Random House',
#   'media_type': 'Print hardback paperback',
#   'preceded_by': 'Requiem for a Nun',
#   'followed_by': 'The Town 1957 novel The Town'},
#  'A Friend of the Earth': {'name': 'A Friend of the Earth',
#   'image': 'FriendOfTheEarth jpg',
#   'caption': '1st edition cover',
#   'author': 'T C Boyle',
#   'cover_artist': 'Marty Blake',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Eco fiction',
#   'published': '2000 Viking Books',
#   'media_type': 'Print',
#   'pages': '256 pages',
#   'isbn': '0 670 89177 0',
#   'dewey': '813 54 21',
#   'congress': 'PS3552 O932 F75 2000',
#   'oclc': '43296883'},
#  'A Fighting Man of Mars': {'name': 'A Fighting Man of Mars',
#   'image': 'Fighting Man of Mars jpg',
#   'alt': 'A Fighting Man of Mars',
#   'caption': 'dust jacket for A Fighting Man of Mars',
#   'author': 'Edgar Rice Burroughs',
#   'country': 'United States',
#   'language': 'English',
#   'series': 'Barsoom',
#   'genre': 'Science fantasy Science fantasy novel',
#   'publisher': 'Metropolitan Books',
#   'release_date': '1930',
#   'media_type': 'Print Hardcover Hardback',
#   'pages': '319',
#   'preceded_by': 'The Master Mind of Mars',
#   'followed_by': 'Swords of Mars'},
#  'A Day in the Life of Ivan Denisovich': {'name': 'One Day in the Life of Ivan Denisovich',
#   'title_orig': 'Один день Ивана Денисовича',
#   'translators': 'Ralph Parker 1963 Ron Hingley and Max Hayward 1963 Gillon Aitken 1970 H T Willetts 1991',
#   'image': 'One Day in the Life of Ivan Denisovich cover jpg',
#   'author': 'Aleksandr Solzhenitsyn',
#   'country': 'Soviet Union',
#   'language': 'Russian',
#   'publisher': 'New American Library Signet Classic',
#   'release_date': '1962',
#   'isbn': '0 451 52310 5',
#   'oclc': '29526909'},
#  'A Good Man is Hard to Find': {'name': 'A Good Man Is Hard to Find',
#   'image': 'AGoodManIsHardToFind jpg',
#   'caption': 'First edition cover',
#   'author': 'Flannery O Connor',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Southern Gothic',
#   'published': '1955 Harcourt Trade Publishers Harcourt Brace and Company',
#   'media_type': 'Print hardcover',
#   'pages': '256 pp',
#   'isbn': '978 0156364652'},
#  'A Fringe of Leaves': {'name': 'A Fringe of Leaves',
#   'image': 'Fringe of Leaves jpg',
#   'caption': 'First edition cover',
#   'author': 'Patrick White',
#   'cover_artist': 'Sidney Nolan Mrs Fraser and Convict oil and enamel on composition board 1962 64 in the collection of the Queensland Art Gallery',
#   'country': 'Australia',
#   'language': 'English',
#   'genre': 'Novel',
#   'published': '1976 Jonathan Cape',
#   'media_type': 'Print hardback and paperback',
#   'pages': '405 pp',
#   'isbn': '0 224 00902 8',
#   'dewey': '823',
#   'congress': 'PR9619 3 W5 E9 1973',
#   'oclc': '1147089'},
#  'A Good School': {'name': 'A Good School',
#   'image': 'A good school yates jpg',
#   'border': 'yes',
#   'caption': 'Cover to the first edition',
#   'author': 'Richard Yates novelist Richard Yates',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Novel',
#   'published': '1978 Dell Publishing Delacorte Press S Lawrence',
#   'media_type': 'Print hardback paperback',
#   'pages': '178 Hardback first edition',
#   'isbn': '0 440 03246 6',
#   'dewey': '813 5 4',
#   'congress': 'PZ4 Y335 Go 1978 PS3575 A83',
#   'oclc': '3965867'},
#  'A Heritage and Its History': {'name': 'A Heritage and Its History',
#   'image': 'Heritage History jpg',
#   'caption': 'First edition',
#   'author': 'Ivy Compton Burnett',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'genre': 'Family saga',
#   'publisher': 'Victor Gollancz Ltd Gollancz',
#   'pub_date': '1959',
#   'media_type': 'Print hardback',
#   'pages': '240 pp'},
#  'A Gun for Dinosaur and Other Imaginative Tales': {'name': 'A Gun for Dinosaur and Other Imaginative Tales',
#   'image': 'Gun for dinosaur jpg',
#   'caption': 'first edition of A Gun for Dinosaur and Other Imaginative Tales',
#   'author': 'L Sprague de Camp',
#   'cover_artist': 'Gilda Kuhlman',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Science fiction short stories',
#   'publisher': 'Doubleday publisher Doubleday',
#   'release_date': '1963',
#   'media_type': 'Print hardback',
#   'pages': '359 pp'},
#  'A Happy Death': {'name': 'A Happy Death',
#   'title_orig': 'La mort heureuse',
#   'image': 'File HappyDeath jpg',
#   'caption': 'Cover of the first edition',
#   'author': 'Albert Camus',
#   'country': 'France',
#   'language': 'French',
#   'genre': 'Existentialist Absurdism Absurdist',
#   'publisher': 'French Éditions Gallimard Gallimard English Alfred A Knopf Knopf',
#   'pub_date': '1971',
#   'english_pub_date': '1972',
#   'isbn': '0 679 76400 3',
#   'dewey': '843 914 20',
#   'congress': 'PQ2605 A3734 M613 1995',
#   'oclc': '33430967'},
#  "A Gathering of Days: A New England Girl's Journal": {'name': 'A Gathering of Days',
#   'image': 'A Gathering of Days jpg',
#   'caption': 'First edition',
#   'author': 'Joan Blos',
#   'cover_artist': 'Robert Papp',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Historical novel',
#   'published': '1979 Prentice Hall',
#   'media_type': 'Print hardback paperback',
#   'pages': '144',
#   'isbn': '978 0 684 16340 6',
#   'congress': 'PZ7 B6237 Gat',
#   'oclc': '5171140'},
#  'A Christmas Carol': {'name': 'A Christmas Carol',
#   'title_orig': 'A Christmas Carol In Prose Being a Ghost Story of Christmas',
#   'image': 'Charles Dickens A Christmas Carol Cloth First Edition 1843 jpg',
#   'alt': 'Brown book cover bearing the words A Christmas Carol by Charles Dickens in gold',
#   'caption': 'First edition cover 1843',
#   'author': 'Charles Dickens',
#   'illustrator': 'John Leech caricaturist John Leech',
#   'country': 'England',
#   'published': 'date and age 19 December 1843',
#   'publisher': 'Chapman Hall',
#   'wikisource': 'A Christmas Carol Dickens 1843'},
#  'A Hornbook for Witches': {'name': 'A Hornbook for Witches',
#   'image': 'Hornbook JPG',
#   'caption': 'Jacket illustration by Frank Utpatel for A Hornbook for Witches',
#   'author': 'Leah Bodine Drake',
#   'cover_artist': 'Frank Utpatel',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'poetry',
#   'publisher': 'Arkham House',
#   'release_date': '1950',
#   'media_type': 'Print Hardcover Hardback',
#   'pages': '70 pp'},
#  'A Heartbreaking Work of Staggering Genius': {'name': 'A Heartbreaking Work of Staggering Genius',
#   'image': 'Heartbreaking Work Dave Eggers jpg',
#   'caption': 'First edition',
#   'author': 'Dave Eggers',
#   'cover_artist': 'Komar and Melamid',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Memoir',
#   'publisher': 'Simon Schuster',
#   'pub_date': 'Start date 2000',
#   'media_type': 'Print paperback',
#   'pages': '375',
#   'isbn': '0 684 86347 2',
#   'oclc': '42667954',
#   'congress': 'CT275 E37 A3 2000'},
#  'A History of Fly Fishing for Trout': {'name': 'A History of Fly Fishing for Trout',
#   'image': 'AHistoryofFlyFishingForTrout JPG',
#   'caption': 'Title page',
#   'author': 'John Waller Hills',
#   'country': 'England',
#   'language': 'English',
#   'subject': 'Fly fishing',
#   'publisher': 'Phillip Allan Co London',
#   'pub_date': '1921',
#   'pages': '244',
#   'followed_by': 'A Summer on the Test 1925'},
#  'A House-Boat on the Styx': {'name': 'A House Boat on the Styx',
#   'image': 'File Scan of A House Boat on the Styx English cover jpg',
#   'caption': 'Front cover of the first edition',
#   'author': 'John Kendrick Bangs',
#   'illustrator': 'Peter Newell',
#   'country': 'United States',
#   'series': 'Associated Shades',
#   'genre': 'Fantasy fiction Fantasy short stories',
#   'publisher': 'Harper Brothers',
#   'pub_date': '1895',
#   'media_type': 'Print hardcover',
#   'pages': '171 pp',
#   'oclc': '859421539',
#   'congress': 'PS1064 B3 H6 1896',
#   'followed_by': 'The Pursuit of the House Boat'},
#  "A Doll's House": {'name': 'A Doll s House',
#   'image': 'A Doll s House jpeg',
#   'caption': 'Original manuscript cover page 1879',
#   'writer': 'Henrik Ibsen',
#   'characters': 'plainlist Nora Torvald Helmer Krogstad Mrs Linde Dr Rank Children Anne Marie Helene',
#   'setting': 'The home of the Helmer family in an unspecified Norwegian town or city circa 1879',
#   'premiere': 'Start date df y 1879 12 21',
#   'place': 'Royal Danish Theatre Royal Theatre in Copenhagen Denmark',
#   'orig_lang': 'Norwegian language Norwegian Danish language Danish',
#   'subject': 'The awakening of a middle class wife and mother',
#   'genre': 'Naturalism theatre Naturalistic Realism theatre realistic problem play Modern tragedy'},
#  'A Hunger Artist': {'name': 'A Hunger Artist',
#   'title_orig': 'Ein Hungerkünstler',
#   'translator': 'H Steinhauer and Helen Jessiman 1938 Edwin Muir Willa and Edwin Muir 1948',
#   'author': 'Franz Kafka',
#   'country': 'Germany written in Austria Hungary',
#   'language': 'German language German',
#   'genre': 'Short story',
#   'published_in': 'Neue Rundschau Die neue Rundschau',
#   'publication_type': 'periodical',
#   'pub_date': '1922',
#   'english_pub_date': '1938'},
#  'A House for Mr. Biswas': {'name': 'A House for Mr Biswas',
#   'image': 'HouseForMrBiswas jpg',
#   'caption': 'First edition cover',
#   'cover_artist': 'Stephen Russ',
#   'author': 'V S Naipaul',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'genre': 'Contemporary fiction',
#   'published': '1961',
#   'publisher': 'André Deutsch',
#   'media_type': 'Print'},
#  'A Journey in Other Worlds': {'name': 'A Journey in Other Worlds',
#   'author': 'John Jacob Astor IV',
#   'image': 'A Journey in Other Worlds 1 front cover jpg',
#   'illustrator': 'Daniel Carter Beard Dan Beard',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Science fiction Speculative fiction Utopian and dystopian fiction Utopian fiction',
#   'publisher': 'D Appleton Co',
#   'pub_date': '1894',
#   'media_type': 'Print hardcover',
#   'pages': '476 pp'},
#  'A Dance with Dragons': {'name': 'A Dance with Dragons',
#   'image': 'A Dance With Dragons US jpg',
#   'author': 'George R R Martin',
#   'audio_read_by': 'Roy Dotrice',
#   'cover_artist': 'Larry Rostant',
#   'country': 'United States',
#   'language': 'English',
#   'series': 'A Song of Ice and Fire',
#   'genre': 'Fantasy literature Fantasy',
#   'published': 'July 12 2011',
#   'publisher': 'Voyager Books UK Bantam Spectra US',
#   'media_type': 'Print hardback paperback',
#   'pages': '1016 US hardcover',
#   'award': 'Locus Award for Best Fantasy Novel 2012',
#   'isbn': '978 0553801477',
#   'isbn_note': '9780007456376 UK hardback',
#   'dewey': '813 54',
#   'congress': 'http lccn loc gov 2011015508 PS3563 A7239 D36 2011',
#   'oclc': '191922936',
#   'preceded_by': 'A Feast for Crows',
#   'followed_by': 'The Winds of Winter forthcoming'},
#  'A Man in Full': {'name': 'A Man in Full',
#   'image': 'Image Tommywolfie jpg',
#   'caption': 'First edition',
#   'author': 'Tom Wolfe',
#   'country': 'United States',
#   'language': 'English',
#   'publisher': 'Farrar Straus Giroux',
#   'release_date': 'November 12 1998',
#   'media_type': 'Print Hardback',
#   'pages': '742 pages',
#   'isbn': '0 374 27032 5',
#   'dewey': '813 54 21',
#   'congress': 'PS3573 O526 M26 1998',
#   'oclc': '39339625'},
#  'A Matter of Honour': {'name': 'A Matter of Honour',
#   'image': 'AMatterOfHonour jpg',
#   'caption': 'First edition',
#   'author': 'Jeffrey Archer',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'genre': 'Thriller genre Thriller Spy fiction',
#   'publisher': 'Hodder Stoughton',
#   'pub_date': '1 July 1986',
#   'media_type': 'Print Hardcover',
#   'pages': '350 pp',
#   'isbn': '0 340 39365 3'},
#  'A Man Called Ove (novel)': {'name': 'A Man Called Ove',
#   'title_orig': 'En man som heter Ove',
#   'translator': 'Henning Koch',
#   'image': 'A Man Called Ove novel jpg',
#   'caption': 'First edition Swedish',
#   'author': 'Fredrik Backman',
#   'country': 'Sweden',
#   'language': 'Swedish',
#   'genre': 'Novel',
#   'publisher': 'Bokförlaget Forum Forum Swedish',
#   'publisher2': 'Atria Publishing Group Atria Books English',
#   'pub_date': '27 August 2012',
#   'english_pub_date': '15 July 2014',
#   'media_type': 'Print',
#   'pages': '368 pp US 347 pp SWE',
#   'isbn': '9781476738024'},
#  'A Meeting at Corvallis': {'name': 'A Meeting at Corvallis',
#   'image': 'File A meeting at corvallis jpg',
#   'caption': 'First edition',
#   'author': 'S M Stirling',
#   'cover_artist': 'Larry Rostant',
#   'country': 'United States',
#   'language': 'English',
#   'series': 'The Emberverse series',
#   'genre': 'Science fiction',
#   'publisher': 'Roc Books',
#   'release_date': 'September 5 2006',
#   'media_type': 'Print hardback paperback',
#   'pages': '512',
#   'isbn': '0 451 46111 8',
#   'dewey': '813 54 22',
#   'congress': 'PS3569 T543 M44 2006',
#   'oclc': '63178922',
#   'preceded_by': 'The Protector s War',
#   'followed_by': 'The Sunrise Lands'},
#  'A Medicine for Melancholy': {'name': 'A Medicine for Melancholy',
#   'image': 'File Medicine for melancholy jpg',
#   'caption': 'Dust jacket illustration from the first edition',
#   'author': 'Ray Bradbury',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Soft science fiction',
#   'publisher': 'Doubleday Company',
#   'release_date': '1959 in literature 1959',
#   'media_type': 'Print hardback paperback',
#   'pages': '240',
#   'isbn': '0 380 73086 3',
#   'isbn_note': 'paperback reprint',
#   'oclc': '38229379'},
#  'A Maze of Death': {'name': 'A Maze of Death',
#   'image': 'File AMazeOfDeath 1stEd jpg',
#   'caption': 'Cover of first edition hardcover',
#   'author': 'Philip K Dick',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Science fiction',
#   'publisher': 'Doubleday publisher Doubleday',
#   'release_date': '1970',
#   'media_type': 'Print Hardcover Paperback',
#   'pages': '216'},
#  'A Manual of Style': {'name': 'The Chicago Manual of Style',
#   'image': 'The Chicago Manual of Style Seventeenth Edition jpg',
#   'caption': 'The Chicago Manual of Style 17th ed 2017',
#   'country': 'United States',
#   'language': 'English',
#   'subject': 'Style guide',
#   'publisher': 'University of Chicago Press',
#   'pub_date': '1906 2017',
#   'media_type': 'Print',
#   'pages': '1 146',
#   'isbn': '978 0 226 28705 8',
#   'dewey': '808 0270973',
#   'congress': 'Z253 U69 2017'},
#  'A Murder of Quality': {'name': 'A Murder of Quality',
#   'image': 'File AMurderOfQuality jpg',
#   'caption': 'First edition',
#   'author': 'John le Carré',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'series': 'George Smiley',
#   'genre': 'Mystery novel',
#   'publisher': 'Victor Gollancz Ltd Gollancz',
#   'release_date': '1962',
#   'media_type': 'Print Hardcover Hardback Paperback',
#   'preceded_by': 'Call for the Dead',
#   'followed_by': 'The Spy Who Came in from the Cold'},
#  'A Mysterious Affair of Style': {'name': 'A Mysterious Affair of Style',
#   'image': 'File Adair Style jpg',
#   'author': 'Gilbert Adair',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'genre': 'Mystery novel',
#   'publisher': 'Faber and Faber',
#   'release_date': '2007',
#   'pages': '292',
#   'isbn': '978 0 571 23425 7',
#   'dewey': '823 914 22',
#   'congress': 'PR6051 D287 M97 2007',
#   'oclc': '153556058',
#   'preceded_by': 'The Act of Roger Murgatroyd',
#   'followed_by': 'And Then There Was No One'},
#  'A New Earth': {'name': 'A New Earth Awakening to Your Life s Purpose',
#   'image': 'File A New Earth by Eckhart Tolle png',
#   'caption': 'First edition US',
#   'author': 'Eckhart Tolle',
#   'genre': 'Spirituality Psychology',
#   'publisher': 'Viking Press UK Dutton imprint Dutton US',
#   'pub_date': '2005',
#   'media_type': 'Print Audiobook',
#   'pages': '336',
#   'isbn': '0 452 28996 3',
#   'oclc': '191751630'},
#  'A Place So Foreign and Eight More': {'name': 'A Place So Foreign and Eight More',
#   'image': 'A Place So Foreign and Eight More jpg',
#   'author': 'Cory Doctorow',
#   'cover_artist': 'Jerry Engelbach',
#   'genre': 'Science fiction Short story Short stories',
#   'publisher': 'Four Walls Eight Windows',
#   'pub_date': '8 September 2003',
#   'pages': '352',
#   'isbn': '1568582862'},
#  'A Million Open Doors': {'name': 'A Million Open Doors',
#   'image': 'File A Million Open Doors cover art jpg',
#   'caption': 'First edition',
#   'author': 'John Barnes author John Barnes',
#   'cover_artist': 'John Harris artist John Harris',
#   'country': 'United States',
#   'language': 'English',
#   'series': 'John Barnes author Thousand Cultures series Thousand Cultures series',
#   'genre': 'Science fiction',
#   'publisher': 'Tor Books',
#   'release_date': 'October 1992',
#   'media_type': 'Print hardback paperback',
#   'isbn': '0 312 85210 X',
#   'dewey': '813 54 20',
#   'congress': 'PS3552 A677 M55 1992',
#   'oclc': '26217511',
#   'followed_by': 'Earth Made of Glass'},
#  'A Planet for the President': {'name': 'A Planet for the President',
#   'image': 'Image Planet President jpg',
#   'border': 'yes',
#   'author': 'Alistair Beaton',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Political novel Political Satire Dystopian novel',
#   'publisher': 'Weidenfeld Nicolson',
#   'release_date': '30 September 2004',
#   'media_type': 'Print Hardcover Hardback Paperback',
#   'pages': '256 pp hardback edition',
#   'isbn': '0 297 84776 7',
#   'isbn_note': 'hardback edition',
#   'oclc': '56658858'},
#  'A Night in the Lonesome October': {'name': 'A Night in the Lonesome October',
#   'image': 'File ANightInTheLonesomeOctober 1stEd jpg',
#   'caption': 'First edition hardcover',
#   'author': 'Roger Zelazny',
#   'illustrator': 'Gahan Wilson',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Fantasy',
#   'publisher': 'William Morrow and Company',
#   'release_date': '1993',
#   'media_type': 'Print hardback and paperback',
#   'pages': '280',
#   'isbn': '0 688 12508 5',
#   'dewey': '813 54 20',
#   'congress': 'PS3576 E43 N5 1993',
#   'oclc': '27640649'},
#  'A Perfect Spy': {'name': 'A Perfect Spy',
#   'image': 'File JohnLeCarre APerfectSpy jpg',
#   'caption': 'First UK edition',
#   'author': 'John le Carré',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'cover_artist': 'Howard J Shaw',
#   'genre': 'Spy novel',
#   'publisher': 'Hodder Stoughton UK Alfred A Knopf Alfred A Knopf Inc USA',
#   'release_date': '17 March 1986',
#   'media_type': 'Print hardback and paperback',
#   'pages': '475 pages Hardback edition 688 Paperback edition',
#   'isbn': '0 394 55141 9',
#   'isbn_note': 'Hardback edition 0671042750 Paperback edition',
#   'dewey': '823 914 19',
#   'congress': 'PR6062 E33 P47 1986',
#   'oclc': '13093947',
#   'preceded_by': 'The Little Drummer Girl',
#   'followed_by': 'The Russia House'},
#  'A Planet for Texans': {'name': 'A Planet for Texans',
#   'author': 'H Beam Piper and J J McGuire',
#   'image': 'File APlanetForTexans jpg',
#   'caption': 'First edition',
#   'cover_artist': 'Ed Emshwiller',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'science fiction novel',
#   'published': '1958 Ace Books',
#   'media_type': 'Print Paperback',
#   'pages': '101 pp Paperback edition',
#   'oclc': '4927510'},
#  'A Painted House': {'name': 'A Painted House',
#   'image': 'File A Painted House JPG',
#   'caption': 'First edition cover',
#   'author': 'John Grisham',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Thriller genre Thriller',
#   'publisher': 'Doubleday publisher Doubleday',
#   'release_date': 'February 6 2001',
#   'media_type': 'Print hardback paperback',
#   'pages': '388 pp',
#   'isbn': '0 385 50120 X',
#   'dewey': '813 54 21',
#   'congress': 'PS3557 R5355 P3 2001b',
#   'oclc': '301832819'},
#  'A Pocketful of Rye': {'name': 'A Pocketful of Rye',
#   'image': 'File Pocketful of Rye jpg',
#   'caption': 'First US edition',
#   'author': 'A J Cronin',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'publisher': 'Little Brown and Company',
#   'pub_date': '1969 June 1',
#   'media_type': 'Print Hardback',
#   'pages': '254 pp',
#   'isbn': '0 316 16175 6',
#   'preceded_by': 'A Song of Sixpence'},
#  'A Praed Street Dossier': {'name': 'A Praed Street Dossier',
#   'image': 'File Praed street dossier jpg',
#   'caption': 'Dust jacket illustration by Frank Utpatel for A Praed Street Dossier',
#   'author': 'August Derleth',
#   'illustrator': 'Frank Utpatel',
#   'cover_artist': 'Frank Utpatel',
#   'country': 'United States',
#   'language': 'English',
#   'series': 'Solar Pons',
#   'genre': 'Detective fiction Detective Science fiction essays',
#   'publisher': 'Mycroft Moran',
#   'release_date': '1968',
#   'media_type': 'Print hardback',
#   'pages': '108',
#   'preceded_by': 'The Casebook of Solar Pons',
#   'followed_by': 'Mr Fairlie s Final Journey'},
#  'A Planet Called Treason': {'name': 'A Planet Called Treason',
#   'image': 'A planet called treason jpg',
#   'caption': 'First edition',
#   'author': 'Orson Scott Card',
#   'cover_artist': 'Paul Stinson',
#   'genre': 'Science fiction',
#   'publisher': 'St Martin s Press',
#   'release_date': '1979 in literature 1979',
#   'media_type': 'Print Hardcover Paperback',
#   'pages': '256',
#   'isbn': '0 312 61395 4',
#   'dewey': '813 5 4',
#   'congress': 'PZ4 C258 Pl PS3553 A655',
#   'oclc': '4667520'},
#  'A Certain Magical Index': {'image': 'Toaru Majutsu no Index light novel cover vol 1 jpg',
#   'caption': 'Cover of the first volume featuring Index',
#   'ja_kanji': 'とある魔術の ruby 禁書目録 インデックス',
#   'ja_romaji': 'Toaru Majutsu no Indekkusu',
#   'genre': 'Action fiction Action science fantasy',
#   'creator': 'Kazuma Kamachi'},
#  'A Prophetic Romance': {'name': 'A Prophetic Romance',
#   'author': 'John McCoy as The Lord Commissioner',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Utopian and dystopian fiction Utopian fiction Speculative fiction Science fiction',
#   'publisher': 'Arena Publishing Co',
#   'pub_date': '1896 in literature 1896',
#   'media_type': 'Print Hardcover',
#   'pages': '283 pp'},
#  'A New Kind of Science (book)': {'name': 'A New Kind of Science',
#   'image': 'A new kind of science PNG',
#   'author': 'Stephen Wolfram',
#   'country': 'United States',
#   'language': 'English',
#   'subject': 'Complex systems',
#   'genre': 'Non fiction',
#   'publisher': 'Wolfram Media',
#   'pub_date': '2002',
#   'media_type': 'Print',
#   'pages': '1197 Hardcover',
#   'isbn': '1 57955 008 8',
#   'oclc': '856779719',
#   'website': 'http www wolframscience com nks A New Kind of Science online'},
#  'A Promise of Romance': {'genre': 'Yaoi'},
#  'A Moveable Feast': {'name': 'A Moveable Feast',
#   'image': 'Image MoveableFeast jpg',
#   'caption': 'First American edition',
#   'author': 'Ernest Hemingway',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Memoir Autobiography',
#   'publisher': 'Scribner s USA Jonathan Cape UK',
#   'release_date': '1964'},
#  'A Presumption of Death': {'name': 'A Presumption of Death',
#   'image': 'File APresumptionOfDeath jpg',
#   'caption': 'Early paperback edition cover',
#   'author': 'Jill Paton Walsh',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'series': 'Lord Peter Wimsey',
#   'genre': 'crime fiction Crime novel',
#   'publisher': 'Hodder Stoughton Hodder Stoughton Ltd',
#   'release_date': 'November 2002',
#   'media_type': 'Print hardback paperback',
#   'isbn': '0 340 82065 9',
#   'oclc': '59499647',
#   'preceded_by': 'Thrones Dominations',
#   'followed_by': 'The Attenbury Emeralds'},
#  'A Passage to India': {'name': 'A Passage to India',
#   'image': 'APassageToIndia jpg',
#   'caption': 'First edition UK',
#   'author': 'E M Forster',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'publisher': 'Edward Arnold publisher Edward Arnold UK Harcourt Brace US',
#   'release_date': '4 June 1924',
#   'media_type': 'Print hardback paperback',
#   'oclc': '59352597'},
#  'A Question of Upbringing': {'name': 'A Question of Upbringing',
#   'image': 'image AQuestionOfUpbringing jpg',
#   'caption': 'First edition UK',
#   'author': 'Anthony Powell',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'series': 'A Dance to the Music of Time',
#   'publisher': 'Heinemann book publisher Heinemann',
#   'pub_date': '1951',
#   'media_type': 'Print Hardcover',
#   'pages': '230 pp',
#   'followed_by': 'A Buyer s Market'},
#  'A Prison Diary': {'name': 'Belmarsh Hell',
#   'image': 'File APrisonDiary jpg',
#   'caption': 'First edition',
#   'author': 'Jeffrey Archer',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'genre': 'Autobiographical prison',
#   'publisher': 'Macmillan publisher Macmillan',
#   'english_pub_date': '2002',
#   'media_type': 'Print',
#   'pages': '272',
#   'isbn': '1 4050 2094 6',
#   'followed_by': 'Wayland Purgatory'},
#  'A Prayer for Owen Meany': {'name': 'A Prayer for Owen Meany',
#   'image': 'Image PrayerForOwenMeany JPG',
#   'caption': 'First edition',
#   'author': 'John Irving',
#   'cover_artist': 'Honi Werner',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Bildungsroman',
#   'publisher': 'William Morrow and Company William Morrow',
#   'release_date': 'March 1989',
#   'pages': '617',
#   'isbn': '0 688 07708 0',
#   'oclc': '18557147',
#   'preceded_by': 'The Cider House Rules',
#   'followed_by': 'A Son of the Circus'},
#  'A Rendezvous in Averoigne': {'name': 'A Rendezvous in Averoigne',
#   'image': 'File Rendezvous in averoigne jpg',
#   'caption': 'Dust jacket illustration by Jeffrey K Potter',
#   'author': 'Clark Ashton Smith',
#   'illustrator': 'Jeffrey K Potter',
#   'cover_artist': 'Jeffrey K Potter',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Science fiction Fantasy fiction Fantasy Horror fiction Horror',
#   'publisher': 'Arkham House',
#   'release_date': '1988',
#   'media_type': 'Print hardback',
#   'pages': 'x 472',
#   'isbn': '0 87054 156 0',
#   'dewey': '813 54 19',
#   'congress': 'PS3537 M335 A6 1988',
#   'oclc': '16870682'},
#  'A Purple Place For Dying': {'name': 'A Purple Place for Dying',
#   'image': 'APurplePlaceDying jpg',
#   'caption': 'First edition cover',
#   'author': 'John D MacDonald',
#   'country': 'United States',
#   'language': 'English',
#   'series': 'Travis McGee',
#   'genre': 'Mystery novel Mystery',
#   'publisher': 'Fawcett Publications',
#   'release_date': 'June 6 1964',
#   'media_type': 'Print paperback',
#   'pages': '158',
#   'isbn': '978 0 449 22438 0',
#   'oclc': '34612267',
#   'preceded_by': 'Nightmare in Pink',
#   'followed_by': 'The Quick Red Fox'},
#  'A Ring of Endless Light': {'name': 'A Ring of Endless Light',
#   'image': 'Ringendlesslight jpg',
#   'image_size': '250px',
#   'caption': 'A Ring of Endless Light first edition',
#   'author': 'Madeleine L Engle',
#   'cover_artist': 'Fred Marcellino hardback',
#   'country': 'United States',
#   'language': 'English',
#   'series': 'Austin family',
#   'subject': 'love death growing up',
#   'genre': 'Young adult novels Young Adult',
#   'publisher': 'Farrar Straus Giroux',
#   'release_date': '1980',
#   'media_type': 'Print hardback',
#   'pages': '324 pp',
#   'isbn': '0 374 36299 8',
#   'congress': 'PZ7 L5385 Ri 1980',
#   'oclc': '5894387',
#   'preceded_by': 'The Young Unicorns',
#   'followed_by': 'Troubling a Star'},
#  'A Portrait of the Artist as a Young Man': {'name': 'A Portrait of the Artist as a Young Man',
#   'author': 'James Joyce',
#   'language': 'English',
#   'set_in': 'Dublin and Clongowes Wood College c 1890s',
#   'genre': 'Künstlerroman literary modernism modernism',
#   'pages': '299',
#   'media_type': 'Print hardback',
#   'dewey': '823 912',
#   'congress': 'PR6019 O9',
#   'published': '29 December 1916',
#   'publisher': 'B W Huebsch',
#   'image': 'JamesJoyce Portrait1916 jpg',
#   'alt': 'A book cover It is entirely blue and has A Portrait of the Artist as a Young Man James Joyce embossed on it',
#   'caption': 'Front cover of the first edition published by B W Huebsch in 1916'},
#  'A Severed Head': {'name': 'A Severed Head',
#   'image': 'severed head jpg',
#   'caption': 'Cover',
#   'author': 'Iris Murdoch',
#   'cover_artist': 'Val Biro',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'publisher': 'Chatto and Windus',
#   'release_date': '1961',
#   'media_type': 'Print Hardcover and Paperback',
#   'pages': '251'},
#  'A Solitary Grief': {'name': 'A Solitary Grief',
#   'image': 'File ASolitaryGrief jpg',
#   'caption': 'First edition',
#   'author': 'Bernice Rubens',
#   'publisher': 'Sinclair Stevenson Ltd',
#   'pub_date': '6 May 1991',
#   'pages': '240',
#   'isbn': '978 1 85619 057 2'},
#  'A Single Shard': {'name': 'A Single Shard',
#   'image': 'image SingleShard jpg',
#   'border': 'yes',
#   'caption': 'First edition',
#   'author': 'Linda Sue Park',
#   'cover_artist': 'Jean and Mon sien Tseng',
#   'country': 'United States of America',
#   'language': 'English',
#   'genre': 'Historical novel',
#   'publisher': 'Clarion Books',
#   'release_date': 'April 23 2001',
#   'media_type': 'Print hardback paperback',
#   'pages': '148',
#   'isbn': '0 395 97827 0',
#   'congress': 'PZ7 P22115 Si 2001',
#   'oclc': '44803112'},
#  'A Room with a View': {'name': 'A Room with a View',
#   'image': 'A Room with a View jpg',
#   'caption': 'Cover of Penguin Essentials edition 2011',
#   'author': 'E M Forster',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'genre': 'Novel',
#   'publisher': 'Edward Arnold publisher Edward Arnold',
#   'pub_date': '1908',
#   'media_type': 'Print hardcover',
#   'pages': '321'},
#  'A Strange Manuscript Found in a Copper Cylinder': {'name': 'A Strange Manuscript Found in a Copper Cylinder',
#   'image': 'File Strange manuscript jpg',
#   'caption': 'Cover',
#   'author': 'James De Mille',
#   'country': 'Canada',
#   'language': 'English',
#   'genre': 'Fantasy novel',
#   'publisher': 'Harper Brothers',
#   'release_date': '1888',
#   'media_type': 'Print Hardcover Hardback',
#   'pages': '291 pp',
#   'isbn': '978 1515037941'},
#  'A Shade of Difference': {'name': 'A Shade of Difference',
#   'image': 'AShadeOfDifference jpg',
#   'caption': 'First edition',
#   'author': 'Allen Drury',
# ...
#   'country': 'Germany',
#   'language': 'German',
#   'genre': 'Autobiographical novel erotic novel',
#   'publisher': 'M DuMont Schauberg',
#   'release_date': '2009',
#   'media_type': 'Print Hardcover hardback audiobook',
#   'pages': '220',
#   'isbn': '978 3 8321 8057 7',
#   'oclc': '213398233'},
#  'Ficciones': {'name': 'Fictions',
#   'title_orig': 'Ficciones',
#   'translator': 'various',
#   'image': 'image Ficciones jpg',
#   'caption': 'First edition',
#   'author': 'Jorge Luis Borges',
#   'country': 'Argentina',
#   'language': 'Spanish',
#   'publisher': 'Editorial Sur 1944 Emecé Editores Emecé 1956',
#   'pub_date': '1941 2 1944 1956',
#   'english_pub_date': '1962 by Grove Press',
#   'media_type': 'Print',
#   'pages': '203pp 1944 197pp 1956'},
#  'Fifty Shades Freed': {'name': 'Fifty Shades Freed',
#   'image': 'Fifty_Shades_Freed_book_cover png',
#   'author': 'E L James',
#   'cover_artist': 'Isaiah Ogasawara',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'series': 'Fifty Shades novel series Fifty Shades trilogy',
#   'genre': 'Erotic romance novels Erotic romance',
#   'published': '17 April 2012 Vintage Books UK 26 April 2012 Arrow Books',
#   'media_type': 'Print Hardcover Paperback',
#   'pages': '592',
#   'isbn': '0345803507',
#   'preceded_by': 'Fifty Shades Darker',
#   'followed_by': 'Grey Fifty Shades of Grey as Told by Christian'},
#  'Fifty Shades Darker': {'name': 'Fifty Shades Darker',
#   'image': 'Fifty Shades Darker book cover jpg',
#   'caption': '2012 paperback cover',
#   'author': 'E L James',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'series': 'Fifty Shades novel series Fifty Shades trilogy',
#   'genre': 'Erotic romance novels Erotic romance',
#   'published': '17 April 2012 Vintage Books',
#   'media_type': 'Print Hardcover Paperback',
#   'pages': '544',
#   'isbn': '978 0 34580349 8',
#   'preceded_by': 'Fifty Shades of Grey',
#   'followed_by': 'Fifty Shades Freed'},
#  'Ezra Pound': {'width': '350px',
#   'align': 'right',
#   'bgcolor': 'FFF8E7',
#   'salign': 'right',
#   'style': 'padding 1 30em',
#   'fontsize': '94',
#   'title': 'In Durance',
#   'source': 'nbsp Personae of Ezra Pound 1909 written in Crawfordsville Indiana 1907'},
#  'Fine Things': {'name': 'Fine Things',
#   'image': 'Fine_things_cover jpg',
#   'caption': 'First edition',
#   'author': 'Danielle Steel',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Romance novel',
#   'publisher': 'Delacorte Press',
#   'pub_date': 'February 1 1987',
#   'media_type': 'Print Hardcover Hardback Paperback',
#   'pages': '432 pp',
#   'isbn': '0 440 20056 3',
#   'oclc': '17609637'},
#  'Fences (play)': {'name': 'Fences',
#   'image': 'Fences August Wilson play script cover jpg',
#   'image_size': '150px',
#   'writer': 'August Wilson',
#   'characters': 'Troy Maxson Rose Maxson Cory Maxson Jim Bono Gabriel Maxson Lyons Maxson Raynell Maxson',
#   'setting': '1957 in a backyard of a house in Pittsburgh Pennsylvania',
#   'premiere': '1985',
#   'place': 'Eugene O Neill Theater Center Waterford Connecticut',
#   'orig_lang': 'English',
#   'genre': 'Drama Fiction',
#   'subject': 'A Negro baseball league player is now a garbageman his bitterness affects his loved ones',
#   'series': 'The Pittsburgh Cycle'},
#  'Fire and Sleet and Candlelight': {'name': 'Fire and Sleet and Candlelight',
#   'image': 'Fire and sleet and candlelight jpg',
#   'image_size': '200px',
#   'caption': 'Dust jacket illustration by Gary Gore for Fire and Sleet and Candlelight',
#   'author': 'edited by August Derleth',
#   'cover_artist': 'Gary Gore',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'fantasy horror fiction horror speculative poetry',
#   'publisher': 'Arkham House',
#   'release_date': '1961',
#   'media_type': 'Print Hardcover Hardback',
#   'pages': 'xix 236 pp'},
#  'FLCL': {'image': 'FLCL image jpg',
#   'caption': 'Promotional artwork used on a number of DVD releases of FLCL featuring the three primary characters from the anime from top Canti the blue robot Haruko and Naota',
#   'ja_kanji': 'フリクリ',
#   'ja_romaji': 'Furi Kuri',
#   'genre': 'ubl Comedy ref cite web last Beveridge first Chris title FLCL Lands at FUNimation url http www mania com flcl lands funimation_article_119796 html website Mania com access date January 8 2020 archive url https web archive org web 20100109034507 http www mania com flcl lands funimation_article_119796 html archive date January 9 2010 date January 6 2010 quote The series from Gainax is six episodes long and set the stage for part of Gainax s revival earlier in the decade with a perfect blend of comedy action and surreal visuals and designs Science fiction ref cite web title FLCL and I m Gonna Be An Angel Acquisition Announcement url https www animenewsnetwork com news 2001 03 30 flcl and i m gonna be an angel acquisition announcement website Anime News Network access date January 8 2020 date March 30 2001 quote FLCL is the wacky sci fi OAV series from GAINAX archive date April 1 2020 archive url https web archive org web 20200401110151 https www animenewsnetwork com news 2001 03 30 flcl and i m gonna be an angel acquisition announcement url status live Surrealism ref cite web last Green first Jason title Dig For Fire The Roots of Gurren Lagann url https www animenewsnetwork com feature 2008 09 07 website Anime News Network access date January 8 2020 date September 7 2008 quote He rose to the rank of animation director for 2000 s surrealist six part OAV FLCL an Adult Swim mainstay under the title Fooly Cooly archive date October 24 2019 archive url https web archive org web 20191024081001 https www animenewsnetwork com feature 2008 09 07 url status live',
#   'creator': 'ubl Gainax FLCL efn name original work nihongo Original Work 原作 Kazuya Tsurumaki FLCL efn nihongo Original Plan 原案 Production I G FLCL Progressive Alternative efn name original work efn name original work nihongo Original Work 原作 nihongo Original Work 原作 efn nihongo Original Plan 原案 nihongo Original Plan 原案 efn name original work'},
#  'Five Against Venus': {'name': 'Five Against Venus',
#   'image': 'Five Against Venus jpg',
#   'caption': 'First edition cover',
#   'author': 'Philip Latham',
#   'illustrator': 'Alex Schomburg endpapers',
#   'cover_artist': 'Virgil Finlay',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'science fiction novel',
#   'published': 'April 14 1952',
#   'publisher': 'John C Winston Company',
#   'media_type': 'Print hardcover',
#   'pages': 'vii 214',
#   'oclc': '1374703'},
#  'Five Days In Paris': {'name': 'Five Days In Paris',
#   'image': 'File Five Days in Paris book cover jpg',
#   'caption': 'First edition',
#   'author': 'Danielle Steel',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Romance novel',
#   'publisher': 'Delacorte Press',
#   'pub_date': '1995',
#   'media_type': 'Print Hardcover Hardback Paperback',
#   'pages': '269 pp',
#   'isbn': '0 385 31530 9',
#   'dewey': '813 54 20',
#   'congress': 'PS3569 T33828 F54 1995',
#   'oclc': '32546750'},
#  'Five Children and It': {'name': 'Five Children and It',
#   'image': 'File Five Children and It novel 1st ed jpg',
#   'caption': 'First edition',
#   'author': 'Edith Nesbit',
#   'illustrator': 'H R Millar',
#   'country': 'United Kingdom',
#   'language': 'English language English',
#   'series': 'Psammead Trilogy',
#   'genre': 'Fantasy genre Fantasy',
#   'publisher': 'T Fisher Unwin',
#   'release_date': '1902',
#   'media_type': 'Print',
#   'oclc': '4378896',
#   'followed_by': 'The Phoenix and the Carpet'},
#  'Fingersmith (novel)': {'name': 'Fingersmith',
#   'image': 'Image Fingersmithcover jpg',
#   'caption': 'First edition',
#   'author': 'Sarah Waters',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'genre': 'Crime novel historical fiction gothic fiction',
#   'publisher': 'Virago Press',
#   'release_date': '4 February 2002',
#   'media_type': 'Print Hardcover Hardback paperback',
#   'pages': '511 pp',
#   'isbn': '1 86049 882 5',
#   'oclc': '48235549'},
#  'Five Quarters of the Orange': {'name': 'Five Quarters of the Orange',
#   'image': '5 quarters orange jpg',
#   'image_size': '200px',
#   'caption': 'First edition cover',
#   'author': 'Joanne Harris',
#   'cover_artist': 'Stuart Haygarth',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'genre': 'Historical fiction',
#   'publisher': 'Doubleday publisher Doubleday',
#   'release_date': '2001',
#   'media_type': 'Print Hardcover Hardback Paperback',
#   'pages': '307 pp',
#   'isbn': '0 552 99883 4',
#   'oclc': '48026119',
#   'preceded_by': 'Blackberry Wine'},
#  'First Man: The Life of Neil A. Armstrong': {'name': 'First Man The Life of Neil A Armstrong',
#   'image': 'FirstManCover jpg',
#   'image_size': '200px',
#   'caption': 'Cover of First Man The Life of Neil A Armstrong',
#   'author': 'James R Hansen',
#   'country': 'United States',
#   'language': 'English',
#   'subject': 'Neil A Armstrong',
#   'publisher': 'Simon Schuster',
#   'release_date': '2005',
#   'media_type': 'Print',
#   'pages': '768 pp',
#   'isbn': '0 7432 5631 X',
#   'dewey': '629 45 0092 B 22',
#   'congress': 'TL789 85 A75 H36 2005',
#   'oclc': '60743246'},
#  'Fifty Shades of Grey': {'name': 'Fifty Shades of Grey',
#   'image': '50ShadesofGreyCoverArt jpg',
#   'caption': 'First edition',
#   'author': 'E L James',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'series': 'Fifty Shades trilogy Fifty Shades trilogy',
#   'genre': 'Romance novels romance',
#   'published': '20 June 2011 self published',
#   'media_type': 'Print Hardcover paperback',
#   'pages': '514',
#   'isbn': '978 1 61213 028 6',
#   'oclc': '780307033',
#   'followed_by': 'Fifty Shades Darker',
#   'publisher': 'Vintage Books'},
#  'Fifty Shades trilogy': {'name': 'Fifty Shades',
#   'image': 'Fifty Shades triology paperback cover jpg',
#   'caption': 'Trilogy pack set',
#   'books': 'Fifty Shades of Grey Fifty Shades Darker Fifty Shades Freed Grey Fifty Shades of Grey as Told by Christian Grey Darker Fifty Shades Darker as Told by Christian Darker Freed Fifty Shades Freed as Told by Christian Freed',
#   'author': 'E L James',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'genre': 'Erotic romance',
#   'publisher': 'Vintage Books',
#   'pub_date': '2011 2021',
#   'media_type': 'Print Paperback'},
#  'Five Point Someone': {'name': 'Five Point Someone What not to do at IIT',
#   'author': 'Chetan Bhagat',
#   'country': 'India',
#   'genre': 'Fiction Buddy film Buddy',
#   'publisher': 'Rupa Co',
#   'isbn': '81 291 0459 8',
#   'image': 'Five Point Someone What not to do at IIT jpg',
#   'caption': 'First edition',
#   'release_date': '4 August 2004',
#   'pages': '270',
#   'media_type': 'Paperback'},
#  'Flesh and Fire': {'name': 'Flesh and Fire',
#   'image': 'Flesh and Fire Book Cover png',
#   'image_size': '200px',
#   'alt': 'A young man with long hair holding fire with a village and vineyards in the background',
#   'caption': 'Cover of Flesh and Fire by Chris McGrath',
#   'author': 'Laura Anne Gilman',
#   'cover_artist': 'Chris Mc Grath',
#   'country': 'United States',
#   'language': 'English',
#   'series': 'The Vineart War',
#   'genre': 'young adult fiction Young adult Fantasy novel',
#   'publisher': 'Pocket Books',
#   'release_date': 'October 2009',
#   'media_type': 'Print hardcover',
#   'pages': '374',
#   'isbn': '978 1 4391 9154 5',
#   'congress': 'PS3557 I4545F54 2009',
#   'followed_by': 'Weight of Stone'},
#  'Flare (science fiction novel)': {'name': 'Flare',
#   'image': 'Flare sf novel jpg',
#   'image_size': '200px',
#   'caption': 'Cover illustration from the first edition',
#   'author': 'Roger Zelazny and Thomas Thurston Thomas',
#   'cover_artist': 'Dean Morrissey',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Science fiction',
#   'publisher': 'Baen Books',
#   'release_date': 'September 1992',
#   'media_type': 'Print paperback',
#   'pages': '344',
#   'isbn': '0 671 72133 X',
#   'oclc': '26429687'},
#  'Flaws in the Glass': {'name': 'Flaws in the Glass a self portrait',
#   'image': 'File FlawsInTheGlass jpg',
#   'caption': 'First edition',
#   'author': 'Patrick White',
#   'country': 'Australia',
#   'language': 'English',
#   'genre': 'Autobiographical',
#   'publisher': 'Jonathan Cape',
#   'release_date': '1981',
#   'media_type': 'Print hardback paperback',
#   'pages': '260 pp',
#   'isbn': '0 14 006293 9'},
#  'First Men in the Moon': {'name': 'The First Men in the Moon',
#   'image': 'File TheFirstMenInTheMoonHGWells jpg',
#   'caption': 'First US edition',
#   'author': 'H G Wells',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'genre': 'Science fiction',
#   'published': '1901',
#   'publisher': 'George Newnes Ltd George Newnes UK Bowen Merrill US',
#   'media_type': 'Print hardcover',
#   'pages': '342',
#   'oclc': '655463',
#   'wikisource': 'The First Men in the Moon'},
#  'Floodtide': {'name': 'Floodtide',
#   'image': 'Floodtide _ 1949 jpg',
#   'caption': 'Original pressbook',
#   'director': 'Frederick Wilson film editor Frederick Wilson',
#   'producer': 'Donald B Wilson',
#   'writer': 'ubl George Blake Donald B Wilson Frederick Wilson',
#   'starring': 'ubl Gordon Jackson actor Gordon Jackson Rona Anderson John Laurie Jimmy Logan',
#   'music': 'Robert Irving conductor Robert Irving',
#   'cinematography': 'George Stretton',
#   'editing': 'Peter Bezencenet',
#   'studio': 'Aquila Film',
#   'distributor': 'General Film Distributors UK',
#   'released': '15 March 1949 London UK',
#   'runtime': '90 min',
#   'country': 'United Kingdom',
#   'language': 'English language English'},
#  'Fledgling (novel)': {'name': 'Fledgling',
#   'image': 'File Butler_Fledgling_cover_art jpg',
#   'caption': 'Paperback cover of Fledgling',
#   'author': 'Octavia Butler',
#   'cover_artist': 'Jon Gilbert',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Science fiction novel',
#   'publisher': 'Jane Langton',
#   'release_date': '8 September 2005',
#   'media_type': 'Print Hardcover Hardback',
#   'pages': '352 hardcover first edition',
#   'isbn': '1 58322 690 7',
#   'isbn_note': 'hardcover first edition',
#   'dewey': '813 54 22',
#   'congress': 'PS3552 U827 F47 2005',
#   'oclc': '58055361'},
#  "Flaubert's Parrot": {'name': 'Flaubert s Parrot',
#   'image': 'File FlaubertsParrot jpg',
#   'border': 'yes',
#   'caption': 'First edition cover',
#   'author': 'Julian Barnes',
#   'country': 'England',
#   'language': 'English',
#   'publisher': 'Jonathan Cape',
#   'release_date': '1984',
#   'media_type': 'Print Hardcover',
#   'pages': '190 pp',
#   'isbn': '0 7475 1347 3',
#   'oclc': '27415629'},
#  'Floating Flies and How to Dress Them': {'name': 'Floating Flies and How to Dress Them',
#   'image': 'FloatingFliesandHowToDressThem JPG',
#   'author': 'Frederic M Halford',
#   'country': 'England',
#   'language': 'English',
#   'subject': 'Fly fishing',
#   'publisher': 'Sampson Low Marston Searle and Rivington London',
#   'pub_date': 'April 1886',
#   'pages': '136',
#   'followed_by': 'Dry Fly Fishing in Theory and Practice 1889'},
#  'Fool on the Hill (novel)': {'name': 'Fool on the Hill',
#   'image': 'MattRuff FoolOnTheHill AtlanticMonthlyPress jpg',
#   'image_size': '200px',
#   'caption': 'first US hardcover edition',
#   'author': 'Matt Ruff',
#   'cover_artist': 'original jacket illustration by Andrew Paquette design by Chip Kidd',
#   'country': 'United States',
#   'language': 'English language English',
#   'genre': 'Fantasy',
#   'publisher': 'The Atlantic Monthly Press',
#   'release_date': '1988',
#   'media_type': 'Print',
#   'pages': '396',
#   'isbn': '0 87113 243 5',
#   'followed_by': 'Sewer Gas Electric'},
#  'Fludd (novel)': {'name': 'Fludd',
#   'image': 'Image Fludd jpg',
#   'caption': 'First edition',
#   'author': 'Hilary Mantel',
#   'cover_artist': 'Russell Ayto',
#   'country': 'United Kingdom',
#   'language': 'English',
#   'publisher': 'Viking Press',
#   'release_date': '1989',
#   'media_type': 'Print eBook',
#   'pages': '192',
#   'isbn': '0 670 82118 7'},
#  'Flush (novel)': {'image': 'FlushNovel jpg',
#   'caption': 'First edition cover',
#   'author': 'Carl Hiaasen',
#   'country': 'United States',
#   'language': 'English',
#   'genre': 'Realistic Fiction',
#   'published': '13 Sep 2005 Alfred A Knopf',
#   'media_type': 'Print book',
#   'pages': '263',
#   'isbn': '0 375 92182 6',
#   'oclc': '53393228'},
#  ...}

# %%
tmp = nl_infoboxes.copy()
for k, v in tmp.items():
    if not v:
        nl_infoboxes.pop(k)
    elif type(v) == dict:
        for k1, v1 in v.items():
            nl_infoboxes[k][k1] = unpack_iterables(v1)
nl_infoboxes
# Out:
# {'A Certain Smile': {'titel': 'A Certain Smile Als een verre glimlach',
#   'regie': 'Jean Negulesco',
#   'producer': 'Henry Ephron',
#   'schrijver': 'Frances Goodrich Albert Hackett Françoise Sagan roman',
#   'spelers': 'Rossano Brazzi Joan Fontaine Bradford Dillman',
#   'muziek': 'Alfred Newman',
#   'montage': 'Louis R Loeffler',
#   'cinematografie': 'Milton R Krasner',
#   'distributeur': '20th Century Fox',
#   'première': '22 september 1958',
#   'genre': 'Drama',
#   'lengte': '104 minuten',
#   'taal': 'Engels',
#   'land': 'US',
#   'budget': '2 300 000',
#   'opbrengst': '1 300 000',
#   'imdb': '0051466',
#   'moviemeter': '48099'},
#  "A Clergyman's Daughter": {'naam': 'De domineesdochter',
#   'orig titel': 'A Clergyman s Daughter',
#   'auteur': 'George Orwell',
#   'vertaler': 'Elizabeth Stortenbeker',
#   'land': 'Engeland',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'uitgever': 'Meulenhoff',
#   'uitgiftedatum origineel': '1935',
#   'paginas': '302',
#   'isbn': '90 290 0373 1'},
#  'A Case of Conscience': {'naam': 'De goddeloze tuin van Eden',
#   'afbeelding': 'Cover If 195309 jpg',
#   'onderschrift': 'A Case of Conscience omslag eerste uitgave',
#   'auteur': 'James Blish',
#   'vertaler': 'Cornelis Andries Gerardus van den Broek',
#   'kaftontwerp': 'Alex Jagtenberg Studio Lemaire',
#   'land': 'US',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'reeks': 'Born SF',
#   'genre': 'Sciencefiction',
#   'uitgever': 'Born',
#   'originele uitgever': 'Ballantine Books',
#   'uitgiftedatum': '1969',
#   'uitgiftedatum origineel': '1958',
#   'paginas': '190',
#   'grootte': '190 mm',
#   'vervolg': 'After Such Knowledge',
#   'vorigeboek': '',
#   'volgendeboek': 'Doctor Mirabilis',
#   'extra portaal': 'Sciencefiction'},
#  '2010: Odyssey Two': {'naam': '2010 Odyssey Two',
#   'auteur': 'Arthur C Clarke',
#   'land': 'UK',
#   'genre': 'Sciencefiction',
#   'uitgiftedatum': '1982',
#   'film': '2010 The Year We Make Contact',
#   'voorafgegaan': '2001 A Space Odyssey 2061 Odyssey Three',
#   'vervolg': '3001 The Final Odyssey'},
#  'A Brief History of Time': {'naam': 'Het heelal',
#   'orig titel': 'A Brief History of Time',
#   'vertaler': 'Ronald Jonkers',
#   'auteur': 'Stephen Hawking',
#   'taal': 'Nederlands',
#   'onderwerp': 'Kosmologie Theoretische natuurkunde',
#   'genre': 'Populaire wetenschap Populairwetenschappelijk',
#   'uitgever': 'Bert Bakker uitgeverij Bert Bakker',
#   'uitgiftedatum': '1988',
#   'paginas': '231',
#   'isbn': '90 351 0611 3',
#   'portaal': 'Astronomie'},
#  '11/22/63': {'naam': '22 11 1963',
#   'cover-op-enwp': '11 22 63 jpg',
#   'orig titel': '11 22 63',
#   'auteur': 'Stephen King schrijver Stephen King',
#   'vertaler': 'Hugo Kuipers',
#   'kaftontwerp': 'DPS Davy van der Elsken',
#   'land': 'Verenigde Staten',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'onderwerp': 'Moord op de Amerikaanse president John F Kennedy',
#   'genre': 'Sciencefiction Amerikaanse geschiedenis drama',
#   'uitgever': 'Uitgeverij Luitingh Sijthoff B V Amsterdam',
#   'originele uitgever': 'Scribner',
#   'uitgiftedatum': 'november 2011',
#   'uitgiftedatum origineel': '8 november 2011',
#   'paginas': '879',
#   'isbn': '978 90 245 3362 6',
#   'film': '11 22 63 miniserie 2016'},
#  'A Crown of Swords': {'naam': 'Een Kroon van Zwaarden',
#   'reeks': 'Het Rad des Tijds',
#   'auteur': 'Robert Jordan auteur Robert Jordan',
#   'vertaler': 'Jo Thomas Johan Martijn Flaton',
#   'uitgever': 'Luitingh Sijthoff',
#   'originele uitgever': 'Tor Books',
#   'orig titel': 'Crown of Swords',
#   'uitgiftedatum': '1998',
#   'uitgiftedatum origineel': '15 mei 1996',
#   'genre': 'Fantasy genre Fantasy',
#   'paginas': '704 blz',
#   'isbn': '9024512689',
#   'voorafgegaan': 'Heer van Chaos',
#   'vervolg': 'Het Pad der Dolken'},
#  'A Clockwork Orange (novel)': {'naam': 'A Clockwork Orange',
#   'afbeelding': 'A_CLOCKWORK_ORANGE jpg',
#   'auteur': 'Anthony Burgess',
#   'land': 'Verenigd Koninkrijk',
#   'taal': 'Engels Nadsat',
#   'genre': 'Toekomstroman satire',
#   'uitgever': 'Heinemann VK',
#   'uitgiftedatum': '1962',
#   'paginas': '192',
#   'isbn': '0434098000',
#   'film': 'A Clockwork Orange film A Clockwork Orange'},
#  '1Q84': {'naam': '1Q84',
#   'vertaler': 'Jacques Westerhoven',
#   'auteur': 'Haruki Murakami',
#   'land': 'Japan',
#   'taal': 'Japans',
#   'genre': 'Roman literatuur Roman',
#   'uitgever': 'Shinchosha',
#   'uitgiftedatum': '29 mei 2009',
#   'medium': 'Boek'},
#  'A Course in Miracles': {'naam': 'Een Cursus in Wonderen',
#   'orig titel': 'A Course in Miracles',
#   'vertaler': 'Willem Glaudemans Kaja van Grieken Bob Hermans Koos Janson Thilly Mercier William Moons Gertje van Ramshorst',
#   'auteur': 'Niet met zekerheid vastgesteld maar op schrift gezet door Helen Schucman en William Thetford',
#   'land': 'Verenigde Staten',
#   'taal': 'Nederlands',
#   'onderwerp': 'Persoonlijke spirituele ontwikkeling',
#   'genre': 'Spiritualiteit',
#   'uitgever': 'The Foundation for Inner Peace Nederlands taalgebied Uitgeverij Ankh Hermes',
#   'uitgiftedatum': '1975',
#   'medium': 'Hardcover',
#   'paginas': '1342',
#   'isbn': '978 90 202 11641 gebonden dundrukuitgave'},
#  'A Confederacy of Dunces': {'naam': 'Een samenzwering van idioten',
#   'orig titel': 'A Confederacy of Dunces',
#   'auteur': 'John Kennedy Toole',
#   'vertaler': 'Paul Syrier',
#   'land': 'Verenigde Staten',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'uitgever': 'Lebowski',
#   'originele uitgever': 'Louisiana State University Press',
#   'uitgiftedatum': '2011',
#   'uitgiftedatum origineel': '1980',
#   'isbn': '978 90 488 0828 1'},
#  'A Fall of Moondust': {'naam': 'Scheepsramp op de maan',
#   'orig titel': 'A Fall of Moondust',
#   'auteur': 'Arthur C Clarke',
#   'vertaler': 'B H Staal',
#   'land': 'Engeland',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'reeks': 'Prisma P955',
#   'genre': 'sciencefiction',
#   'uitgever': 'Het Spectrum',
#   'originele uitgever': 'Victor Gollancz Ltd',
#   'uitgiftedatum': '1964',
#   'uitgiftedatum origineel': '1961',
#   'medium': 'pocketboek',
#   'paginas': '192',
#   'extra portaal': 'Sciencefiction'},
#  'A Fighting Man of Mars': {'naam': 'A Fighting Man of Mars',
#   'auteur': 'Edgar Rice Burroughs',
#   'land': 'Verenigde Staten',
#   'taal': 'Engels',
#   'reeks': 'Barsoom',
#   'genre': 'Science fantasy',
#   'uitgever': 'Metropolitan Books',
#   'uitgiftedatum': '1931',
#   'medium': 'Print',
#   'paginas': '319',
#   'vorigeboek': 'The Master Mind of Mars',
#   'volgendeboek': 'Swords of Mars',
#   'extra portaal': 'Sciencefiction'},
#  'A Christmas Carol': {'naam': 'A Christmas Carol',
#   'orig titel': 'A Christmas Carol in Prose Being a Ghost Story of Christmas',
#   'afbeelding': 'Charles Dickens A Christmas Carol Title page First edition 1843 jpg',
#   'auteur': 'Charles Dickens',
#   'land': 'Verenigd Koninkrijk',
#   'taal': 'Engels',
#   'genre': 'Kerstmis spookverhaal',
#   'uitgever': 'Chapman Hall',
#   'uitgiftedatum': '19 december 1843'},
#  "A Doll's House": {'naam': 'Et Dukkehjem Een poppenhuis',
#   'afbeelding': 'A_Doll s_House jpeg',
#   'onderschrift': 'Titelpagina manuscript 1879',
#   'schrijver': 'Henrik Ibsen',
#   'taal': 'Noors',
#   'nederlandse vertaling door': 'Margaretha Meijboom',
#   'eerste opvoering datum': '21 december 1879',
#   'eerste opvoering waar': 'Kopenhagen',
#   'eerste opvoering NL': '1906',
#   'soort': 'Tendensroman'},
#  'A Dance with Dragons': {'naam': 'Een dans met draken',
#   'reeks': 'Het lied van ijs en vuur',
#   'auteur': 'George R R Martin',
#   'vertaler': 'Renée Vink',
#   'uitgever': 'Luitingh Sijthoff',
#   'orig titel': 'A Dance with Dragons',
#   'genre': 'High fantasy',
#   'voorafgegaan': 'Een feestmaal voor kraaien'},
#  'A Moveable Feast': {'naam': 'A Moveable Feast',
#   'afbeelding': 'GertrudeStein JackHemingway Paris jpg',
#   'onderschrift': 'Gertrude Stein met Jack Hemingway in Parijs',
#   'auteur': 'Ernest Hemingway',
#   'land': 'US',
#   'originele taal': 'Engels',
#   'genre': 'biografie',
#   'originele uitgever': 'Scribner s',
#   'uitgiftedatum origineel': '1964',
#   'paginas': '211',
#   'grootte': '22 cm'},
#  'A Passage to India': {'titel': 'A Passage to India',
#   'regie': 'David Lean',
#   'producer': 'John Brabourne Richard B Goodwin',
#   'schrijver': 'David Lean',
#   'spelers': 'Judy Davis Victor Banerjee Peggy Ashcroft James Fox acteur James Fox Alec Guinness',
#   'muziek': 'Maurice Jarre',
#   'montage': 'David Lean',
#   'cinematografie': 'Ernest Day',
#   'distributeur': 'Columbia Pictures',
#   'première': '14 december 1984',
#   'lengte': '163 minuten',
#   'taal': 'Engels',
#   'land': 'UK US',
#   'opbrengst': '27 187 653 VS',
#   'imdb': '0087892',
#   'moviemeter': '2806',
#   'montager': 'David Lean',
#   'studio': 'Thorn EMI HBO',
#   'duur': '163 minuten'},
#  'A Prayer for Owen Meany': {'naam': 'Bidden wij voor Owen Meany',
#   'orig titel': 'A Prayer for Owen Meany',
#   'auteur': 'John Irving',
#   'vertaler': 'Cornelis Andries Gerardus van den Broek C A G van den Broek',
#   'land': 'Verenigde Staten',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'genre': 'Roman literatuur Roman',
#   'uitgever': 'De Bezige Bij',
#   'uitgiftedatum': '2012',
#   'uitgiftedatum origineel': '1989',
#   'isbn': '978 90 234 3859 5',
#   'film': 'Simon Birch 1998'},
#  'A Ring of Endless Light': {'titel': 'A Ring of Endless Light',
#   'regie': 'Greg Beeman',
#   'producer': 'Greg Beeman',
#   'schrijver': 'Marita Giovanni Bruce Graham Madeleine L Engle roman',
#   'spelers': 'Mischa Barton Ryan Merriman',
#   'distributeur': 'Disney Channel',
#   'première': '23 augustus 2002 VS 26 februari 2005 NL',
#   'muziek': 'Phil Marshall als Philip Marshall',
#   'cinematografie': 'Rodney Charters',
#   'genre': 'Drama',
#   'lengte': '88 minuten',
#   'taal': 'Engels',
#   'land': 'US',
#   'imdb': '0282123',
#   'moviemeter': '22452'},
#  'A Room with a View': {'titel': 'A Room with a View Kamer met uitzicht',
#   'regie': 'James Ivory regisseur James Ivory',
#   'producer': 'Ismail Merchant',
#   'schrijver': 'Ruth Prawer Jhabvala',
#   'spelers': 'Helena Bonham Carter Julian Sands',
#   'muziek': 'Richard Robbins',
#   'montage': 'Humphrey Dixon',
#   'cinematografie': 'Tony Pierce Roberts',
#   'distributeur': 'Curzon',
#   'première': '13 december 1985',
#   'genre': 'Romantische komedie',
#   'lengte': '117 minuten',
#   'taal': 'Engels',
#   'land': 'GB',
#   'budget': '3 000 000',
#   'opbrengst': '20 966 644',
#   'imdb': '0091867',
#   'moviemeter': '891'},
#  'A Shock to the System (1990 film)': {'titel': 'A Shock to the System',
#   'première': '1990',
#   'regie': 'Jan Egleson',
#   'spelers': 'Michael Caine Elizabeth McGovern Peter Riegert Swoosie Kurtz',
#   'land': 'US',
#   'duur': '91 minuten',
#   'imdb': '0100602',
#   'moviemeter': '7744',
#   'taal': 'Engels',
#   'lengte': '91 minuten',
#   'tagline': 'Climbing the corporate ladder can be murder',
#   'montage': 'William M Anderson'},
#  'A Princess of Mars': {'naam': 'Prinses van Mars',
#   'afbeelding': 'Princess of Mars large jpg',
#   'orig titel': 'A Princess of Mars',
#   'auteur': 'Edgar Rice Burroughs',
#   'vertaler': 'Ton Stam',
#   'land': 'US',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'reeks': 'Barsoom',
#   'genre': 'Sciencefiction',
#   'uitgever': 'Hoorn West Friesland',
#   'originele uitgever': 'A C McClurg',
#   'uitgiftedatum': '1971',
#   'uitgiftedatum origineel': '1917',
#   'medium': 'Print',
#   'paginas': '160',
#   'isbn': 'ISBN 90 205 0588 2',
#   'film': 'Princess of Mars John Carter film John Carter',
#   'volgendeboek': 'Goden van Mars',
#   'extra portaal': 'Sciencefiction'},
#  'A Short History of Nearly Everything': {'naam': 'Een kleine geschiedenis van bijna alles',
#   'orig titel': 'A short history of nearly everything',
#   'auteur': 'Bill Bryson',
#   'vertaler': 'Servaas Goddijn',
#   'land': 'GB',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'onderwerp': 'Natuurwetenschap Geschiedenis',
#   'genre': 'Non fictie',
#   'uitgever': 'NL VLAG Atlas uitgeverij Atlas',
#   'originele uitgever': 'GB VLAG Doubleday US VLAG Broadway Books',
#   'uitgiftedatum': '2004',
#   'uitgiftedatum origineel': '2003',
#   'paginas': '512',
#   'isbn': '978 90 450 0970 4',
#   'isbntoelichting': 'Paperback'},
#  'A Scanner Darkly': {'titel': 'A Scanner Darkly',
#   'tagline': 'Everything Is Not Going To Be OK What Does A Scanner See',
#   'regie': 'Richard Linklater',
#   'producer': 'Tommy Pallotta Anne Walker McBay Palmer West Jonah Smith Erwin Stoff',
#   'schrijver': 'Richard Linklater',
#   'spelers': 'Keanu Reeves Robert Downey Jr Woody Harrelson Winona Ryder',
#   'muziek': 'Graham Reynolds',
#   'montage': 'Sandra Adair',
#   'cinematografie': 'Shane F Kelly',
#   'distributeur': 'Warner Home Video',
#   'première': '7 juli 2006',
#   'genre': 'Sciencefictionfilm Animatiefilm',
#   'lengte': '100 minuten',
#   'taal': 'Engels',
#   'land': 'US',
#   'budget': '8 7 miljoen dollar',
#   'imdb': '0405296',
#   'moviemeter': '28490'},
#  'A Series of Unfortunate Events': {'naam': 'Ellendige avonturen',
#   'orig titel': 'A series of Unfortunate Events',
#   'vertaler': 'Huberte Vriesendorp',
#   'afbeelding': 'A_Series_of_Unfortunate_Events_logo png',
#   'auteur': 'Daniel Handler aka Lemony Snicket',
#   'kaftontwerp': 'Brett Helquist',
#   'land': 'Verenigde Staten',
#   'taal': 'Engels',
#   'genre': 'Jeugdliteratuur Jeugd zwarte humor steampunk',
#   'uitgever': 'HarperCollins Uitgeverij Ploegsma',
#   'uitgiftedatum': '30 september 1999'},
#  'A Thousand Splendid Suns': {'naam': 'Duizend schitterende zonnen',
#   'orig titel': 'A Thousand Splendid Suns',
#   'vertaler': 'W Hansen',
#   'auteur': 'Khaled Hosseini',
#   'uitgever': 'Riverhead Books Verenigde Staten De Bezige Bij Nederland',
#   'uitgiftedatum': '2007',
#   'paginas': '397 Nederland',
#   'isbn': '9789023426066'},
#  'A Study in Scarlet': {'naam': 'Een studie in rood',
#   'orig titel': 'A Study in Scarlet',
#   'afbeelding': 'ArthurConanDoyle AStudyInScarlet annual jpg',
#   'auteur': 'Arthur Conan Doyle',
#   'land': 'Verenigd Koninkrijk',
#   'taal': 'Engels',
#   'reeks': 'Sherlock Holmes',
#   'genre': 'detectiveverhaal detective misdaad mysterie',
#   'uitgiftedatum': '1887',
#   'medium': 'print hardcover paperback en luisterboek',
#   'paginas': '96',
#   'vervolg': 'Het teken van de vier'},
#  'A World Out of Time': {'naam': 'Buiten de tijd',
#   'cover-op-enwp': 'WRLDTFTMZW1977 jpg',
#   'orig titel': 'A World Out of Time',
#   'vertaler': 'Pon Ruiter',
#   'auteur': 'Larry Niven',
#   'originele taal': 'Engels',
#   'taal': 'Nederlands',
#   'genre': 'Sciencefiction',
#   'uitgever': 'Elsevier uitgeverij Elsevier',
#   'uitgiftedatum': '1977',
#   'medium': 'Boek',
#   'paginas': '256',
#   'isbn': '9789010018915',
#   'vervolg': 'De integraalbomen'},
#  'A Wrinkle in Time': {'naam': 'Een rimpel in de tijd',
#   'orig titel': 'A Wrinkle in Time',
#   'auteur': 'Madeleine L Engle',
#   'illustraties': 'Ellen Raskin',
#   'land': 'US',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'genre': 'Jeugdliteratuur Science fantasy',
#   'uitgever': 'Luitingh Sijthoff',
#   'originele uitgever': 'Ariel Books',
#   'uitgiftedatum': '5 maart 2018',
#   'uitgiftedatum origineel': '1 januari 1962',
#   'medium': 'Paperback',
#   'paginas': '160',
#   'isbn': '9789024580606',
#   'NUR-code': '283',
#   'volgendeboek': 'Een scheur in de ruimte 1973'},
#  'Advise and Consent': {'titel': 'Advise and Consent Storm over Washington',
#   'afbeelding': 'Advise Consent 1 jpg',
#   'onderschrift': 'Aanplakbiljet voor Advise and Consent',
#   'regie': 'Otto Preminger',
#   'producer': 'Otto Preminger',
#   'schrijver': 'Wendell Mayes Allen Drury roman',
#   'spelers': 'Franchot Tone Lew Ayres Henry Fonda',
#   'muziek': 'Jerry Fielding',
#   'montage': 'Louis R Loeffler',
#   'cinematografie': 'Sam Leavitt',
#   'distributeur': 'Columbia Pictures',
#   'première': '6 juni 1962',
#   'genre': 'Drama',
#   'lengte': '139 minuten',
#   'taal': 'Engels',
#   'land': 'US',
#   'imdb': '0055728',
#   'moviemeter': '7962'},
#  'After the Funeral': {'naam': 'Na de begrafenis',
#   'orig titel': 'After the Funeral',
#   'auteur': 'Agatha Christie',
#   'originele taal': 'Engels hoofdbetekenis Engels',
#   'genre': 'Detectiveverhaal detective',
#   'uitgever': 'Luitingh Sijthoff',
#   'originele uitgever': 'Dodd Mead and Company',
#   'uitgiftedatum': '1953',
#   'uitgiftedatum origineel': '1953',
#   'vorigeboek': 'Gebroken verhouding',
#   'volgendeboek': 'Een handvol rogge'},
#  'Adventures of Huckleberry Finn': {'naam': 'De lotgevallen van Huckleberry Finn',
#   'orig titel': 'Adventures of Huckleberry Finn',
#   'afbeelding': 'E W Kemble Adventures of Huckleberry Finn Cover jpg',
#   'auteur': 'Mark Twain',
#   'land': 'Verenigde Staten',
#   'taal': 'Engels',
#   'uitgiftedatum': '1884',
#   'paginas': '366',
#   'isbn': '0 553 21079 3',
#   'voorafgegaan': 'De lotgevallen van Tom Sawyer',
#   'vervolg': 'Tom Sawyer Abroad'},
#  'Aeneid': {'naam': 'Aeneis Eneïde',
#   'afbeelding': 'Aeneas bij de sibylle Arcana RP P OB 42 318 jpg',
#   'onderschrift': 'Prent Aeneas bij de sibylle Arcana tussen 1651 en 1682 door François Bourlier vermeld op object naar ontwerp van François Perrier',
#   'cover-op-enwp': 'Cristoforo_Majorana_ _Leaf_from_Eclogues _Georgics_and_Aeneid_ _Walters_W40055R_ _Open_Obverse jpg',
#   'auteur': 'Vergilius',
#   'land': 'Romeinse Republiek',
#   'taal': 'Latijn',
#   'onderwerp': 'heldendaden van Aeneas oorsprong van de Romeinse Rijk Romeinse beschaving',
#   'genre': 'heldendicht',
#   'uitgiftedatum origineel': '19 v Chr'},
#  'Allegiant (novel)': {'naam': 'Samensmelting Haar keuze bepaalt alles',
#   'orig titel': 'Allegiant One choice will define you',
#   'vertaler': 'Maria Postema',
#   'auteur': 'Veronica Roth',
#   'kaftontwerp': 'Joel Tippie',
#   'land': 'US',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'reeks': 'Divergent trilogie',
#   'genre': 'young adult',
#   'uitgever': 'Uitgeverij Unieboek Van Goor',
#   'originele uitgever': 'Katherine Tegen Books',
#   'uitgiftedatum': '19 februari 2014',
#   'uitgiftedatum origineel': '22 oktober 2013',
#   'medium': 'boek',
#   'paginas': '380',
#   'gewicht': '649 gram',
#   'isbn': '9789000334797',
#   'voorafgegaan': 'Opstand Veronica Roth Opstand'},
#  'Altered Carbon': {'titel': 'Altered Carbon',
#   'cover-op-enwp': 'Altered_Carbon_title jpg',
#   'genre': 'Cyberpunk',
#   'speelduur': '46 66 minuten',
#   'spelers': 'Joel Kinnaman James Purefoy Martha Higareda Chris Conner Dichen Lachman Ato Essandoh Kristin Lehman Trieu Tran Renée Elise Goldsberry',
#   'orkestratie': 'Jeff Russo',
#   'land': 'VS',
#   'producer': 'John G Lenic',
#   'productiebedrijf': 'Virago Productions Mythology Entertainment Phoenix Pictures Skydance Television',
#   'distributeur': 'Netflix',
#   'start': '2 februari 2018',
#   'afleveringen': '18',
#   'seizoenen': '2',
#   'beeldformaat': '4K Ultra HD High dynamic range',
#   'audioformaat': 'Dolby Digital 5 1 Dolby Atmos',
#   'imdb': '2261227'},
#  'All Quiet on the Western Front': {'naam': 'Van het westelijk front geen nieuws',
#   'orig titel': 'Im Westen nichts Neues',
#   'vertalers': 'Annie Salomons en Ronald Jonkers',
#   'afbeelding': 'Remarque_All_Quiet_NL_9e_druk_a jpg',
#   'auteur': 'Erich Maria Remarque',
#   'land': 'NL',
#   'taal': 'Nederlands',
#   'onderwerp': 'Eerste Wereldoorlog',
#   'genre': 'Oorlogsroman',
#   'uitgever': 'Erven J Bijleveld Utrecht stad Utrecht',
#   'uitgiftedatum': '1929',
#   'medium': 'Boek',
#   'vertaler': 'Annie Salomons en Ronald Jonkers'},
#  "All the President's Men": {'titel': 'All the President s Men',
#   'regie': 'Alan J Pakula',
#   'producer': 'Jon Boorstin Michael Britton Walter Coblenz',
#   'schrijver': 'William Goldman Carl Bernstein boek Bob Woodward boek',
#   'spelers': 'Dustin Hoffman Robert Redford Jack Warden',
#   'muziek': 'David Shire',
#   'montage': 'Robert L Wolfe',
#   'cinematografie': 'Gordon Willis',
#   'distributeur': 'Warner Bros',
#   'première': '4 april 1976',
#   'genre': 'Drama',
#   'lengte': '138 minuten',
#   'taal': 'Engels Spaans',
#   'land': 'US',
#   'budget': '8 500 000',
#   'opbrengst': '70 600 000',
#   'imdb': '0074119',
#   'moviemeter': '1097'},
#  "Alice's Adventures in Wonderland": {'naam': 'Alice in Wonderland',
#   'onderschrift': 'Tekening van Alice het konijn en de Mad Hatter tijdens het theekransje',
#   'orig titel': 'Alice s Adventures in Wonderland',
#   'vertaler': 'Sofia Engelsman',
#   'afbeelding': 'Alice par John Tenniel 25 png',
#   'auteur': 'Lewis Carroll',
#   'illustraties': 'John Tenniel Rie Cramer Floor Rieder',
#   'land': 'Verenigd Koninkrijk',
#   'taal': 'Engels',
#   'genre': 'Sprookje psychologisch',
#   'originele uitgever': 'Macmillan Co',
#   'uitgiftedatum': '1865',
#   'paginas': '192',
#   'film': 'Alice in Wonderland 1903 Alice in Wonderland 1915 Alice in Wonderland 1933 Alice in Wonderland 1949 Alice in Wonderland 1951 Alice in Wonderland televisiefilm Alice in Wonderland 1966 Alice in Wonderland or What s a Nice Kid Like You Doing in a Place Like This 1966 Alice in Wonderland An X Rated Musical Fantasy 1976 Alice in Wonderland 1985 Alice 1988 Alice in Wonderland 1988 Alice in Wonderland 1995 Alice in Wonderland 1999 Alice in Wonderland What s the Matter with Hatter Malice in Wonderland 2009 Malice in Wonderland 2009 Alice in Wonderland 2010 Malice in Lalaland 2010',
#   'vervolg': 'Through the Looking Glass 1871',
#   'extra portaal': 'Film'},
#  'American Psycho': {'naam': 'American Psycho',
#   'auteur': 'Bret Easton Ellis',
#   'vertaler': 'Balt Lenders',
#   'land': 'Verenigde Staten',
#   'originele taal': 'Engels',
#   'onderwerp': 'Bdsm kannibalisme necrofilie psychopathie seriemoord consumptiemaatschappij prostitutie',
#   'genre': 'Psychologische thriller satire postmodernisme',
#   'originele uitgever': 'Vintage Books',
#   'uitgiftedatum': '1991',
#   'paginas': '399',
#   'film': 'American Psycho film American Psycho'},
#  'An American Tragedy': {'titel': 'An American Tragedy Een Amerikaansche tragedie',
#   'afbeelding': 'An_American_Tragedy_Theodore_Dreiser_dust_jacket jpeg',
#   'onderschrift': 'Stofkaft van de uitgave van An American Tragedy',
#   'regie': 'Josef von Sternberg',
#   'producer': 'Josef von Sternberg',
#   'schrijver': 'Samuel Hoffenstein Josef von Sternberg Theodore Dreiser roman',
#   'spelers': 'Phillips Holmes Sylvia Sidney Frances Dee',
#   'muziek': 'John Leipold Ralph Rainger',
#   'montage': 'Hans Dreier',
#   'cinematografie': 'Lee Garmes',
#   'distributeur': 'Paramount Pictures',
#   'première': '5 augustus 1931',
#   'genre': 'Drama',
#   'lengte': '96 minuten',
#   'taal': 'Engels',
#   'land': 'US',
#   'imdb': '0021607',
#   'moviemeter': '75512'},
#  'An Essay on the Principle of Population': {'naam': 'An Essay on the Principle of Population',
#   'afbeelding': 'An Essay on the Principle of Population jpg',
#   'onderschrift': 'Titelpagina van de 1e druk uit 1798',
#   'auteur': 'Thomas Malthus Thomas Robert Malthus',
#   'land': 'EN',
#   'originele taal': 'Engels',
#   'uitgever': 'J Johnson Londen',
#   'uitgiftedatum origineel': '1798',
#   'extra portaal': 'Mens maatschappij'},
#  'Anatomy of a Murder': {'titel': 'Anatomy of a Murder Analyse van een moord',
#   'afbeelding': 'AnatomyMurder2 jpg',
#   'onderschrift': 'Filmposter',
#   'regie': 'Otto Preminger',
#   'producer': 'Otto Preminger',
#   'schrijver': 'Wendell Mayes',
#   'spelers': 'James Stewart acteur James Stewart Lee Remick Ben Gazzara',
#   'muziek': 'Duke Ellington',
#   'montage': 'Louis R Loeffler',
#   'production design': 'Boris Leven',
#   'cinematografie': 'Sam Leavitt',
#   'distributeur': 'Columbia Pictures',
#   'première': '1 juli 1959',
#   'genre': 'Drama',
#   'lengte': '160 minuten',
#   'taal': 'Engels',
#   'land': 'US',
#   'imdb': '0052561',
#   'moviemeter': '2544'},
#  "Angela's Ashes": {'naam': 'De as van mijn moeder',
#   'orig titel': 'Angela s Ashes',
#   'vertaler': 'Christien Jonkheer',
#   'auteur': 'Frank McCourt',
#   'uitgever': 'Barnes and Noble Verenigde Staten Prometheus uitgeverij Nederland',
#   'uitgiftedatum': '1997',
#   'paginas': '408 Nederland',
#   'grootte_gewicht': '11 5 cm bij 17 6 267 gram',
#   'isbn': '904614089X',
#   'vervolg': 'Tis'},
#  'Aniara': {'naam': 'Aniara',
#   'titelweergave': 'Aniara',
#   'orde': 'Kevers Coleoptera Kevers',
#   'familie': 'Loopkevers Carabidae Loopkevers',
#   'onderfamilie': 'Zandloopkevers onderfamilie Cicindelinae Zandloopkevers',
#   'taxon': 'Geslacht biologie Geslacht',
#   'w-naam': 'Aniara',
#   'auteur': 'Frederick William Hope Hope',
#   'datum': '1838'},
#  'And Then There Were None': {'naam': 'Tien kleine negertjes',
#   'orig titel': 'Ten little niggers',
#   'auteur': 'Agatha Christie',
#   'land': 'Verenigd Koninkrijk',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'genre': 'misdaadgenre',
#   'uitgever': 'Luitingh Sijthoff',
#   'originele uitgever': 'Dodd Mead and Company',
#   'uitgiftedatum origineel': '6 november 1939',
#   'medium': 'Pocket',
#   'paginas': '229',
#   'vorigeboek': 'Het Regatta mysterie',
#   'volgendeboek': 'Schuldig in eigen ogen'},
#  'Angels and Demons': {'titel': 'Angels Demons',
#   'tagline': 'The holiest event of our time Perfect for their return The path is alive',
#   'regie': 'Ron Howard',
#   'producer': 'Brian Grazer John Calley',
#   'schrijver': 'Dan Brown boek Akiva Goldsman script',
#   'spelers': 'Tom Hanks Ewan McGregor Slim Khezri Armin Mueller Stahl',
#   'muziek': 'Hans Zimmer',
#   'montage': 'Daniel P Hanley Mike Hill',
#   'cinematografie': 'Salvatore Totino',
#   'distributeur': 'Sony Pictures Entertainment Columbia Pictures',
#   'première': 'US VLAG 15 mei 2009 BE VLAG 13 mei 2009 NL VLAG 13 mei 2009',
#   'genre': 'Mystery Thriller genre Thriller',
#   'lengte': '145 min',
#   'taal': 'Engels hoofdbetekenis Engels',
#   'land': 'US',
#   'budget': '150 000 000',
#   'opbrengst': '485 930 816',
#   'voorloper': 'The Da Vinci Code film The Da Vinci Code',
#   'vervolg': 'Inferno 2016 Inferno',
#   'imdb': '0808151',
#   'moviemeter': '49002'},
#  'Angel Beats!': {'titel': 'Angel Beats',
#   'afbeelding': 'Angel Beats game logo svg',
#   'genre': 'Actie Fantasy genre Fantasy',
#   'bedenker': 'Jun Maeda',
#   'stemmen (oorspr.)': 'Harumi Sakurai Hiroshi Kamiya Kana Hanazawa',
#   'stemmen (NL)': 'Niet beschikbaar',
#   'muziek': 'Jun Maeda Anant Garde Eyes',
#   'intromuziek': 'My Soul Your Beats door Lia',
#   'land': 'Japan',
#   'taal': 'Japans Engels Duits',
#   'producer': 'Kenji Horikawa Hiro Maruyama Hironori Toba',
#   'afleveringen': '13',
#   'seizoenen': '1'},
#  'Anna Karenina': {'naam': 'Anna Karenina',
#   'afbeelding': 'AnnaKareninaTitle jpg',
#   'afbeeldingbreedte': '220px',
#   'onderschrift': 'Titelblad eerste boekuitgave 1878',
#   'auteur': 'Lev Tolstoj',
#   'land': 'RU',
#   'originele taal': 'Russisch',
#   'genre': 'Roman',
#   'uitgiftedatum origineel': '1877'},
#  'Animal Farm': {'naam': 'Boerderij der Dieren',
#   'orig titel': 'Animal Farm',
#   'vertaler': 'Anthony Ross',
#   'afbeelding': 'Animal Farm 1st edition jpg',
#   'auteur': 'George Orwell',
#   'taal': 'Engels',
#   'uitgever': 'Uitgeverij Phoenix 1947 de Arbeiderspers 1956',
#   'uitgiftedatum': '1945',
#   'isbn': '0 8488 0120 2'},
#  'Anne of Green Gables': {'naam': 'Anne van het Groene Huis',
#   'orig titel': 'Anne of Green Gables',
#   'vertaler': 'E R Kuitenbrouwer Dickson en Hermine Vermeulen Smit later ook Martha Heesen',
#   'afbeelding': 'FirstPageGreenGables gif',
#   'auteur': 'Lucy Maud Montgomery',
#   'illustraties': 'M A en W A J Claus',
#   'land': 'Canada',
#   'taal': 'Engels',
#   'reeks': 'Anne van het Groene Huis',
#   'genre': 'fictie',
#   'uitgever': 'L C Page Co in Nederland De Fontein uitgeverij De Fontein',
#   'uitgiftedatum': 'juni 1908',
#   'paginas': '429 eerste druk'},
#  'Around the Moon': {'naam': 'De reis om de maan',
#   'orig titel': 'Autour de la Lune',
#   'afbeelding': 'Around the Moon by Bayard and Neuville 36 jpg',
#   'auteur': 'Jules Verne',
#   'illustraties': 'Émile Antoine Bayard Alphonse Marie de Neuville',
#   'land': 'Frankrijk',
#   'taal': 'Frans',
#   'reeks': 'Voyages extraordinaires 7',
#   'genre': 'Sciencefiction',
#   'uitgever': 'Pierre Jules Hetzel',
#   'uitgiftedatum': '1870',
#   'medium': 'Print Hardcover Hardback Paperback',
#   'paginas': '212',
#   'voorafgegaan': 'Van de aarde naar de maan',
#   'vervolg': 'Een schot in de lucht'},
#  'Artemis Fowl and the Lost Colony': {'naam': 'Artemis Fowl De verloren kolonie',
#   'orig titel': 'Artemis Fowl The Lost Colony',
#   'auteur': 'Eoin Colfer',
#   'land': 'Ierland land Ierland',
#   'taal': 'Engels',
#   'reeks': 'Artemis Fowl serie Artemis Fowl',
#   'genre': 'Fantasy',
#   'uitgever': 'Puffin Books',
#   'uitgiftedatum': '2 augustus 2006',
#   'medium': 'Print Hardcover Hardback Paperback',
#   'paginas': '384',
#   'isbn': '0141382686',
#   'voorafgegaan': 'Artemis Fowl Het bedrog van Opal',
#   'vervolg': 'Artemis Fowl en de tijdparadox'},
#  'Artemis Fowl: The Eternity Code': {'naam': 'Artemis Fowl De eeuwige code',
#   'orig titel': 'Artemis Fowl The Eternity Code',
#   'auteur': 'Eoin Colfer',
#   'land': 'Ierland land Ierland',
#   'taal': 'Engels',
#   'reeks': 'Artemis Fowl serie Artemis Fowl',
#   'genre': 'Fantasy',
#   'uitgever': 'Viking Press',
#   'uitgiftedatum': '27 april 2003',
#   'medium': 'Print Hardcover Hardback Paperback',
#   'paginas': '352',
#   'isbn': '0670913529',
#   'voorafgegaan': 'Artemis Fowl De Russische connectie',
#   'vervolg': 'Artemis Fowl Het bedrog van Opal'},
#  "Asimov's Mysteries": {'naam': 'De sprekende steen',
#   'orig titel': 'Asimov s Mysteries',
#   'auteur': 'Isaac Asimov',
#   'vertaler': 'Henk Bouwman',
#   'land': 'US',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'genre': 'Sciencefiction',
#   'uitgever': 'A W Bruna Uitgevers',
#   'originele uitgever': 'Doubleday',
#   'uitgiftedatum': '1970',
#   'uitgiftedatum origineel': '1968',
#   'medium': 'pocketboek',
#   'extra portaal': 'Sciencefiction'},
#  'As I Lay Dying': {'naam': 'Terwijl ik al heenging',
#   'afbeelding': 'AsILayDying jpg',
#   'orig titel': 'As I Lay Dying',
#   'auteur': 'William Faulkner',
#   'vertaler': 'Rien Verhoef',
#   'land': 'Verenigde Staten',
#   'originele taal': 'Engels',
#   'genre': 'Roman literatuur Roman',
#   'uitgever': 'Eldorado',
#   'originele uitgever': 'Jonathan Cape and Harrison Smith New York',
#   'uitgiftedatum': '2007',
#   'uitgiftedatum origineel': '1930',
#   'medium': 'Paperback',
#   'paginas': '255',
#   'isbn': '9047100298'},
#  "Assassin's Quest": {'naam': 'Vermogen en Wijsheid',
#   'orig titel': 'Assassin s Quest',
#   'Schrijfster': 'Robin Hobb',
#   'vertaler': 'Peter Cuijpers',
#   'auteur': 'Robin Hobb',
#   'kaftontwerp': 'John Howe UK',
#   'land': 'Nederland',
#   'taal': 'Nederlands',
#   'reeks': 'De boeken van de Zieners',
#   'genre': 'Fantasy genre Fantasy',
#   'uitgever': 'Uitgeverij M',
#   'uitgiftedatum': '2003',
#   'medium': 'Gebonden Hardcover',
#   'paginas': '640 blz gebonden',
#   'grootte_gewicht': '223 x 161 x 50 millimeter mm 834 Gram eenheid gram',
#   'isbn': '9022536041',
#   'voorafgegaan': 'Moordenaar des konings'},
#  "Assassin's Apprentice": {'naam': 'Leerling en Meester',
#   'orig titel': 'Assassin s Apprentice',
#   'vertaler': 'Erica Feberwee en Peter Cuijpers',
#   'auteur': 'Robin Hobb',
#   'kaftontwerp': 'John Howe UK',
#   'land': 'Nederland',
#   'taal': 'Nederlands',
#   'reeks': 'De boeken van de Zieners',
#   'genre': 'Fantasy genre Fantasy',
#   'uitgever': 'M',
#   'uitgiftedatum': '1998',
#   'medium': 'Gebonden Hardcover',
#   'paginas': '352 blz gebonden',
#   'grootte_gewicht': '568 Gram eenheid gram',
#   'isbn': '9022536025',
#   'vervolg': 'Moordenaar des konings'},
#  'Auntie Mame': {'titel': 'Auntie Mame',
#   'poster-op-enwp': 'Auntie Mame Poster jpg',
#   'regie': 'Morton DaCosta',
#   'producer': 'Morton DaCosta',
#   'schrijver': 'Betty Comden en Adolph Green',
#   'spelers': 'Rosalind Russell Forrest Tucker Coral Browne Roger Smith acteur Roger Smith Peggy Cass Jan Handzlik',
#   'muziek': 'Bronisław Kaper',
#   'montage': 'William Ziegler',
#   'cinematografie': 'Harry Stradling',
#   'distributeur': 'Warner Bros Pictures',
#   'première': '4 december 1958',
#   'lengte': '143 minuten',
#   'taal': 'Engels',
#   'land': 'VS',
#   'imdb': '0051383'},
#  'Atonement (novel)': {'naam': 'Boetekleed',
#   'orig titel': 'Atonement',
#   'auteur': 'Ian McEwan',
#   'vertaler': 'Rien Verhoef',
#   'land': 'Verenigd Koninkrijk Engeland',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'uitgever': 'De Harmonie',
#   'uitgiftedatum': '2002',
#   'uitgiftedatum origineel': '2001',
#   'isbn': '978 90 761 6820 3',
#   'film': 'Atonement film Atonement 2007'},
#  'Band of Brothers (book)': {'naam': 'Band of Brothers van Normandië tot Adolf Hitler Hitlers Kehlsteinhaus Adelaarsnest de Easy compagnie 506de Regiment 101ste Luchtlandingsdivisie',
#   'orig titel': 'Band of Brothers E Company 506th Regiment 101st Airborne from Normandy to Hitler s Eagle s Nest',
#   'vertaler': 'Jeske Nelissen',
#   'auteur': 'Stephen Ambrose',
#   'land': 'Verenigde Staten',
#   'taal': 'Engels',
#   'onderwerp': 'Tweede Wereldoorlog United States Army',
#   'uitgever': 'BZZTôH',
#   'uitgiftedatum': '1993',
#   'paginas': '304',
#   'grootte_gewicht': '25 x 16 x 2 cm 678 gram',
#   'isbn': 'ISBN 9055019887'},
#  'Atlas Shrugged': {'naam': 'Atlas in staking',
#   'orig titel': 'Atlas Shrugged',
#   'vertaler': 'J de Voogt',
#   'afbeelding': 'Atlas Shrugged 1957 1st ed Ayn Rand jpg',
#   'onderschrift': 'Kaft van de eerste druk 1957',
#   'auteur': 'Ayn Rand',
#   'land': 'Verenigde Staten',
#   'taal': 'Engels',
#   'genre': 'Toekomstroman',
#   'uitgever': 'Johannes Multimedia',
#   'uitgiftedatum': '1957 origineel 2007 vertaling',
#   'medium': 'Print',
#   'paginas': '1168 origineel 1003 vertaling',
#   'isbn': '9789077564943',
#   'film': 'Atlas Shrugged Part I'},
#  'Baccano!': {'titel': 'Baccano',
#   'genre': 'Actiefilm Actie Drama kunst en cultuur drama Komedie',
#   'bedenker': 'Takahiro Omori',
#   'stemmen (oorspr.)': 'Sanae Koboyashi Mitsuru Miyamoto Hiroyuki Yoshino en anderen',
#   'stemmen (NL)': 'Niet beschikbaar',
#   'intromuziek': 'Gun s Roses door Paradise Lunch',
#   'land': 'Japan',
#   'taal': 'Japans',
#   'afleveringen': '13 3 extra OVA s',
#   'seizoenen': '1'},
#  'Barnaby Rudge': {'naam': 'Barnaby Rudge',
#   'orig titel': 'Barnaby Rudge A Tale of the Riots of Eighty',
#   'afbeelding': 'Masterclock serial cover jpg',
#   'onderschrift': 'Cover van de serie Master Humphrey s Clock uit 1890',
#   'auteur': 'Charles Dickens',
#   'illustraties': 'George Cattermole Hablot Knight Browne',
#   'land': 'Verenigd Koninkrijk',
#   'taal': 'Engels',
#   'uitgiftedatum': '1841'},
#  'Baudolino': {'naam': 'Baudolino',
#   'afbeelding': 'Umberto Eco 01 jpg',
#   'onderschrift': 'Umberto Eco',
#   'auteur': 'Umberto Eco',
#   'vertaler': 'Yond Boeke',
#   'land': 'Byzantijnse Rijk',
#   'taal': 'Nederlands',
#   'originele taal': 'Italiaans taal Italiaans',
#   'genre': 'Schelmenroman',
#   'uitgever': 'Bert Bakker',
#   'uitgiftedatum': '2001',
#   'isbn': '978 90 351 2288 8'},
#  'Because of Winn-Dixie': {'titel': 'Because of Winn Dixie',
#   'regie': 'Wayne Wang',
#   'producer': 'Trevor Albert Joan Singleton',
#   'schrijver': 'Joan Singleton Kate DiCamillo roman',
#   'voice-over': 'AnnaSophia Robb',
#   'spelers': 'AnnaSophia Robb Jeff Daniels',
#   'distributeur': '20th Century Fox',
#   'première': '26 januari 2005 VS 13 december 2005 NL videotheek',
#   'muziek': 'Rachel Portman',
#   'cinematografie': 'Karl Walter Lindenlaub',
#   'montage': 'Deirdre Slevin',
#   'genre': 'Familie Drama Komedie',
#   'lengte': '106 minuten',
#   'taal': 'Engels',
#   'land': 'US',
#   'budget': '14 000 000',
#   'imdb': '0317132',
#   'moviemeter': '19368'},
#  'Bambi': {'titel': 'Bambi',
#   'afbeelding': 'Bambi_Logo_Black svg',
#   'onderschrift': 'Bambi Feline',
#   'poster-op-enwp': 'Walt Disney s Bambi poster jpg',
#   'regie': 'David Dodd Hand',
#   'producer': 'Walt Disney',
#   'schrijver': 'Felix Salten boek Larry Morey afgeleid verhaal Perce Pearce regie verhaal',
#   'spelers': 'Bobby Stewart Donnie Dunagan Hardie Albright John Sutherland Paula Winslowe Peter Behn Tim Davis Sam Edwards Will Wright acteur Will Wright Cammie King Ann Gillis Fred Shields Stan Alexander Sterling Holloway',
#   'muziek': 'Edward H Plumb',
#   'cinematografie': 'Maxwell Morgan',
#   'première': 'VS 13 augustus 1942 Nederland en België 18 september 1947',
#   'genre': 'Animatie',
#   'lengte': '70 minuten',
#   'taal': 'Engels',
#   'land': 'Verenigde Staten',
#   'budget': 'US 858 000',
#   'opbrengst': 'US 267 miljoen',
#   'nominaties': 'Prijzen en nominaties 6',
#   'prijzen': '2',
#   'vervolg': 'Bambi II',
#   'imdb': '0034492',
#   'moviemeter': '1379',
#   'extra portaal': 'Disney'},
#  'Beach House': {'band_naam': 'Beach House',
#   'afbeelding': 'BeachHouse jpg',
#   'jaren_actief': '2004 heden',
#   'oorsprong': 'Baltimore Maryland Verenigde Staten',
#   'muziek_genre': 'Dreampop Indie muziek indiepop',
#   'record_label': 'Sub Pop',
#   'website': 'http www beachhousebaltimore com',
#   'functie1': 'Zang',
#   'lid1': 'Victoria Legrand',
#   'functie2': 'Gitaar',
#   'lid2': 'Alex Scally',
#   'functie3': 'Drums',
#   'lid3': 'Daniel Franz'},
#  'Between Planets': {'naam': 'Tussen de planeten',
#   'cover-op-enwp': 'Bp51 jpg',
#   'orig titel': 'Between Planets',
#   'auteur': 'Robert Heinlein',
#   'vertaler': 'Ruud Bal',
#   'land': 'US',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'reeks': 'Born SF Born Nova',
#   'genre': 'Sciencefiction',
#   'uitgever': 'Born',
#   'originele uitgever': 'Charles Scribner s Sons',
#   'uitgiftedatum': '1977',
#   'uitgiftedatum origineel': '1951',
#   'medium': 'pocketboek',
#   'paginas': '160',
#   'grootte': '180 x 115',
#   'isbn': '90 283 0546 7',
#   'extra portaal': 'Sciencefiction'},
#  'Being There': {'titel': 'Being There',
#   'regie': 'Hal Ashby',
#   'producer': 'Andrew Braunsberg',
#   'schrijver': 'Jerzy Kosinski',
#   'spelers': 'Peter Sellers Shirley MacLaine Melvyn Douglas',
#   'muziek': 'Johnny Mandel',
#   'montage': 'Don Zimmerman',
#   'cinematografie': 'Caleb Deschanel',
#   'distributeur': 'United Artists',
#   'première': '19 december 1979',
#   'genre': 'Komedie',
#   'lengte': '130 minuten',
#   'taal': 'Engels Russisch Italiaans taal Italiaans',
#   'land': 'US',
#   'budget': '7 000 000',
#   'opbrengst': '30 177 511',
#   'imdb': '0078841',
#   'moviemeter': '1716'},
#  'Bedknobs and Broomsticks': {'titel': 'Heksen Bezemstelen',
#   'poster-op-enwp': 'Bedknobs and Broomsticks poster jpg',
#   'regie': 'Robert Stevenson regisseur Robert Stevenson',
#   'producer': 'Bill Walsh',
#   'schrijver': 'Mary Norton boek Bill Walsh Don DaGradi',
#   'spelers': 'Angela Lansbury David Tomlinson Roddy McDowall Sam Jaffe John Ericson',
#   'muziek': 'Richard Sherman Richard M Sherman Robert Sherman Robert B Sherman Irwin Kostal',
#   'distributeur': 'Buena Vista Distribution',
#   'première': '7 oktober 1971',
#   'genre': 'Familie Avontuur Fantasie Musical',
#   'lengte': '117 minuten',
#   'taal': 'Engels hoofdbetekenis Engels Duits',
#   'land': 'Verenigde Staten hoofdbetekenis Verenigde Staten',
#   'budget': 'US 20 miljoen',
#   'imdb': '0066817',
#   'moviemeter': '9199'},
#  'Beyond the Rocks': {'titel': 'Beyond the Rocks Gouden boeien',
#   'afbeelding': 'Beyond the Rocks Paramount 1922 movieposter jpg',
#   'onderschrift': 'Aanplakbiljet voor Beyond the Rocks',
#   'regie': 'Sam Wood',
#   'producer': 'Jesse L Lasky',
#   'schrijver': 'Jack Cunningham',
#   'spelers': 'Rudolph Valentino Gloria Swanson Edythe Chapman',
#   'cinematografie': 'Alfred Gilks',
#   'distributeur': 'Paramount Pictures',
#   'première': '7 mei 1922',
#   'genre': 'Drama',
#   'lengte': '81 minuten',
#   'taal': 'Engels tussentitels',
#   'land': 'US 1912',
#   'imdb': '0012938',
#   'moviemeter': '21902'},
#  'Barsoom': {'titel': 'Barsoom John Carter of Mars',
#   'afbeelding': 'Princess of Mars large jpg',
#   'onderschrift': 'Cover van A Princess of Mars door Edgar Rice Burroughs A C McClurg McClurg 1917',
#   'land': 'Verenigde Staten',
#   'taal': 'Engels',
#   'genre': 'Sciencefiction Fantasy',
#   'oplage': '10',
#   'schrijver': 'Edgar Rice Burroughs',
#   'medium': 'Boeken Tijdschriften',
#   'eerste': '1912',
#   'laatste': '1943',
#   'extra portaal': 'Sciencefiction'},
#  'Bicentennial Man': {'titel': 'Bicentennial Man',
#   'tagline': 'One robot s 200 year journey to become an ordinary man',
#   'regie': 'Chris Columbus',
#   'producer': 'Wolfgang Petersen Michael Barnathan Laurence Mark Chris Columbus',
#   'schrijver': 'Nicholas Kazan',
#   'spelers': 'Robin Williams Embeth Davidtz',
#   'muziek': 'James Horner',
#   'montage': 'Nicolas De Toth Neil Travis',
#   'distributeur': 'Columbia Pictures Touchstone Pictures',
#   'première': 'VS 13 december 1999 Nederland 24 februari 2000 België 15 maart 2000',
#   'genre': 'Drama sciencefiction',
#   'lengte': '132 minuten',
#   'taal': 'Engels',
#   'land': 'US',
#   'budget': '100 000 000',
#   'nominaties': 'Bicentennial Man Prijzen en nominaties 7',
#   'prijzen': 'Bicentennial Man Prijzen en nominaties 1',
#   'imdb': '0182789',
#   'moviemeter': '17'},
#  'Big Planet': {'naam': 'Grote planeet',
#   'auteur': 'Jack Vance',
#   'vertaler': 'Mark Carpentier Alting',
#   'uitgever': 'J M Meulenhoff Meulenhoff',
#   'orig titel': 'Big Planet',
#   'uitgiftedatum': '1952',
#   'genre': 'Sciencefiction',
#   'paginas': '167 blz',
#   'extra portaal': 'Sciencefiction'},
#  'Billion Dollar Brain': {'titel': 'Billion Dollar Brain Geheime zending voor Finland',
#   'regie': 'Ken Russell',
#   'producer': 'Harry Saltzman',
#   'schrijver': 'Len Deighton boek John McGrath',
#   'spelers': 'Michael Caine Karl Malden Ed Begley Oscar Homolka Françoise Dorléac',
#   'muziek': 'Richard Rodney Bennett',
#   'montage': 'Alan Osbiston',
#   'cinematografie': 'Billy Williams',
#   'distributeur': 'United Artists',
#   'première': '20 december 1967 USA',
#   'genre': 'spionage',
#   'lengte': '111 minuten',
#   'taal': 'Engels',
#   'land': 'GB',
#   'imdb': '0061405',
#   'moviemeter': '7711'},
#  'Black Easter': {'naam': 'Het helse paasvuur',
#   'orig titel': 'Black Easter',
#   'auteur': 'James Blish',
#   'vertaler': 'Hendrik Jan Oolbekkink',
#   'kaftontwerp': 'Alex Jagtenberg Studio Lemaire',
#   'land': 'US',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'reeks': 'Born SF',
#   'genre': 'Fantasy genre Fantasy',
#   'uitgever': 'Born',
#   'uitgiftedatum': '1971',
#   'uitgiftedatum origineel': '1968',
#   'medium': 'pocketboek',
#   'paginas': '160',
#   'grootte': '180 x 115',
#   'extra portaal': 'Fantasy'},
#  'Bleak House': {'naam': 'Bleak House',
#   'afbeelding': 'Bleakhouse serial cover jpg',
#   'onderschrift': 'Omslag van de eerste aflevering 1852',
#   'auteur': 'Charles Dickens',
#   'land': 'Engeland',
#   'taal': 'Engels',
#   'genre': 'Roman literatuur roman',
#   'uitgever': 'Bradbury Evans',
#   'uitgiftedatum': 'in afleveringen 1852 1853 in boekvorm 1853',
#   'isbn': 'n v t',
#   'voorafgegaan': 'David Copperfield boek David Copperfield 1849 1850',
#   'vervolg': 'A Child s History of England 1852 1854'},
#  'Bloodlines (Mead novel)': {'naam': 'Bloedverwanten',
#   'orig titel': 'Bloodlines',
#   'auteur': 'Richelle Mead',
#   'land': 'US',
#   'taal': 'Engels',
#   'reeks': 'De alchemisten',
#   'genre': 'Jeugdliteratuur jeugdliteratuur Jeugdliteratuur fantasie Liefdesroman romantiek',
#   'uitgever': 'Penguin Group Razorbill',
#   'uitgiftedatum': '23 augustus 2011',
#   'isbn': 'ISBN 978 1595143174',
#   'voorafgegaan': 'Academicus Vampyrus boekenserie'},
#  'Bonjour Tristesse': {'naam': 'Bonjour tristesse',
#   'afbeelding': 'Bonjour Tristesse film poster jpg',
#   'orig titel': 'Bonjour tristesse',
#   'auteur': 'Françoise Sagan',
#   'land': 'Frankrijk',
#   'originele taal': 'Frans',
#   'genre': 'Roman literatuur Roman',
#   'originele uitgever': 'Julliard',
#   'uitgiftedatum origineel': '1954',
#   'paginas': '153',
#   'grootte': '14x177x108 millimeter mm',
#   'gewicht': '98 gram eenheid g',
#   'isbn': '978 2 253 00429 5',
#   'film': 'Bonjour tristesse film Bonjour tristesse'},
#  'Born Free': {'titel': 'Born Free',
#   'poster-op-enwp': 'Born Free Poster jpg',
#   'regie': 'James Hill regisseur James Hill',
#   'producer': 'Sam Jaffe Paul B Radin',
#   'schrijver': 'Lester Cole Joy Adamson boek',
#   'spelers': 'Virginia McKenna Bill Travers Geoffrey Keen',
#   'muziek': 'John Barry',
#   'cinematografie': 'Kenneth Talbot',
#   'distributeur': 'Columbia Pictures',
#   'première': '14 maart 1966 Londen JP VLAG 26 maart 1966',
#   'genre': 'Dramafilm Drama Natuurfilm Natuur',
#   'lengte': '95 minuten',
#   'taal': 'Engels',
#   'land': 'UK',
#   'imdb': '0060182',
#   'moviemeter': '5254'},
#  'Book of Kells': {'naam': 'Codex Cenannensis Leabhar Cheanannais Iers',
#   'afbeelding': 'KellsFol292rIncipJohn jpg',
#   'onderschrift': 'De rijkelijk versierde pagina die het begin vormt van het Evangelie volgens Johannes uit het Book of Kells folium 292r',
#   'altnaam': 'Book of Kells Boek van Columba',
#   'bewaarlocatie': 'Trinity College Library Dublin',
#   'datum ontstaan': '9e eeuw',
#   'type': 'Codex evangeliarium',
#   'inhoud': 'evangelie vier evangeliën van het Nieuwe Testament',
#   'auteur': 'Keltisch christendom Keltische monnik en',
#   'omvang': '340 Folio papierformaat folia 680 pagina s',
#   'materiaal': 'Folium blad Folium',
#   'taal': 'Hiberno Latijn',
#   'schrift': 'Insulair schrift',
#   'provenantie': 'Abdij van Kells',
#   'verdere details': 'Vulgaat Vetus Latina bronnen',
#   'extra portaal': 'Christendom'},
#  'Breakfast of Champions': {'naam': 'Ontbijt voor kampioenen',
#   'cover-op-enwp': 'BreakfastOfChampions Vonnegut jpg',
#   'orig titel': 'Breakfast of Champions or Goodbye Blue Monday',
#   'auteur': 'Kurt Vonnegut',
#   'land': 'VS',
#   'originele taal': 'Engels',
#   'uitgiftedatum origineel': '1973',
#   'paginas': '296',
#   'isbn': '0 385 28089 0',
#   'vorigeboek': 'Slachthuis vijf',
#   'volgendeboek': 'Slapstick boek Slapstick'},
#  'Brideshead Revisited': {'naam': 'Brideshead Revisited',
#   'afbeelding': 'Castle Howard Yorkshire jpg',
#   'onderschrift': 'Castle Howard waar de televisieserie en de film zijn opgenomen',
#   'auteur': 'Evelyn Waugh',
#   'land': 'Verenigd Koninkrijk Engeland',
#   'originele taal': 'Engels',
#   'uitgiftedatum': '2008',
#   'uitgiftedatum origineel': '1945',
#   'isbn': '978 0 1411 8248 3',
#   'film': 'Brideshead Revisited film Brideshead Revisited 2008'},
#  'Brave New World#Brave New World Revisited': {'naam': 'Het soma paradijs Heerlijke nieuwe wereld',
#   'orig titel': 'Brave New World',
#   'auteur': 'Aldous Huxley',
#   'land': 'GB',
#   'taal': 'Engels',
#   'genre': 'Sciencefiction'},
#  "Bridget Jones's Diary": {'titel': 'Bridget Jones Diary',
#   'première': '14 juli 2001',
#   'regie': 'Sharon Maguire',
#   'schrijver': 'Helen Fielding Andrew Davies Richard Curtis',
#   'producer': 'Helen Fielding Debra Hayward Liza Chasin',
#   'genre': 'Komedie',
#   'distributie': 'Miramax Universal Studio Canal',
#   'muziek': 'Patrick Doyle',
#   'land': 'US UK',
#   'taal': 'Engels',
#   'vervolg': 'Bridget Jones The Edge of Reason film Bridget Jones The Edge of Reason 2004',
#   'budget': '22 000 000',
#   'opbrengst': '281 929 795',
#   'imdb': '0243155',
#   'moviemeter': '171',
#   'lengte': '97 minuten',
#   'tagline': 'This Year s Resolutions Stop smoking Stop drinking Find inner poise Go to the gym three times a week Don t flirt with the boss Reduce thighs Learn to love thighs Forget about thighs Stop making lists',
#   'montage': 'Martin Walsh editor Martin Walsh'},
#  'Brave New World': {'naam': 'Het soma paradijs Heerlijke nieuwe wereld',
#   'orig titel': 'Brave New World',
#   'auteur': 'Aldous Huxley',
#   'land': 'GB',
#   'taal': 'Engels',
#   'genre': 'Sciencefiction'},
#  'Burmese Days': {'naam': 'De jaren in Birma',
#   'orig titel': 'Burmese Days',
#   'auteur': 'George Orwell',
#   'land': 'Verenigd Koninkrijk',
#   'taal': 'Engels',
#   'genre': 'Roman literatuur Roman',
#   'uitgever': 'Harper Brothers Verenigde Staten VS',
#   'uitgiftedatum': 'oktober 1934',
#   'medium': 'Print kaft pocketboek',
#   'isbn': '90 290 0089 9'},
#  'Cannery Row (novel)': {'naam': 'Een blik in Cannery Row',
#   'afbeelding': 'Cannery Row Sculpture 15398335477 jpg',
#   'onderschrift': 'Het Cannery Row Monument in Cannery Row Monterey Cannery Row met John Steinbeck boven Ed Ricketts rechts en diverse personages uit het boek',
#   'cover-op-enwp': 'CanneryRow jpg',
#   'orig titel': 'Cannery Row',
#   'auteur': 'John Steinbeck',
#   'vertaler': 'L I Brugmans Martens',
#   'land': 'US',
#   'originele taal': 'Engels',
#   'uitgever': 'Van Holkema Warendorf',
#   'originele uitgever': 'Viking Press',
#   'uitgiftedatum': '1948',
#   'uitgiftedatum origineel': 'januari 1945',
#   'film': 'Cannery Row film Cannery Row 1982',
#   'vervolg': 'Goede Donderdag',
#   'vorigeboek': 'De vliegenvanger',
#   'volgendeboek': 'De Parel',
#   'extra portaal': 'Amerikaanse literatuur'},
#  'Carrie (novel)': {'naam': 'Carrie',
#   'cover-op-enwp': 'Carrienovel jpg',
#   'auteur': 'Stephen King schrijver Stephen King',
#   'vertaler': 'Ingrid Nijkerk',
#   'land': 'US',
#   'taal': 'Engels',
#   'onderwerp': 'Coming of age genre Coming of age Pesten gedrag pesten religieus fundamentalisme misbruik telekinese',
#   'genre': 'Horror psychologische thriller',
#   'uitgever': 'Doubleday',
#   'uitgiftedatum': '5 april 1974',
# ...
#   'medium': 'pocketboek',
#   'paginas': '267',
#   'isbn': '90 6221 291 3',
#   'volgendeboek': 'Marune Sterrenwereld 933',
#   'extra portaal': 'Sciencefiction'},
#  'Troilus and Cressida': {'naam': 'Troilus en Cressida Troilus and Cressida',
#   'afbeelding': 'Houghton STC 22332 Troylus and Cresseid title jpg',
#   'onderschrift': 'Titelblad Troilus and Cressida 1609',
#   'schrijver': 'William Shakespeare',
#   'taal': 'Engels',
#   'eerste opvoering datum': '1609',
#   'soort': 'Tragedie toneel Tragedie historisch',
#   'aantal aktes': '5'},
#  'Ubik': {'naam': 'UBIK',
#   'ontwikkelaar': 'Cryo Interactive Entertainment Smart Dog PlayStation',
#   'uitgever': 'Cryo Interactive Entertainment R P Electronic Media Nederland',
#   'ontwerper': 'Philippe Nouhra Jean Luc Sala',
#   'muziek': 'Eric Los',
#   'uitgebracht': '1998',
#   'genre': 'Actiespel Actie en Strategiespel strategie',
#   'modes': 'Singleplayer',
#   'platform': 'PlayStation spelcomputer PlayStation Microsoft Windows'},
#  'Twilight (novel series)': {'titel': 'Twilight Saga',
#   'afbeelding': 'Twilight_Saga jpg',
#   'onderschrift': 'Twilight Saga',
#   'land': 'US',
#   'taal': 'Engels',
#   'genre': 'Jeugdliteratuur jeugdliteratuur Jeugdliteratuur Fantasy genre Fantasy Liefdesroman Romantiek',
#   'schrijver': 'Stephenie Meyer',
#   'uitgever': 'Little Brown and Company',
#   'eerste': '2005',
#   'laatste': '2010',
#   'lijst': 'Twilight roman Twilight Nieuwe maan roman Nieuwe Maan Eclips roman Eclips Morgenrood roman Morgenrood'},
#  'Treasure Island': {'naam': 'Schateiland',
#   'orig titel': 'Treasure Island',
#   'vertaler': 'Theun de Vries',
#   'afbeelding': 'Treasure Island Scribner s 1911 jpg',
#   'auteur': 'Robert Louis Stevenson',
#   'land': 'Schotland',
#   'taal': 'Engels',
#   'genre': 'Avontuur',
#   'uitgever': 'London Cassell and Company nu onderdeel van Orion Publishing Group',
#   'uitgiftedatum': '1883'},
#  'Unfinished Tales': {'naam': 'Nagelaten vertellingen',
#   'cover-op-enwp': 'UnfinishedTales JPG',
#   'orig titel': 'Unfinished Tales',
#   'auteur': 'J R R Tolkien',
#   'vertaler': 'Max Schuchart',
#   'originele taal': 'Engels',
#   'originele uitgever': 'Allen Unwin',
#   'uitgiftedatum': '1980',
#   'extra portaal': 'Fantasy'},
#  'VALIS': {'naam': 'VALIS',
#   'cover-op-enwp': 'VALIS 1stEd jpg',
#   'auteur': 'Philip K Dick',
#   'land': 'Verenigde Staten',
#   'taal': 'Engels',
#   'genre': 'autobiografie Autobiografische fictie',
#   'uitgever': 'Bantam Books',
#   'uitgiftedatum': '1981',
#   'paginas': '227',
#   'isbn': '0553141562',
#   'vervolg': 'The Divine Invasion',
#   'extra portaal': 'Sciencefiction'},
#  'Valley of the Dolls': {'titel': 'Valley of the Dolls De val naar de top',
#   'afbeelding': 'Valley_of_the_Dolls_ 1967 _still_1 jpg',
#   'onderschrift': 'Scène uit Valley of the Dolls',
#   'alternatieve titel': 'De val naar de top',
#   'regie': 'Mark Robson',
#   'producer': 'David Weisbart',
#   'schrijver': 'Helen Deutsch Dorothy Kingsley Jacqueline Susann roman',
#   'spelers': 'Barbara Parkins Patty Duke Sharon Tate',
#   'montage': 'Dorothy Spencer',
#   'cinematografie': 'William H Daniels',
#   'distributeur': '20th Century Fox',
#   'première': '15 december 1967',
#   'genre': 'Drama romantiek',
#   'lengte': '123 minuten',
#   'taal': 'Engels',
#   'land': 'US',
#   'budget': '5 000 000',
#   'nominaties': '5',
#   'vervolg': 'Beyond the Valley of the Dolls',
#   'remake': 'Jacqueline Susann s Valley of the Dolls',
#   'imdb': '0062430',
#   'moviemeter': '13889'},
#  'Vampire Academy': {'titel': 'Academicus Vampyrus',
#   'orig titel': 'Vampire Academy',
#   'afbeelding': 'Logo Vampire Academy Saga png',
#   'land': 'US',
#   'taal': 'Engels',
#   'genre': 'Jeugdliteratuur fantasy genre fantasie Liefdesroman romantiek',
#   'onderwerp': 'Vampiers',
#   'schrijver': 'Richelle Mead',
#   'uitgever': 'Penguin Group Razorbill',
#   'medium': 'Druk Pocketboek e reader Kindle Nook',
#   'eerste': '2007',
#   'laatste': '2010',
#   'website': 'http us penguingroup com static packages us yreaders vampireacademy index html',
#   'lijst': 'Academicus Vampyrus roman Academicus Vampyrus IJskoud roman IJskoud Schaduwkus Bloedbelofte Geestesband Offergave'},
#  'Voyage to the Bottom of the Sea (novel)': {'naam': 'Reis naar het diepste van de zee',
#   'orig titel': 'The voyage to the bottom of the sea',
#   'auteur': 'Theodore Sturgeon',
#   'vertaler': 'J H P J Willems',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'genre': 'Sciencefiction',
#   'uitgever': 'Het Spectrum',
#   'originele uitgever': 'Pyramid Publications',
#   'uitgiftedatum': '1967',
#   'uitgiftedatum origineel': '1961',
#   'medium': 'paperback',
#   'paginas': '187',
#   'extra portaal': 'Sciencefiction'},
#  'Vespasian': {'naam': 'Vespasianus',
#   'dominaat/principaat': 'principaat',
#   'afbeelding': 'Vespasianus02 pushkin jpg',
#   'tijdvak': 'Vierkeizerjaar en Flavische dynastie',
#   'voorganger': 'Aulus Vitellius princeps Vitellius 69',
#   'periode': '69 79',
#   'opvolger': 'Titus Flavius Titus 79 81',
#   'imperator': '69 79',
#   'geboortedatum': '9',
#   'sterfdatum': '79',
#   'geboortenaam': 'Titus Flavius Vespasianus',
#   'keizernaam': 'Vespasianus Augustus',
#   'ouders': 'Titus Flavius Sabinus vader van Vespasianus Titus Flavius Sabinus vader Vespasia Polla moeder',
#   'kinderen': 'Titus keizer Titus Titus Flavius Domitianus Domitianus Flavia Domitilla minor',
#   'vrouw': 'Flavia Domitilla maior Domitilla de Oudere',
#   'broer van': 'Titus Flavius Sabinus consul suffectus in 52 Titus Flavius Sabinus Flavia Vespasia'},
#  'Water for Elephants': {'titel': 'Water for Elephants',
#   'afbeelding': 'Water_For_Elephants_ _Logo jpg',
#   'poster-op-enwp': 'Water_for_Elephants_Poster jpg',
#   'regie': 'Francis Lawrence',
#   'producer': 'Fox 2000 Pictures 3 Arts Entertainment Flashpoint Entertainment Dune Entertainment Ingenious Media Big Screen Productions',
#   'schrijver': 'Sara Gruen boek Richard LaGravenese script',
#   'spelers': 'Robert Pattinson Reese Witherspoon Christoph Waltz',
#   'muziek': 'James Newton Howard',
#   'montage': 'Alan Edward Bell',
#   'production design': 'Jack Fisk',
#   'cinematografie': 'Rodrigo Prieto',
#   'distributeur': '20th Century Fox VS bioscoop',
#   'première': '22 april 2011 VS 4 mei 2011 België 5 mei 2011 Nederland',
#   'genre': 'romantische film dramafilm historische film',
#   'lengte': '120 min',
#   'taal': 'Engels',
#   'land': 'US',
#   'budget': '38 miljoen',
#   'opbrengst': '117 094 902',
#   'imdb': '1067583',
#   'moviemeter': '72655'},
#  'War and Peace': {'naam': 'Oorlog en vrede',
#   'afbeelding': 'Tolstoy War and Peace first edition 1869 jpg',
#   'afbeeldingbreedte': '200px',
#   'onderschrift': 'De kaft van de eerste editie van Oorlog en vrede 1869',
#   'orig titel': 'Vojna i Mir',
#   'auteur': 'Lev Tolstoj',
#   'land': 'RU',
#   'originele taal': 'Russisch',
#   'genre': 'roman',
#   'uitgiftedatum origineel': '1869'},
#  'Way Station (novel)': {'naam': 'Ruimtestation op Aarde',
#   'cover-op-enwp': 'Way_Station jpg',
#   'orig titel': 'Way station',
#   'auteur': 'Clifford D Simak',
#   'vertaler': 'J Willems',
#   'kaftontwerp': 'Karel Thole',
#   'land': 'Verenigde Staten',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'reeks': 'Bruna SF',
#   'genre': 'Sciencefiction',
#   'uitgever': 'A W Bruna Uitgevers',
#   'uitgiftedatum': '1978',
#   'uitgiftedatum origineel': '1963',
#   'medium': 'pocketboek',
#   'paginas': '240',
#   'grootte': '180 x 115',
#   'isbn': '90 229 9095 8',
#   'extra portaal': 'Sciencefiction'},
#  'Waiting for Godot': {'naam': 'Wachten op Godot',
#   'afbeelding': 'Poster for drama performance of Waiting for Godot jpg',
#   'schrijver': 'Samuel Beckett',
#   'eerste opvoering datum': '5 januari 1953',
#   'taal': 'Frans',
#   'onderschrift': 'poster voor opvoering van Wachten op Godot met Lucky en Pozzo op de voorgrond',
#   'aantal aktes': 'twee',
#   'eerste opvoering waar': 'Théâtre de Babylone Parijs',
#   'soort': 'Tragikomedie'},
#  'Wee Willie Winkie': {'titel': 'Wee Willie Winkie',
#   'afbeelding': 'Illustrated front cover from The Queenslander December 1 1937 12468547293 jpg',
#   'onderschrift': 'Voorpagina van The Queenslander om de film te promoten in Australië',
#   'regie': 'John Ford regisseur John Ford',
#   'producer': 'Gene Markey',
#   'schrijver': 'Ernest Pascal Julien Josephson Rudyard Kipling novelle',
#   'spelers': 'Shirley Temple Victor McLaglen C Aubrey Smith',
#   'muziek': 'Alfred Newman',
#   'montage': 'Walter Thompson',
#   'cinematografie': 'Arthur C Miller',
#   'distributeur': '20th Century Fox',
#   'première': '25 juni 1937',
#   'genre': 'Avontuur',
#   'lengte': '100 minuten',
#   'taal': 'Engels',
#   'land': 'US',
#   'budget': '1 000 000',
#   'imdb': '0029751',
#   'moviemeter': '16101'},
#  'Watchmen': {'titel': 'Watchmen',
#   'afbeelding': 'Watchmen_logo svg',
#   'land': 'Verenigd Koninkrijk Verenigde Staten',
#   'taal': 'Engels',
#   'genre': 'Superheld',
#   'schrijver': 'Alan Moore',
#   'tekenaar': 'Dave Gibbons',
#   'publicatie': 'stripbladen',
#   'status': 'gestopt',
#   'eerste': '1986',
#   'laatste': '1987'},
#  'Watership Down': {'naam': 'Waterschapsheuvel',
#   'orig titel': 'Watership Down',
#   'auteur': 'Richard Adams',
#   'uitgiftedatum': '1972',
#   'isbn': '9027408114',
#   'vervolg': 'Verhalen uit Waterschapsheuvel'},
#  'We (novel)': {'naam': 'Wij',
#   'orig titel': 'мы',
#   'auteur': 'Jevgeni Zamjatin',
#   'land': 'Rusland',
#   'originele taal': 'Russisch',
#   'uitgiftedatum origineel': '1920'},
#  'When Worlds Collide': {'titel': 'When Worlds Collide Als de wereld vergaat',
#   'afbeelding': 'When_Worlds_Collide_ 1951 _trailer_1 jpg',
#   'onderschrift': 'Scène uit When Worlds Collide',
#   'regie': 'Rudolph Maté',
#   'producer': 'George Pal',
#   'schrijver': 'Edwin Balmer Sydney Boehm Philip Wylie',
#   'spelers': 'Richard Derr Barbara Rush Peter Hansen acteur Peter Hansen',
#   'muziek': 'Leith Stevens',
#   'cinematografie': 'W Howard Greene John F Seitz',
#   'distributeur': 'Paramount Pictures',
#   'première': '1951',
#   'genre': 'sciencefiction',
#   'lengte': '83 minuten',
#   'taal': 'Engels',
#   'land': 'US',
#   'budget': '936 000',
#   'nominaties': '1952 Oscars beste camerawerk',
#   'prijzen': '1952 Oscars beste speciale effecten',
#   'moviemeter': '11303',
#   'imdb': '0044207'},
#  'White Oleander': {'titel': 'White Oleander',
#   'tagline': 'Where does a mother end and a daughter begin',
#   'regie': 'Peter Kosminsky',
#   'producer': 'Hunt Lowry John Wells',
#   'schrijver': 'Mary Agnes Donoghue Janet Fitch boek',
#   'spelers': 'Alison Lohman Michelle Pfeiffer Renée Zellweger',
#   'muziek': 'Thomas Newman',
#   'montage': 'Chris Ridsdale',
#   'cinematografie': 'Elliot Davis',
#   'distributeur': 'Warner Bros Pictures',
#   'première': 'CA VLAG 6 september 2002 BE VLAG 23 april 2003 NL VLAG 19 juni 2003',
#   'genre': 'Dramafilm Drama',
#   'lengte': '109 min',
#   'ratio': '1 85 1',
#   'taal': 'Engels',
#   'land': 'US DE',
#   'budget': '16 000 000 Amerikaanse dollar USD',
#   'opbrengst': '21 670 000 USD',
#   'nominaties': '4',
#   'prijzen': '3',
#   'imdb': '0283139',
#   'moviemeter': '4638'},
#  'Who? (novel)': {'naam': 'Metalen man uit Rusland',
#   'cover-op-enwp': 'Who 1stEd jpg',
#   'orig titel': 'Who',
#   'auteur': 'Algis Budrys',
#   'vertaler': 'Frank Visser',
#   'kaftontwerp': 'Alex Jagtenberg',
#   'land': 'US',
#   'taal': 'Nederlands',
#   'originele taal': 'Engels',
#   'reeks': 'Born SF',
#   'genre': 'sciencefiction',
#   'uitgever': 'Born',
#   'uitgiftedatum': '1970',
#   'uitgiftedatum origineel': '1958',
#   'medium': 'pocket',
#   'paginas': '189',
#   'film': 'Who',
#   'extra portaal': 'Sciencefiction'},
#  "Winter's Heart": {'naam': 'Hart van de Winter',
#   'orig titel': 'Winter s Heart',
#   'reeks': 'Het Rad des Tijds',
#   'auteur': 'Robert Jordan auteur Robert Jordan',
#   'vertaler': 'Jo Thomas en Johan Martijn Flaton',
#   'uitgever': 'Luitingh Sijthoff',
#   'originele uitgever': 'Tor Books',
#   'uitgiftedatum': '2001',
#   'uitgiftedatum origineel': '7 november 2000',
#   'genre': 'Fantasy genre Fantasy',
#   'paginas': '607 blz',
#   'isbn': '9024538637',
#   'voorafgegaan': 'Het Pad der Dolken',
#   'vervolg': 'Viersprong van de Schemer'},
#  'Wise Blood': {'titel': 'Wise Blood',
#   'regie': 'John Huston regisseur John Huston',
#   'producer': 'Kathy Fitzgerald Michael Fitzgerald filmproducent Michael Fitzgerald',
#   'schrijver': 'Benedict Fitzgerald Flannery O Connor roman',
#   'spelers': 'Brad Dourif John Huston regisseur John Huston Dan Shor',
#   'muziek': 'Alex North',
#   'montage': 'Roberto Silvi',
#   'cinematografie': 'Gerry Fisher',
#   'distributeur': 'New Line Cinema',
#   'première': '24 oktober 1979',
#   'genre': 'Drama',
#   'lengte': '108 minuten',
#   'taal': 'Engels',
#   'land': 'US DE 1949 WD',
#   'budget': '1 000 000',
#   'imdb': '0080140',
#   'moviemeter': '3313'},
#  "Wizard's First Rule": {'naam': 'Het zwaard van de waarheid',
#   'reeks': 'De wetten van de magie',
#   'auteur': 'Terry Goodkind',
#   'vertaler': 'Max Schuchart',
#   'uitgever': 'Luitingh Sijthoff',
#   'orig titel': 'Wizard s First Rule',
#   'uitgiftedatum': '1996 Origineel 1995',
#   'genre': 'Fantasy genre Fantasy',
#   'paginas': '784 blz',
#   'isbn': '9024523427',
#   'voorafgegaan': 'De aflossing',
#   'vervolg': 'Steen der tranen'},
#  'Wyrd Sisters': {'naam': 'De plaagzusters',
#   'reeks': 'Schijfwereld',
#   'auteur': 'Terry Pratchett',
#   'vertaler': 'Venugopalan Ittekot',
#   'uitgever': 'Het Spectrum',
#   'orig titel': 'Wyrd Sisters',
#   'uitgiftedatum': '1988 1993',
#   'genre': 'Fantasy genre Fantasy',
#   'paginas': '233 blz',
#   'isbn': '9027431639',
#   'voorafgegaan': 'Betoverkind',
#   'vervolg': 'Pyramides'},
#  'World War Z': {'titel': 'World War Z',
#   'poster-op-enwp': 'World War Z poster jpg',
#   'tagline': 'Remember Philly',
#   'regie': 'Marc Forster',
#   'producer': 'Ian Bryce Dede Gardner Jeremy Kleiner Brad Pitt',
#   'prodmaatschappij': 'Paramount Pictures Skydance Media',
#   'schrijver': 'Boek Max Brooks Scenario Matthew Michael Carnahan J Michael Straczynski Draaiboek Matthew Michael Carnahan Drew Goddard Damon Lindelof',
#   'spelers': 'Brad Pitt',
#   'muziek': 'Marco Beltrami',
#   'cinematografie': 'Ben Seresin',
#   'distributeur': 'Paramount Pictures United International Pictures',
#   'première': 'UK VLAG 2 juni 2013 wereldpremière BE VLAG 3 juli 2013 NL VLAG 4 juli 2013',
#   'genre': 'Horrorfilm Horror Actiefilm actie',
#   'lengte': '116 min',
#   'taal': 'Engels Spaans Hebreeuws',
#   'land': 'US',
#   'budget': 'Amerikaanse dollar US 190 miljoen',
#   'opbrengst': 'US 540 miljoen',
#   'nominaties': '18',
#   'prijzen': '4',
#   'imdb': '0816711',
#   'moviemeter': '90206'},
#  'Your Name (novel)': {'titel': 'Your Name',
#   'afbeelding': 'Your name movie logo svg',
#   'beschrijving': 'Titel van Your Name',
#   'ja_naam': '君の名は',
#   'ja_naam_trans': 'Kimi no Na wa',
#   'genre': 'Drama genre Drama Fantasy genre Fantasy'},
#  'Wuthering Heights': {'naam': 'Woeste hoogten',
#   'orig titel': 'Wuthering Heights',
#   'afbeelding': 'Houghton Lowell 1238 5 A Wuthering Heights 1847 jpg',
#   'onderschrift': 'Titelpagina',
#   'auteur': 'Emily Brontë',
#   'land': 'Verenigd Koninkrijk',
#   'taal': 'Engels',
#   'genre': 'Roman literatuur Roman gothic novel',
#   'uitgever': 'Thomas Cautley Newby',
#   'uitgiftedatum': '1847',
#   'paginas': '416',
#   'isbn': '0141023546'},
#  'You Only Live Twice (novel)': {'naam': 'You Only Live Twice Je Leeft Maar Twee Maal',
#   'cover-op-enwp': 'You_Only_Live_Twice Ian_Fleming jpg',
#   'auteur': 'Ian Fleming',
#   'vertaler': 'O Falk',
#   'kaftontwerp': 'Richard Chopping',
#   'land': 'Verenigd Koninkrijk Groot Brittannië',
#   'taal': 'Engels',
#   'reeks': 'James Bond mediafranchise James Bond',
#   'paginas': '224',
#   'genre': 'Spionage',
#   'uitgever': 'Glidrose Productions',
#   'originele uitgever': 'Jonathan Cape',
#   'uitgiftedatum': '16 maart 1964',
#   'voorafgegaan': 'On Her Majesty s Secret Service roman On Her Majesty s Secret Service',
#   'vervolg': 'The Man with the Golden Gun roman The Man With The Golden Gun',
#   'film': 'You Only Live Twice film You Only Live Twice'},
#  'Zero no Tsukaima': {'titel': 'Zero no Tsukaima',
#   'afbeelding': 'Zero no Tsukaima logo png',
#   'beschrijving': 'Japans Logo',
#   'ja_naam': 'ゼロの使い魔',
#   'ja_naam_trans': 'Zero no Tsukaima',
#   'doelgroep': 'Seinen manga Seinen',
#   'genre': 'Avonturenroman Avontuur Fantasy genre Fantasie Romantische komedie'}}

# %%
with open('data/nl_infoboxes_clean.pickle', 'wb') as f:
    pickle.dump(nl_infoboxes, f)

with open('data/en_infoboxes_clean.pickle', 'wb') as f:
    pickle.dump(en_infoboxes, f)

# %%
both_available = en_infoboxes.keys() & nl_infoboxes.keys()

# %%
for k, v in nl_infoboxes.items():
    for k1, v1 in v.items():
        if '[' in v:
            print(v)

# %%
len(en_infoboxes)
# Out:
# 4227

# %%
len(both_available)
# Out:
# 703

# %%
# use a set so we only keep track of unique mappings
matches = {
    'exact_key': set(),
    'full_match': set(),
    'partial_match': set(),
}

for key in both_available:
    for nl_k, nl_v in nl_infoboxes[key].items():
        for en_k, en_v in en_infoboxes[key].items():
            nl_k = nl_k.lower()
            en_k = en_k.lower()
            result = (en_k, nl_k)

            # TODO hier keys groeperen die dezelfde waarden hebben
            # zodat [isbn, issn] samenkomen of
            # [uitgeverij, originele uitgever, uitgever]
            # beide kanten op kijken of je al bestaande keys hebt voor het nl en
            # en

            if nl_k == en_k:
                matches['exact_key'].add(result)
            elif nl_v == en_v:
                matches['full_match'].add(result)
            elif (nl_v in en_v) or (en_v in nl_v):
                matches['partial_match'].add(result)

print(len(matches))
# Out:
# 3

# %%
matches
# Out:
# {'exact_key': {('awards', 'awards'),
#   ('budget', 'budget'),
#   ('editing', 'editing'),
#   ('english_pub_date', 'english_pub_date'),
#   ('fusiongenres', 'fusiongenres'),
#   ('genre', 'genre'),
#   ('illustrator', 'illustrator'),
#   ('isbn', 'isbn'),
#   ('name', 'name'),
#   ('producer', 'producer'),
#   ('setting', 'setting'),
#   ('subgenres', 'subgenres'),
#   ('taxon', 'taxon'),
#   ('website', 'website')},
#  'full_match': {('alt', 'naam'),
#   ('artist', 'tekenaar'),
#   ('author', 'auteur'),
#   ('author', 'illustraties'),
#   ('author', 'naam'),
#   ('author', 'onderschrift'),
#   ('author', 'schrijfster'),
#   ('author', 'schrijver'),
#   ('birth_name', 'geboortenaam'),
#   ('birth_name', 'volledige naam'),
#   ('birth_name', 'volledigenaam'),
#   ('book', 'boek'),
#   ('caption', 'titel'),
#   ('cinematography', 'cinematografie'),
#   ('country', 'land'),
#   ('cover_artist', 'auteur'),
#   ('cover_artist', 'cover-op-enwp'),
#   ('cover_artist', 'illustraties'),
#   ('cover_artist', 'kaftontwerp'),
#   ('creator', 'auteur'),
#   ('creator', 'bedenker'),
#   ('creator', 'scenario'),
#   ('creator', 'tekenaar'),
#   ('date', 'eerstedruk'),
#   ('date', 'laatste'),
#   ('date of issue', 'uitgiftedatum'),
#   ('director', 'producer'),
#   ('director', 'regie'),
#   ('director', 'schrijver'),
#   ('distributor', 'distributeur'),
#   ('distributor', 'prodmaatschappij'),
#   ('editing', 'montage'),
#   ('english_release_date', 'uitgiftedatum'),
#   ('followed_by', 'vervolg'),
#   ('followed_by', 'volgendeboek'),
#   ('foreigntitle', 'orig titel'),
#   ('full title', 'orig titel'),
#   ('genre', 'extra portaal'),
#   ('gross', 'opbrengst'),
#   ('illustrator', 'auteur'),
#   ('illustrator', 'illustraties'),
#   ('illustrator', 'kaftontwerp'),
#   ('image', 'afbeelding'),
#   ('image', 'cover-op-enwp'),
#   ('image', 'poster-op-enwp'),
#   ('isbn', 'issn'),
#   ('ja_kanji', 'ja_naam'),
#   ('ja_romaji', 'ja_naam_trans'),
#   ('ja_romaji', 'titel'),
#   ('lyrics', 'muziek'),
#   ('lyrics', 'tekst'),
#   ('media_type', 'medium'),
#   ('music', 'muziek'),
#   ('music', 'tekst'),
#   ('name', 'band_naam'),
#   ('name', 'beter-bekend-als'),
#   ('name', 'extra portaal'),
#   ('name', 'film'),
#   ('name', 'naam'),
#   ('name', 'onderschrift'),
#   ('name', 'orig titel'),
#   ('name', 'portaal2'),
#   ('name', 'titel'),
#   ('name', 'titelweergave'),
#   ('name', 'volledige naam'),
#   ('name', 'w-naam'),
#   ('native_name', 'volledigenaam'),
#   ('native_wikisource', 'naam'),
#   ('native_wikisource', 'orig titel'),
#   ('network', 'netwerk'),
#   ('num_episodes', 'afleveringen'),
#   ('num_seasons', 'seizoenen'),
#   ('number_of_books', 'nominaties'),
#   ('number_of_books', 'volgnummer'),
#   ('origpublication', 'titel'),
#   ('pages', 'paginas'),
#   ('preceded_by', 'voorafgegaan'),
#   ('preceded_by', 'vorigeboek'),
#   ('predecessor', 'voorganger'),
#   ('presenter', 'presentatie'),
#   ('producer', 'regie'),
#   ('pub_date', 'jaren-actief'),
#   ('pub_date', 'uitgiftedatum'),
#   ('pub_date', 'uitgiftedatum origineel'),
#   ('published', 'uitgiftedatum'),
#   ('published', 'uitgiftedatum origineel'),
#   ('published_in', 'originele uitgever'),
#   ('publisher', 'originele uitgever'),
#   ('publisher', 'uitgever'),
#   ('publisher', 'uitgeverij'),
#   ('release_date', 'uitgiftedatum'),
#   ('release_date', 'uitgiftedatum origineel'),
#   ('screenplay', 'schrijver'),
#   ('series', 'extra portaal'),
#   ('series', 'film'),
#   ('series', 'naam'),
#   ('series', 'onderwerp'),
#   ('series', 'orig titel'),
#   ('series', 'reeks'),
#   ('signature', 'handtekening'),
#   ('starring', 'spelers'),
#   ('studio', 'distributeur'),
#   ('studio', 'prodmaatschappij'),
#   ('successor', 'opvolger'),
#   ('taxon', 'naam'),
#   ('taxon', 'titelweergave'),
#   ('taxon', 'w-naam'),
#   ('title', 'titel'),
#   ('title_orig', 'naam'),
#   ('title_orig', 'orig titel'),
#   ('transdate', 'eerstedruk'),
#   ('wikisource', 'naam'),
#   ('wikisource', 'orig titel'),
#   ('writer', 'auteur'),
#   ('writer', 'regie'),
#   ('writer', 'schrijver')},
#  'partial_match': {('alias', 'schrijver'),
#   ('alias', 'titel'),
#   ('alt', 'afbeelding'),
#   ('alt', 'auteur'),
#   ('alt', 'extra portaal'),
#   ('alt', 'naam'),
#   ('alt', 'orig titel'),
#   ('alt', 'prijzen'),
#   ('alt', 'titel'),
#   ('alt', 'tv_com'),
#   ('alternative title(s)', 'naam'),
#   ('artist', 'artiest'),
#   ('author', 'afbeelding'),
#   ('author', 'auteur'),
#   ('author', 'bronmateriaal'),
#   ('author', 'cover-op-enwp'),
#   ('author', 'film'),
#   ('author', 'illustraties'),
#   ('author', 'kaftontwerp'),
#   ('author', 'onderschrift'),
#   ('author', 'producer'),
#   ('author', 'remake'),
#   ('author', 'schrijver'),
#   ('author', 'vervolg'),
#   ('author', 'voorafgegaan'),
#   ('author', 'vorigeboek'),
#   ('author', 'website'),
#   ('author(s)', 'auteur'),
#   ('awards', 'uitgiftedatum'),
#   ('based_on', 'titel'),
#   ('birth_date', 'geboortedatum'),
#   ('birth_date', 'nominaties'),
#   ('birth_date', 'prijzen'),
#   ('birth_name', 'naam'),
#   ('birth_name', 'volledigenaam'),
#   ('birth_place', 'geboorteplaats'),
#   ('books', 'eerste'),
#   ('books', 'extra portaal'),
#   ('books', 'laatste'),
#   ('books', 'orig titel'),
#   ('books', 'schrijver'),
#   ('books', 'titel'),
#   ('books', 'uitgever'),
#   ('books', 'volgnummer'),
#   ('border', 'uitgiftedatum'),
#   ('border', 'vertaler'),
#   ('budget', 'nominaties'),
#   ('budget', 'prijzen'),
#   ('caption', 'afbeelding'),
#   ('caption', 'auteur'),
#   ('caption', 'band_naam'),
#   ('caption', 'eerste'),
#   ('caption', 'illustraties'),
#   ('caption', 'ja_naam_trans'),
#   ('caption', 'land'),
#   ('caption', 'naam'),
#   ('caption', 'nominaties'),
#   ('caption', 'onderschrift'),
#   ('caption', 'orig titel'),
#   ('caption', 'originele uitgever'),
#   ('caption', 'prijzen'),
#   ('caption', 'reeks'),
#   ('caption', 'tekenaar'),
#   ('caption', 'titel'),
#   ('caption', 'uitgever'),
#   ('caption', 'uitgiftedatum'),
#   ('caption', 'uitgiftedatum origineel'),
#   ('caption', 'vervolg'),
#   ('caption', 'voorafgegaan'),
#   ('caption', 'vorigeboek'),
#   ('channel', 'netwerk'),
#   ('children', 'geboortedatum'),
#   ('children', 'onderschrift'),
#   ('cinematography', 'cinematografie'),
#   ('company', 'seizoenen'),
#   ('congress', 'nominaties'),
#   ('congress', 'prijzen'),
#   ('congress', 'uitgiftedatum'),
#   ('congress', 'uitgiftedatum origineel'),
#   ('congress', 'vorigeboek'),
#   ('country', 'budget'),
#   ('country', 'distributeur'),
#   ('country', 'land'),
#   ('country', 'onderwerp'),
#   ('country', 'schrijver'),
#   ('country', 'taal'),
#   ('country', 'titel'),
#   ('country', 'vervolg'),
#   ('country', 'voorafgegaan'),
#   ('country', 'vorigeboek'),
#   ('cover', 'titel'),
#   ('cover_artist', 'auteur'),
#   ('cover_artist', 'illustraties'),
#   ('cover_artist', 'kaftontwerp'),
#   ('cover_artist', 'originele uitgever'),
#   ('cover_artist', 'uitgever'),
#   ('cover_artist', 'vervolg'),
#   ('cover_artist', 'voorafgegaan'),
#   ('creator', 'auteur'),
#   ('creator', 'bedenker'),
#   ('creator', 'muziek'),
#   ('creator', 'onderschrift'),
#   ('creator', 'presentatie'),
#   ('creator', 'tekenaar'),
#   ('current_members', 'lid1'),
#   ('current_members', 'lid2'),
#   ('date', 'eerste'),
#   ('date', 'laatste'),
#   ('date of issue', 'oplage'),
#   ('death_date', 'geboortedatum'),
#   ('death_date', 'nominaties'),
#   ('death_date', 'prijzen'),
#   ('death_date', 'sterfdatum'),
#   ('death_place', 'overlijdensplaats'),
#   ('death_place', 'sterfplaats'),
#   ('developer', 'bedenker'),
#   ('dewey', 'moviemeter'),
#   ('dewey', 'nominaties'),
#   ('dewey', 'onderschrift'),
#   ('dewey', 'première'),
#   ('dewey', 'prijzen'),
#   ('dewey', 'spelers'),
#   ('dewey', 'taal'),
#   ('dewey', 'vorigeboek'),
#   ('director', 'producer'),
#   ('director', 'regie'),
#   ('director', 'schrijver'),
#   ('director', 'spelers'),
#   ('disappeared_date', 'nominaties'),
#   ('disappeared_date', 'prijzen'),
#   ('distributor', 'distributeur'),
#   ('distributor', 'netwerk'),
#   ('distributor', 'verdeler'),
#   ('editing', 'montage'),
#   ('editor', 'auteur'),
#   ('english_pub_date', 'eerste'),
#   ('english_pub_date', 'illustraties'),
#   ('english_pub_date', 'laatste'),
#   ('english_pub_date', 'onderschrift'),
#   ('english_pub_date', 'uitgiftedatum'),
#   ('executive_producer', 'bedenker'),
#   ('executive_producer', 'producer'),
#   ('executive_producer', 'seizoenen'),
#   ('external_url', 'orig titel'),
#   ('family', 'naam'),
#   ('family', 'onderschrift'),
#   ('family', 'prijzen'),
#   ('father', 'geboortenaam'),
#   ('father', 'naam'),
#   ('father', 'ouders'),
#   ('first', 'eerste'),
#   ('first', 'naam'),
#   ('first', 'onderschrift'),
#   ('first', 'uitgiftedatum origineel'),
#   ('first', 'volledige naam'),
#   ('followed by', 'orig titel'),
#   ('followed by', 'titel'),
#   ('followed_by', 'auteur'),
#   ('followed_by', 'extra portaal'),
#   ('followed_by', 'naam'),
#   ('followed_by', 'onderwerp'),
#   ('followed_by', 'orig titel'),
#   ('followed_by', 'reeks'),
#   ('followed_by', 'titel'),
#   ('followed_by', 'uitgiftedatum'),
#   ('followed_by', 'uitgiftedatum origineel'),
#   ('followed_by', 'vervolg'),
#   ('followed_by', 'volgendeboek'),
#   ('followed_by', 'voorafgegaan'),
#   ('followed_by', 'voorloper'),
#   ('followed_by', 'vorigeboek'),
#   ('footnotes', 'naam'),
#   ('full name', 'geboortenaam'),
#   ('full name', 'naam'),
#   ('genre', 'afbeelding'),
#   ('genre', 'band_naam'),
#   ('genre', 'extra portaal'),
#   ('genre', 'ja_naam'),
#   ('genre', 'onderwerp'),
#   ('genre', 'orig titel'),
#   ('genre', 'originele taal'),
#   ('genre', 'titel'),
#   ('genre', 'uitgiftedatum'),
#   ('genre', 'vervolg'),
#   ('genre', 'voorafgegaan'),
#   ('genre', 'vorigeboek'),
#   ('gross', 'land'),
#   ('gross', 'nominaties'),
#   ('gross', 'prijzen'),
#   ('honorific_prefix', 'extra portaal'),
#   ('illustrator', 'afbeelding'),
#   ('illustrator', 'film'),
#   ('illustrator', 'illustraties'),
#   ('illustrator', 'kaftontwerp'),
#   ('illustrator', 'producer'),
#   ('illustrator', 'schrijver'),
#   ('image', 'afbeelding'),
#   ('image', 'auteur'),
#   ('image', 'band_naam'),
#   ('image', 'cover-op-enwp'),
#   ('image', 'extra portaal'),
#   ('image', 'film'),
#   ('image', 'land'),
#   ('image', 'naam'),
#   ('image', 'onderschrift'),
#   ('image', 'orig titel'),
#   ('image', 'producer'),
#   ('image', 'reeks'),
#   ('image', 'schrijfster'),
#   ('image', 'schrijver'),
#   ('image', 'titel'),
#   ('image', 'titelweergave'),
#   ('image', 'uitgiftedatum'),
#   ('image', 'uitgiftedatum origineel'),
#   ('image', 'vchinees'),
#   ('image', 'vervolg'),
#   ('image', 'volgnummer'),
#   ('image', 'volledige naam'),
#   ('image', 'volledigenaam'),
#   ('image', 'voorafgegaan'),
#   ('image', 'vorigeboek'),
#   ('image', 'w-naam'),
#   ('image_caption', 'naam'),
#   ('image_caption', 'onderschrift'),
#   ('image_caption', 'orig titel'),
#   ('image_caption', 'schrijver'),
#   ('image_caption', 'titel'),
#   ('image_caption', 'titelweergave'),
#   ('image_caption', 'uitgiftedatum'),
#   ('image_caption', 'w-naam'),
#   ('isbn', 'afleveringen'),
#   ('isbn', 'nominaties'),
#   ('isbn', 'paginas'),
#   ('isbn', 'prijzen'),
#   ('isbn', 'seizoenen'),
#   ('isbn', 'vervolg'),
#   ('isbn', 'voorafgegaan'),
#   ('isbn', 'vorigeboek'),
#   ('isbn_note', 'land'),
#   ('isbn_note', 'vervolg'),
#   ('isbn_note', 'voorafgegaan'),
#   ('isbn_note', 'vorigeboek'),
#   ('issue', 'kinderen'),
#   ('issue', 'naam'),
#   ('ja_kanji', 'ja_naam'),
#   ('ja_romaji', 'afbeelding'),
#   ('ja_romaji', 'ja_naam_trans'),
#   ('label', 'record_label'),
#   ('language', 'film'),
#   ('language', 'land'),
#   ('language', 'naam'),
#   ('language', 'orig titel'),
#   ('language', 'verdere details'),
#   ('language', 'vervolg'),
#   ('language', 'voorafgegaan'),
#   ('language', 'vorigeboek'),
#   ('last', 'naam'),
#   ('last', 'onderschrift'),
#   ('list_episodes', 'titel'),
#   ('media_type', 'afbeelding'),
#   ('media_type', 'isbntoelichting'),
#   ('media_type', 'medium'),
#   ('media_type', 'uitgiftedatum'),
#   ('media_type', 'vervolg'),
#   ('media_type', 'voorafgegaan'),
#   ('media_type', 'vorigeboek'),
#   ('mother', 'ouders'),
#   ('music', 'muziek'),
#   ('music', 'regie'),
#   ('music', 'schrijver'),
#   ('mute', 'afbeelding'),
#   ('mute', 'naam'),
#   ('mute', 'onderschrift'),
#   ('name', 'afbeelding'),
#   ('name', 'afleveringen'),
#   ('name', 'bekende-werken'),
#   ('name', 'beschrijving'),
#   ('name', 'bronmateriaal'),
#   ('name', 'cover-op-enwp'),
#   ('name', 'eerste'),
#   ('name', 'extra portaal'),
#   ('name', 'film'),
#   ('name', 'genre'),
#   ('name', 'handtekening'),
#   ('name', 'huidige'),
#   ('name', 'lijst'),
#   ('name', 'muziek'),
#   ('name', 'naam'),
#   ('name', 'nominaties'),
#   ('name', 'onderschrift'),
#   ('name', 'onderwerp'),
#   ('name', 'orig titel'),
#   ('name', 'poster-op-enwp'),
#   ('name', 'reeks'),
#   ('name', 'remake'),
#   ('name', 'schrijver'),
#   ('name', 'serie'),
#   ('name', 'tagline'),
#   ('name', 'titel'),
#   ('name', 'uitgever'),
#   ('name', 'vervolg'),
#   ('name', 'volgendeboek'),
#   ('name', 'volledige naam'),
#   ('name', 'voorafgegaan'),
#   ('name', 'vorigeboek'),
#   ('narrator', 'spelers'),
#   ('nationality', 'afbeelding'),
#   ('nationality', 'groep'),
#   ('native_name', 'naam'),
#   ('native_wikisource', 'auteur'),
#   ('native_wikisource', 'naam'),
#   ('native_wikisource', 'orig titel'),
#   ('native_wikisource', 'tchinees'),
#   ('network', 'netwerk'),
#   ('next-date', 'volgnummer'),
#   ('next_year', 'volgende album'),
#   ('nickname', 'cover-op-enwp'),
#   ('nickname', 'film'),
#   ('nickname', 'naam'),
#   ('nickname', 'orig titel'),
#   ('notable_ideas', 'volledige naam'),
#   ('notes', 'titel'),
#   ('num_episodes', 'afleveringen'),
#   ('num_episodes', 'website'),
#   ('num_seasons', 'afleveringen'),
#   ('num_seasons', 'einde'),
#   ('num_seasons', 'imdb'),
#   ('num_seasons', 'start'),
#   ('num_seasons', 'website'),
#   ('number_of_books', 'eerste'),
#   ('number_of_books', 'isbn'),
#   ('number_of_books', 'jaren-actief'),
#   ('number_of_books', 'laatste'),
#   ('number_of_books', 'lengte'),
#   ('number_of_books', 'lijst'),
#   ('number_of_books', 'uitgiftedatum'),
#   ('number_of_books', 'volgnummer'),
#   ('oclc', 'afleveringen'),
#   ('oclc', 'nominaties'),
#   ('oclc', 'prijzen'),
#   ('oclc', 'seizoenen'),
#   ('oclc', 'vervolg'),
#   ('oclc', 'voorafgegaan'),
#   ('oclc', 'vorigeboek'),
#   ('orig_lang_code', 'afbeelding'),
#   ('orig_lang_code', 'onderwerp'),
#   ('orig_lang_code', 'pinyin'),
#   ('orig_lang_code', 'taal'),
#   ('origdate', 'eerste'),
#   ('origdate', 'eerstedruk'),
#   ('origdate', 'laatste'),
#   ('origdate', 'paginas'),
#   ('origdate', 'volgnummer'),
#   ('origpublication', 'afbeelding'),
#   ('other_names', 'naam'),
#   ('other_names', 'volledige naam'),
#   ('other_topics', 'naam'),
#   ('other_topics', 'portaal2'),
#   ('pages', 'nominaties'),
#   ('pages', 'paginas'),
#   ('pages', 'prijzen'),
#   ('pages', 'uitgiftedatum origineel'),
#   ('pages', 'vervolg'),
#   ('pages', 'voorafgegaan'),
#   ('pages', 'vorigeboek'),
#   ('portrayer', 'naam'),
#   ('portrayer', 'spelers'),
#   ('portrayer', 'titel'),
#   ('preceded by', 'orig titel'),
#   ('preceded_by', 'cover-op-enwp'),
#   ('preceded_by', 'extra portaal'),
#   ('preceded_by', 'orig titel'),
#   ('preceded_by', 'reeks'),
#   ('preceded_by', 'uitgiftedatum origineel'),
#   ('preceded_by', 'vervolg'),
#   ('preceded_by', 'voorafgegaan'),
#   ('preceded_by', 'voorloper'),
#   ('preceded_by', 'vorigeboek'),
#   ('predecessor', 'adoptief ouders'),
#   ('predecessor', 'broer van'),
#   ('predecessor', 'caesar onder'),
#   ('predecessor', 'geboortenaam'),
#   ('predecessor', 'keizernaam'),
#   ('predecessor', 'oom van'),
#   ('predecessor', 'voorganger'),
#   ('predecessor', 'vrouw'),
#   ('premiere', 'aantal aktes'),
#   ('premiere', 'eerste opvoering datum'),
#   ('presenter', 'bedenker'),
#   ('presenter', 'onderschrift'),
#   ('prev_year', 'jaar'),
#   ('prev_year', 'vorige album'),
#   ('previous', 'volgnummer'),
#   ('producer', 'extra portaal'),
#   ('producer', 'poster-op-enwp'),
#   ('producer', 'regie'),
#   ('producer', 'schrijver'),
#   ('pub_date', 'afbeelding'),
#   ('pub_date', 'datum'),
#   ('pub_date', 'eerste'),
#   ('pub_date', 'jaren-actief'),
#   ('pub_date', 'laatste'),
#   ('pub_date', 'orig titel'),
#   ('pub_date', 'orig verschenen'),
#   ('pub_date', 'prijzen'),
#   ('pub_date', 'titel'),
#   ('pub_date', 'uitgiftedatum'),
#   ('pub_date', 'uitgiftedatum origineel'),
#   ('pub_date', 'volgnummer'),
#   ('published', 'land'),
#   ('published', 'naam'),
#   ('published', 'originele uitgever'),
#   ('published', 'uitgever'),
#   ('published', 'uitgiftedatum'),
#   ('published', 'uitgiftedatum origineel'),
#   ('published', 'vorigeboek'),
#   ('published_in', 'datum'),
#   ('published_in', 'orig gebundeld'),
#   ('publisher', 'afbeelding'),
#   ('publisher', 'auteur'),
#   ('publisher', 'land'),
#   ('publisher', 'naam'),
#   ('publisher', 'onderschrift'),
#   ('publisher', 'originele uitgever'),
#   ('publisher', 'uitgever'),
#   ('publisher', 'uitgiftedatum origineel'),
#   ('publisher', 'vervolg'),
#   ('publisher', 'voorafgegaan'),
#   ('publisher', 'vorigeboek'),
#   ('range_map', 'naam'),
#   ('range_map', 'titelweergave'),
#   ('range_map', 'w-naam'),
#   ('regnal name', 'geboortedatum'),
#   ('regnal name', 'keizernaam'),
#   ('regnal name', 'naam'),
#   ('reign', 'geboortedatum'),
#   ('reign', 'sterfdatum'),
#   ('related', 'titel'),
#   ('relatives', 'naam'),
#   ('release_date', 'afbeelding'),
#   ('release_date', 'cover-op-enwp'),
#   ('release_date', 'eerste'),
#   ('release_date', 'land'),
#   ('release_date', 'lat_min'),
#   ('release_date', 'lon_sec'),
#   ('release_date', 'onderschrift'),
#   ('release_date', 'orig titel'),
#   ('release_date', 'seizoenen'),
#   ('release_date', 'uitgiftedatum'),
#   ('release_date', 'uitgiftedatum origineel'),
#   ('release_date', 'vervolg'),
#   ('release_date', 'voorafgegaan'),
#   ('release_date', 'vorigeboek'),
#   ('released', 'jaar'),
#   ('released', 'land'),
#   ('released', 'nominaties'),
#   ('released', 'première'),
#   ('released', 'prijzen'),
#   ('released', 'titel'),
#   ('released', 'vorige album'),
#   ('resting place coordinates', 'prijzen'),
#   ('resting_place', 'overlijdensplaats'),
#   ('runtime', 'lengte'),
#   ('runtime', 'nominaties'),
#   ('runtime', 'prijzen'),
#   ('screenplay', 'producer'),
#   ('screenplay', 'regie'),
#   ('screenplay', 'schrijver'),
#   ('series', 'afbeelding'),
#   ('series', 'auteur'),
#   ('series', 'cover-op-enwp'),
#   ('series', 'film'),
#   ('series', 'moviemeter'),
#   ('series', 'naam'),
#   ('series', 'onderschrift'),
#   ('series', 'orig titel'),
#   ('series', 'première'),
#   ('series', 'reeks'),
#   ('series', 'serie'),
#   ('series', 'titel'),
#   ('series', 'vervolg'),
#   ('series', 'volledige naam'),
#   ('series', 'voorafgegaan'),
#   ('series', 'vorigeboek'),
#   ('set_in', 'orig titel'),
#   ('signature', 'naam'),
#   ('spouse', 'geboortedatum'),
#   ('spouse', 'huwelijken'),
#   ('spouse', 'naam'),
#   ('starring', 'regie'),
#   ('starring', 'spelers'),
#   ('story', 'schrijver'),
#   ('studio', 'distributeur'),
#   ('studio', 'extra portaal'),
#   ('studio', 'prodmaatschappij'),
#   ('studio', 'producer'),
#   ('studio', 'regie'),
#   ('studio', 'verdeler'),
#   ('subdivision', 'naam'),
#   ('subdivision', 'titelweergave'),
#   ('subdivision', 'w-naam'),
#   ('subject', 'orig titel'),
#   ('successor', 'adoptief zoon'),
#   ('successor', 'broer van'),
#   ('successor', 'geboortenaam'),
#   ('successor', 'kinderen'),
#   ('successor', 'opvolger'),
#   ('successor', 'ouders'),
#   ('taxon', 'afbeelding'),
#   ('title_orig', 'afbeelding'),
#   ('title_orig', 'bronmateriaal'),
#   ('title_orig', 'film'),
#   ('title_orig', 'ja_naam'),
#   ('title_orig', 'ja_naam_trans'),
#   ('title_orig', 'naam'),
#   ('title_orig', 'onderschrift'),
#   ('title_orig', 'orig titel'),
#   ('title_orig', 'pinyin'),
#   ('title_orig', 'tchinees'),
#   ('title_orig', 'titel'),
#   ('transdate', 'volgnummer'),
#   ('type_species', 'naam'),
#   ('type_species', 'titelweergave'),
#   ('type_species', 'w-naam'),
#   ('type_species_authority', 'datum'),
#   ('voice', 'naam'),
#   ('website', 'titel'),
#   ('wikisource', 'afbeelding'),
#   ('wikisource', 'cover-op-enwp'),
#   ('wikisource', 'film'),
#   ('wikisource', 'genre'),
#   ('wikisource', 'naam'),
#   ('wikisource', 'onderschrift'),
#   ('wikisource', 'orig titel'),
#   ('wikisource', 'reeks'),
#   ('wikisource', 'uitgever'),
#   ('wikisource', 'uitgiftedatum'),
#   ('wikisource', 'vervolg'),
#   ('writer', 'auteur'),
#   ('writer', 'producer'),
#   ('writer', 'regie'),
#   ('writer', 'schrijver'),
#   ('years_active', 'jaren-actief'),
#   ('years_active', 'nominaties'),
#   ('years_active', 'prijzen')}}

# %%
expanded_boxes, left_untouched_boxes = [], []
for title, existing_infobox in en_infoboxes.items():
    # we have an existing infobox for Dutch, check if we need to expand it
    if title in nl_infoboxes.keys():
        nl_existing = nl_infoboxes[title]
        nl_new = nl_existing.copy()
        for nl_k, nl_v in nl_existing.items():
            en_existing = en_infoboxes[title]
            for en_k, en_v in en_existing.items():
                if en_v == nl_v:
                    continue

                # TODO: Dit is niet best, we kunnen beter de keys waarvan we weten
                # dat ze bestaan in de Engelse infobox verzamelen en die 
                # toepassen, maar met sets van tuples is dat niet handig
                # for k in matches.keys():
                for k in ['exact_key', 'full_match']:
                    reason = f'Door {k}'
                    for en_map, nl_map in matches[k]:
                        if en_map == en_k and nl_map not in nl_new and en_v not in nl_new.values():
                            nl_new[nl_map] = (en_existing[en_map], reason)
        if nl_new != nl_existing:
            expanded_boxes.append({'old': nl_existing, 'new': nl_new})
        else:
            left_untouched_boxes.append(nl_existing)

# %%
len(expanded_boxes), len(left_untouched_boxes)
# Out:
# (694, 9)

# %%
expanded_boxes
# Out:
# [{'old': {'titel': 'A Certain Smile Als een verre glimlach',
#    'regie': 'Jean Negulesco',
#    'producer': 'Henry Ephron',
#    'schrijver': 'Frances Goodrich Albert Hackett Françoise Sagan roman',
#    'spelers': 'Rossano Brazzi Joan Fontaine Bradford Dillman',
#    'muziek': 'Alfred Newman',
#    'montage': 'Louis R Loeffler',
#    'cinematografie': 'Milton R Krasner',
#    'distributeur': '20th Century Fox',
#    'première': '22 september 1958',
#    'genre': 'Drama',
#    'lengte': '104 minuten',
#    'taal': 'Engels',
#    'land': 'US',
#    'budget': '2 300 000',
#    'opbrengst': '1 300 000',
#    'imdb': '0051466',
#    'moviemeter': '48099',
#    'name': 'A Certain Smile',
#    'english_pub_date': '1956'},
#   'new': {'titel': 'A Certain Smile Als een verre glimlach',
#    'regie': 'Jean Negulesco',
#    'producer': 'Henry Ephron',
#    'schrijver': 'Frances Goodrich Albert Hackett Françoise Sagan roman',
#    'spelers': 'Rossano Brazzi Joan Fontaine Bradford Dillman',
#    'muziek': 'Alfred Newman',
#    'montage': 'Louis R Loeffler',
#    'cinematografie': 'Milton R Krasner',
#    'distributeur': '20th Century Fox',
#    'première': '22 september 1958',
#    'genre': 'Drama',
#    'lengte': '104 minuten',
#    'taal': 'Engels',
#    'land': 'US',
#    'budget': '2 300 000',
#    'opbrengst': '1 300 000',
#    'imdb': '0051466',
#    'moviemeter': '48099',
#    'name': 'A Certain Smile',
#    'english_pub_date': '1956',
#    'orig titel': ('Un Certain Sourire', 'Door full_match'),
#    'naam': ('Un Certain Sourire', 'Door full_match'),
#    'poster-op-enwp': ('ACertainSmile jpg', 'Door full_match'),
#    'afbeelding': ('ACertainSmile jpg', 'Door full_match'),
#    'cover-op-enwp': ('ACertainSmile jpg', 'Door full_match'),
#    'illustraties': ('Françoise Sagan', 'Door full_match'),
#    'onderschrift': ('Françoise Sagan', 'Door full_match'),
#    'auteur': ('Françoise Sagan', 'Door full_match'),
#    'schrijfster': ('Françoise Sagan', 'Door full_match'),
#    'kaftontwerp': ('Catherine Denvir', 'Door full_match'),
#    'extra portaal': ('Romance novel', 'Door full_match'),
#    'uitgeverij': ('E P Dutton US', 'Door full_match'),
#    'originele uitgever': ('E P Dutton US', 'Door full_match'),
#    'uitgever': ('E P Dutton US', 'Door full_match'),
#    'voorafgegaan': ('Bonjour Tristesse', 'Door full_match'),
#    'vorigeboek': ('Bonjour Tristesse', 'Door full_match'),
#    'volgendeboek': ('Dans un mois dans un an', 'Door full_match'),
#    'vervolg': ('Dans un mois dans un an', 'Door full_match')}},
#  {'old': {'naam': 'De domineesdochter',
#    'orig titel': 'A Clergyman s Daughter',
#    'auteur': 'George Orwell',
#    'vertaler': 'Elizabeth Stortenbeker',
#    'land': 'Engeland',
#    'taal': 'Nederlands',
#    'originele taal': 'Engels',
#    'uitgever': 'Meulenhoff',
#    'uitgiftedatum origineel': '1935',
#    'paginas': '302',
#    'isbn': '90 290 0373 1'},
#   'new': {'naam': 'De domineesdochter',
#    'orig titel': 'A Clergyman s Daughter',
#    'auteur': 'George Orwell',
#    'vertaler': 'Elizabeth Stortenbeker',
#    'land': 'Engeland',
#    'taal': 'Nederlands',
#    'originele taal': 'Engels',
#    'uitgever': 'Meulenhoff',
#    'uitgiftedatum origineel': '1935',
#    'paginas': '302',
#    'isbn': '90 290 0373 1',
#    'poster-op-enwp': ('File A Clergyman s Daughter 1st US edition cover art jpg',
#     'Door full_match'),
#    'afbeelding': ('File A Clergyman s Daughter 1st US edition cover art jpg',
#     'Door full_match'),
#    'cover-op-enwp': ('File A Clergyman s Daughter 1st US edition cover art jpg',
#     'Door full_match'),
#    'titel': ('First US edition cover the novel published in America with a slight change of title as The Clergyman s Daughter',
#     'Door full_match'),
#    'uitgiftedatum': ('1935 Victor Gollancz', 'Door full_match'),
#    'medium': ('Print hardback paperback', 'Door full_match'),
#    'voorafgegaan': ('Burmese Days', 'Door full_match'),
#    'vorigeboek': ('Burmese Days', 'Door full_match'),
#    'volgendeboek': ('Keep the Aspidistra Flying', 'Door full_match'),
#    'vervolg': ('Keep the Aspidistra Flying', 'Door full_match')}},
#  {'old': {'naam': 'De goddeloze tuin van Eden',
#    'afbeelding': 'Cover If 195309 jpg',
#    'onderschrift': 'A Case of Conscience omslag eerste uitgave',
#    'auteur': 'James Blish',
#    'vertaler': 'Cornelis Andries Gerardus van den Broek',
#    'kaftontwerp': 'Alex Jagtenberg Studio Lemaire',
#    'land': 'US',
#    'taal': 'Nederlands',
#    'originele taal': 'Engels',
#    'reeks': 'Born SF',
#    'genre': 'Sciencefiction',
#    'uitgever': 'Born',
#    'originele uitgever': 'Ballantine Books',
#    'uitgiftedatum': '1969',
#    'uitgiftedatum origineel': '1958',
#    'paginas': '190',
#    'grootte': '190 mm',
#    'vervolg': 'After Such Knowledge',
#    'vorigeboek': '',
#    'volgendeboek': 'Doctor Mirabilis',
#    'extra portaal': 'Sciencefiction'},
#   'new': {'naam': 'De goddeloze tuin van Eden',
#    'afbeelding': 'Cover If 195309 jpg',
#    'onderschrift': 'A Case of Conscience omslag eerste uitgave',
#    'auteur': 'James Blish',
#    'vertaler': 'Cornelis Andries Gerardus van den Broek',
#    'kaftontwerp': 'Alex Jagtenberg Studio Lemaire',
#    'land': 'US',
#    'taal': 'Nederlands',
#    'originele taal': 'Engels',
#    'reeks': 'Born SF',
#    'genre': 'Sciencefiction',
#    'uitgever': 'Born',
#    'originele uitgever': 'Ballantine Books',
#    'uitgiftedatum': '1969',
#    'uitgiftedatum origineel': '1958',
#    'paginas': '190',
#    'grootte': '190 mm',
#    'vervolg': 'After Such Knowledge',
#    'vorigeboek': '',
#    'volgendeboek': 'Doctor Mirabilis',
#    'extra portaal': 'Sciencefiction',
#    'name': ('A Case of Conscience', 'Door exact_key'),
#    'titel': ('A Case of Conscience', 'Door full_match'),
#    'film': ('A Case of Conscience', 'Door full_match'),
#    'band_naam': ('A Case of Conscience', 'Door full_match'),
#    'orig titel': ('A Case of Conscience', 'Door full_match'),
#    'w-naam': ('A Case of Conscience', 'Door full_match'),
#    'beter-bekend-als': ('A Case of Conscience', 'Door full_match'),
#    'titelweergave': ('A Case of Conscience', 'Door full_match'),
#    'portaal2': ('A Case of Conscience', 'Door full_match'),
#    'volledige naam': ('A Case of Conscience', 'Door full_match'),
#    'poster-op-enwp': ('ACaseOfConscience novel jpg', 'Door full_match'),
#    'cover-op-enwp': ('ACaseOfConscience novel jpg', 'Door full_match'),
#    'onderwerp': ('James Blish Career After Such Knowledge trilogy',
#     'Door full_match'),
#    'medium': ('Print paperback', 'Door full_match'),
#    'isbn': ('0 345 43835 3', 'Door exact_key'),
#    'issn': ('0 345 43835 3', 'Door full_match')}},
#  {'old': {'naam': '2010 Odyssey Two',
#    'auteur': 'Arthur C Clarke',
#    'land': 'UK',
#    'genre': 'Sciencefiction',
#    'uitgiftedatum': '1982',
#    'film': '2010 The Year We Make Contact',
#    'voorafgegaan': '2001 A Space Odyssey 2061 Odyssey Three',
#    'vervolg': '3001 The Final Odyssey'},
#   'new': {'naam': '2010 Odyssey Two',
#    'auteur': 'Arthur C Clarke',
#    'land': 'UK',
#    'genre': 'Sciencefiction',
#    'uitgiftedatum': '1982',
#    'film': '2010 The Year We Make Contact',
#    'voorafgegaan': '2001 A Space Odyssey 2061 Odyssey Three',
#    'vervolg': '3001 The Final Odyssey',
#    'poster-op-enwp': ('ArthurCClarke 2010OdysseyTwo jpg', 'Door full_match'),
#    'afbeelding': ('ArthurCClarke 2010OdysseyTwo jpg', 'Door full_match'),
#    'cover-op-enwp': ('ArthurCClarke 2010OdysseyTwo jpg', 'Door full_match'),
#    'titel': ('First Edition cover 1982', 'Door full_match'),
#    'kaftontwerp': ('Michael Whelan', 'Door full_match'),
#    'illustraties': ('Michael Whelan', 'Door full_match'),
#    'onderwerp': ('The Space Odyssey series Space Odyssey', 'Door full_match'),
#    'reeks': ('The Space Odyssey series Space Odyssey', 'Door full_match'),
#    'extra portaal': ('The Space Odyssey series Space Odyssey',
#     'Door full_match'),
#    'orig titel': ('The Space Odyssey series Space Odyssey', 'Door full_match'),
#    'uitgeverij': ('Ballantine Books', 'Door full_match'),
#    'originele uitgever': ('Ballantine Books', 'Door full_match'),
#    'uitgever': ('Ballantine Books', 'Door full_match'),
#    'uitgiftedatum origineel': ('December 1982', 'Door full_match'),
#    'medium': ('Print Hardcover Paperback', 'Door full_match'),
#    'paginas': ('291 first edition hardback', 'Door full_match'),
#    'isbn': ('0 345 30305 9', 'Door exact_key'),
#    'issn': ('0 345 30305 9', 'Door full_match'),
#    'vorigeboek': ('2001 A Space Odyssey novel 2001 A Space Odyssey',
#     'Door full_match'),
#    'volgendeboek': ('2061 Odyssey Three', 'Door full_match')}},
#  {'old': {'naam': 'Het heelal',
#    'orig titel': 'A Brief History of Time',
#    'vertaler': 'Ronald Jonkers',
#    'auteur': 'Stephen Hawking',
#    'taal': 'Nederlands',
#    'onderwerp': 'Kosmologie Theoretische natuurkunde',
#    'genre': 'Populaire wetenschap Populairwetenschappelijk',
#    'uitgever': 'Bert Bakker uitgeverij Bert Bakker',
#    'uitgiftedatum': '1988',
#    'paginas': '231',
#    'isbn': '90 351 0611 3',
#    'portaal': 'Astronomie'},
#   'new': {'naam': 'Het heelal',
#    'orig titel': 'A Brief History of Time',
#    'vertaler': 'Ronald Jonkers',
#    'auteur': 'Stephen Hawking',
#    'taal': 'Nederlands',
#    'onderwerp': 'Kosmologie Theoretische natuurkunde',
#    'genre': 'Populaire wetenschap Populairwetenschappelijk',
#    'uitgever': 'Bert Bakker uitgeverij Bert Bakker',
#    'uitgiftedatum': '1988',
#    'paginas': '231',
#    'isbn': '90 351 0611 3',
#    'portaal': 'Astronomie',
#    'poster-op-enwp': ('BriefHistoryTime jpg', 'Door full_match'),
#    'afbeelding': ('BriefHistoryTime jpg', 'Door full_match'),
#    'cover-op-enwp': ('BriefHistoryTime jpg', 'Door full_match'),
#    'titel': ('First edition', 'Door full_match'),
#    'land': ('United Kingdom', 'Door full_match'),
#    'uitgeverij': ('Bantam Books Bantam Dell Publishing Group',
#     'Door full_match'),
#    'originele uitgever': ('Bantam Books Bantam Dell Publishing Group',
#     'Door full_match'),
#    'medium': ('Print Hardcover and Paperback', 'Door full_match'),
#    'issn': ('978 0 553 10953 5', 'Door full_match'),
#    'volgendeboek': ('Black Holes and Baby Universes and Other Essays',
#     'Door full_match'),
#    'vervolg': ('Black Holes and Baby Universes and Other Essays',
#     'Door full_match')}},
#  {'old': {'naam': '22 11 1963',
#    'cover-op-enwp': '11 22 63 jpg',
#    'orig titel': '11 22 63',
#    'auteur': 'Stephen King schrijver Stephen King',
#    'vertaler': 'Hugo Kuipers',
#    'kaftontwerp': 'DPS Davy van der Elsken',
#    'land': 'Verenigde Staten',
#    'taal': 'Nederlands',
#    'originele taal': 'Engels',
#    'onderwerp': 'Moord op de Amerikaanse president John F Kennedy',
#    'genre': 'Sciencefiction Amerikaanse geschiedenis drama',
#    'uitgever': 'Uitgeverij Luitingh Sijthoff B V Amsterdam',
#    'originele uitgever': 'Scribner',
#    'uitgiftedatum': 'november 2011',
#    'uitgiftedatum origineel': '8 november 2011',
#    'paginas': '879',
#    'isbn': '978 90 245 3362 6',
#    'film': '11 22 63 miniserie 2016'},
#   'new': {'naam': '22 11 1963',
#    'cover-op-enwp': '11 22 63 jpg',
#    'orig titel': '11 22 63',
#    'auteur': 'Stephen King schrijver Stephen King',
#    'vertaler': 'Hugo Kuipers',
#    'kaftontwerp': 'DPS Davy van der Elsken',
#    'land': 'Verenigde Staten',
#    'taal': 'Nederlands',
#    'originele taal': 'Engels',
#    'onderwerp': 'Moord op de Amerikaanse president John F Kennedy',
#    'genre': 'Sciencefiction Amerikaanse geschiedenis drama',
#    'uitgever': 'Uitgeverij Luitingh Sijthoff B V Amsterdam',
#    'originele uitgever': 'Scribner',
#    'uitgiftedatum': 'november 2011',
#    'uitgiftedatum origineel': '8 november 2011',
#    'paginas': '879',
#    'isbn': '978 90 245 3362 6',
#    'film': '11 22 63 miniserie 2016',
#    'titel': ('First edition cover', 'Door full_match'),
#    'illustraties': ('Stephen King', 'Door full_match'),
#    'onderschrift': ('Stephen King', 'Door full_match'),
#    'schrijver': ('Stephen King', 'Door full_match'),
#    'schrijfster': ('Stephen King', 'Door full_match'),
#    'extra portaal': ('Science fiction Alternate history', 'Door full_match'),
#    'uitgeverij': ('Charles Scribner s Sons Scribner', 'Door full_match'),
#    'medium': ('Print hardcover', 'Door full_match'),
#    'issn': ('978 1 4516 2728 2', 'Door full_match')}},
#  {'old': {'naam': 'Een Kroon van Zwaarden',
#    'reeks': 'Het Rad des Tijds',
#    'auteur': 'Robert Jordan auteur Robert Jordan',
#    'vertaler': 'Jo Thomas Johan Martijn Flaton',
#    'uitgever': 'Luitingh Sijthoff',
#    'originele uitgever': 'Tor Books',
#    'orig titel': 'Crown of Swords',
#    'uitgiftedatum': '1998',
#    'uitgiftedatum origineel': '15 mei 1996',
#    'genre': 'Fantasy genre Fantasy',
#    'paginas': '704 blz',
#    'isbn': '9024512689',
#    'voorafgegaan': 'Heer van Chaos',
#    'vervolg': 'Het Pad der Dolken'},
#   'new': {'naam': 'Een Kroon van Zwaarden',
#    'reeks': 'Het Rad des Tijds',
#    'auteur': 'Robert Jordan auteur Robert Jordan',
#    'vertaler': 'Jo Thomas Johan Martijn Flaton',
#    'uitgever': 'Luitingh Sijthoff',
#    'originele uitgever': 'Tor Books',
#    'orig titel': 'Crown of Swords',
#    'uitgiftedatum': '1998',
#    'uitgiftedatum origineel': '15 mei 1996',
#    'genre': 'Fantasy genre Fantasy',
#    'paginas': '704 blz',
#    'isbn': '9024512689',
#    'voorafgegaan': 'Heer van Chaos',
#    'vervolg': 'Het Pad der Dolken',
#    'name': ('A Crown of Swords', 'Door exact_key'),
#    'onderschrift': ('A Crown of Swords', 'Door full_match'),
#    'titel': ('A Crown of Swords', 'Door full_match'),
#    'extra portaal': ('A Crown of Swords', 'Door full_match'),
#    'film': ('A Crown of Swords', 'Door full_match'),
#    'band_naam': ('A Crown of Swords', 'Door full_match'),
#    'w-naam': ('A Crown of Swords', 'Door full_match'),
#    'beter-bekend-als': ('A Crown of Swords', 'Door full_match'),
#    'titelweergave': ('A Crown of Swords', 'Door full_match'),
#    'portaal2': ('A Crown of Swords', 'Door full_match'),
#    'volledige naam': ('A Crown of Swords', 'Door full_match'),
#    'poster-op-enwp': ('WoT07 ACrownOfSwords jpg', 'Door full_match'),
#    'afbeelding': ('WoT07 ACrownOfSwords jpg', 'Door full_match'),
#    'cover-op-enwp': ('WoT07 ACrownOfSwords jpg', 'Door full_match'),
#    'illustraties': ('Robert Jordan', 'Door full_match'),
#    'schrijver': ('Robert Jordan', 'Door full_match'),
#    'schrijfster': ('Robert Jordan', 'Door full_match'),
#    'kaftontwerp': ('Darrell K Sweet Tyler Jacobson 2013 Edition',
#     'Door full_match'),
#    'land': ('United States', 'Door full_match'),
#    'onderwerp': ('The Wheel of Time', 'Door full_match'),
#    'medium': ('Print hardback paperback', 'Door full_match'),
#    'issn': ('0 312 85767 5', 'Door full_match'),
#    'vorigeboek': ('Lord of Chaos', 'Door full_match'),
#    'volgendeboek': ('The Path of Daggers', 'Door full_match')}},
#  {'old': {'naam': 'A Clockwork Orange',
#    'afbeelding': 'A_CLOCKWORK_ORANGE jpg',
#    'auteur': 'Anthony Burgess',
#    'land': 'Verenigd Koninkrijk',
#    'taal': 'Engels Nadsat',
#    'genre': 'Toekomstroman satire',
#    'uitgever': 'Heinemann VK',
#    'uitgiftedatum': '1962',
#    'paginas': '192',
#    'isbn': '0434098000',
#    'film': 'A Clockwork Orange film A Clockwork Orange'},
#   'new': {'naam': 'A Clockwork Orange',
#    'afbeelding': 'A_CLOCKWORK_ORANGE jpg',
#    'auteur': 'Anthony Burgess',
#    'land': 'Verenigd Koninkrijk',
#    'taal': 'Engels Nadsat',
#    'genre': 'Toekomstroman satire',
#    'uitgever': 'Heinemann VK',
#    'uitgiftedatum': '1962',
#    'paginas': '192',
#    'isbn': '0434098000',
#    'film': 'A Clockwork Orange film A Clockwork Orange',
#    'poster-op-enwp': ('Clockwork orange jpg', 'Door full_match'),
#    'cover-op-enwp': ('Clockwork orange jpg', 'Door full_match'),
#    'titel': ('Dust jacket from the first edition', 'Door full_match'),
#    'kaftontwerp': ('Barry Trengove', 'Door full_match'),
#    'illustraties': ('Barry Trengove', 'Door full_match'),
#    'extra portaal': ('Science fiction dystopian fiction satire black comedy',
#     'Door full_match'),
#    'uitgiftedatum origineel': ('1962 Heinemann book publisher William Heinemann UK',
#     'Door full_match'),
#    'medium': ('Print hardback paperback audio book Compact audio cassette cassette Compact Disc CD',
#     'Door full_match'),
#    'issn': ('0 434 09800 0', 'Door full_match')}},
#  {'old': {'naam': '1Q84',
#    'vertaler': 'Jacques Westerhoven',
#    'auteur': 'Haruki Murakami',
#    'land': 'Japan',
#    'taal': 'Japans',
#    'genre': 'Roman literatuur Roman',
#    'uitgever': 'Shinchosha',
#    'uitgiftedatum': '29 mei 2009',
#    'medium': 'Boek'},
#   'new': {'naam': '1Q84',
#    'vertaler': 'Jacques Westerhoven',
#    'auteur': 'Haruki Murakami',
#    'land': 'Japan',
#    'taal': 'Japans',
#    'genre': 'Roman literatuur Roman',
#    'uitgever': 'Shinchosha',
#    'uitgiftedatum': '29 mei 2009',
#    'medium': 'Boek',
#    'poster-op-enwp': ('1Q84bookcover jpg', 'Door full_match'),
#    'afbeelding': ('1Q84bookcover jpg', 'Door full_match'),
#    'cover-op-enwp': ('1Q84bookcover jpg', 'Door full_match'),
#    'titel': ('Cover of Book 1', 'Door full_match'),
#    'extra portaal': ('Alternate history Parallel universe fiction parallel worlds',
#     'Door full_match'),
#    'uitgiftedatum origineel': ('May 29 2009 small Books 1 and 2 April 16 2010 small Book 3',
#     'Door full_match'),
#    'english_pub_date': ('October 25 2011', 'Door exact_key'),
#    'paginas': ('928', 'Door full_match'),
#    'isbn': ('978 0 307 59331 3', 'Door exact_key'),
#    'issn': ('978 0 307 59331 3', 'Door full_match')}},
#  {'old': {'naam': 'Een Cursus in Wonderen',
#    'orig titel': 'A Course in Miracles',
#    'vertaler': 'Willem Glaudemans Kaja van Grieken Bob Hermans Koos Janson Thilly Mercier William Moons Gertje van Ramshorst',
#    'auteur': 'Niet met zekerheid vastgesteld maar op schrift gezet door Helen Schucman en William Thetford',
#    'land': 'Verenigde Staten',
#    'taal': 'Nederlands',
#    'onderwerp': 'Persoonlijke spirituele ontwikkeling',
#    'genre': 'Spiritualiteit',
#    'uitgever': 'The Foundation for Inner Peace Nederlands taalgebied Uitgeverij Ankh Hermes',
#    'uitgiftedatum': '1975',
#    'medium': 'Hardcover',
#    'paginas': '1342',
#    'isbn': '978 90 202 11641 gebonden dundrukuitgave'},
#   'new': {'naam': 'Een Cursus in Wonderen',
#    'orig titel': 'A Course in Miracles',
#    'vertaler': 'Willem Glaudemans Kaja van Grieken Bob Hermans Koos Janson Thilly Mercier William Moons Gertje van Ramshorst',
#    'auteur': 'Niet met zekerheid vastgesteld maar op schrift gezet door Helen Schucman en William Thetford',
#    'land': 'Verenigde Staten',
#    'taal': 'Nederlands',
#    'onderwerp': 'Persoonlijke spirituele ontwikkeling',
#    'genre': 'Spiritualiteit',
#    'uitgever': 'The Foundation for Inner Peace Nederlands taalgebied Uitgeverij Ankh Hermes',
#    'uitgiftedatum': '1975',
#    'medium': 'Hardcover',
#    'paginas': '1342',
#    'isbn': '978 90 202 11641 gebonden dundrukuitgave',
#    'poster-op-enwp': ('ACIM3COVER jpg', 'Door full_match'),
#    'afbeelding': ('ACIM3COVER jpg', 'Door full_match'),
#    'cover-op-enwp': ('ACIM3COVER jpg', 'Door full_match'),
#    'titel': ('A Course in Miracles Combined Volume Third Edition as published by the Foundation for Inner Peace',
#     'Door full_match'),
#    'illustraties': ('There is no author attributed to ACIM although it was scribed by Helen Schucman',
#     'Door full_match'),
#    'onderschrift': ('There is no author attributed to ACIM although it was scribed by Helen Schucman',
#     'Door full_match'),
#    'schrijver': ('There is no author attributed to ACIM although it was scribed by Helen Schucman',
#     'Door full_match'),
#    'schrijfster': ('There is no author attributed to ACIM although it was scribed by Helen Schucman',
#     'Door full_match'),
#    'uitgeverij': ('1976 New York Viking The Foundation for Inner Peace 2007 The Foundation for Inner Peace 3rd ed',
#     'Door full_match'),
#    'originele uitgever': ('1976 New York Viking The Foundation for Inner Peace 2007 The Foundation for Inner Peace 3rd ed',
#     'Door full_match'),
#    'issn': ('978 1 883360 24 5', 'Door full_match')}},
#  {'old': {'naam': 'Een samenzwering van idioten',
#    'orig titel': 'A Confederacy of Dunces',
#    'auteur': 'John Kennedy Toole',
#    'vertaler': 'Paul Syrier',
#    'land': 'Verenigde Staten',
#    'taal': 'Nederlands',
#    'originele taal': 'Engels',
#    'uitgever': 'Lebowski',
#    'originele uitgever': 'Louisiana State University Press',
#    'uitgiftedatum': '2011',
#    'uitgiftedatum origineel': '1980',
#    'isbn': '978 90 488 0828 1'},
#   'new': {'naam': 'Een samenzwering van idioten',
#    'orig titel': 'A Confederacy of Dunces',
#    'auteur': 'John Kennedy Toole',
#    'vertaler': 'Paul Syrier',
#    'land': 'Verenigde Staten',
#    'taal': 'Nederlands',
#    'originele taal': 'Engels',
#    'uitgever': 'Lebowski',
#    'originele uitgever': 'Louisiana State University Press',
#    'uitgiftedatum': '2011',
#    'uitgiftedatum origineel': '1980',
#    'isbn': '978 90 488 0828 1',
#    'poster-op-enwp': ('Confederacy of dunces cover jpg', 'Door full_match'),
#    'afbeelding': ('Confederacy of dunces cover jpg', 'Door full_match'),
#    'cover-op-enwp': ('Confederacy of dunces cover jpg', 'Door full_match'),
#    'genre': ('Comedy tragicomedy', 'Door exact_key'),
#    'extra portaal': ('Comedy tragicomedy', 'Door full_match'),
#    'medium': ('Print hardback paperback audiobook e book', 'Door full_match'),
#    'paginas': ('405 pp paperback sfn Toole 1980', 'Door full_match'),
#    'issn': ('0 8071 0657 7', 'Door full_match')}},
#  {'old': {'naam': 'Scheepsramp op de maan',
#    'orig titel': 'A Fall of Moondust',
#    'auteur': 'Arthur C Clarke',
#    'vertaler': 'B H Staal',
#    'land': 'Engeland',
#    'taal': 'Nederlands',
#    'originele taal': 'Engels',
#    'reeks': 'Prisma P955',
#    'genre': 'sciencefiction',
#    'uitgever': 'Het Spectrum',
#    'originele uitgever': 'Victor Gollancz Ltd',
#    'uitgiftedatum': '1964',
#    'uitgiftedatum origineel': '1961',
#    'medium': 'pocketboek',
#    'paginas': '192',
#    'extra portaal': 'Sciencefiction'},
#   'new': {'naam': 'Scheepsramp op de maan',
#    'orig titel': 'A Fall of Moondust',
#    'auteur': 'Arthur C Clarke',
#    'vertaler': 'B H Staal',
#    'land': 'Engeland',
#    'taal': 'Nederlands',
#    'originele taal': 'Engels',
#    'reeks': 'Prisma P955',
#    'genre': 'sciencefiction',
#    'uitgever': 'Het Spectrum',
#    'originele uitgever': 'Victor Gollancz Ltd',
#    'uitgiftedatum': '1964',
#    'uitgiftedatum origineel': '1961',
#    'medium': 'pocketboek',
#    'paginas': '192',
#    'extra portaal': 'Sciencefiction',
#    'poster-op-enwp': ('File A Fall of Moondust first edition jpg',
#     'Door full_match'),
#    'afbeelding': ('File A Fall of Moondust first edition jpg',
#     'Door full_match'),
#    'cover-op-enwp': ('File A Fall of Moondust first edition jpg',
#     'Door full_match'),
#    'titel': ('Cover of the first edition', 'Door full_match'),
#    'uitgeverij': ('Victor Gollancz Ltd Gollancz', 'Door full_match'),
#    'isbn': ('0 575 07317 9', 'Door exact_key'),
#    'issn': ('0 575 07317 9', 'Door full_match')}},
#  {'old': {'naam': 'A Fighting Man of Mars',
#    'auteur': 'Edgar Rice Burroughs',
#    'land': 'Verenigde Staten',
#    'taal': 'Engels',
#    'reeks': 'Barsoom',
#    'genre': 'Science fantasy',
#    'uitgever': 'Metropolitan Books',
#    'uitgiftedatum': '1931',
#    'medium': 'Print',
#    'paginas': '319',
#    'vorigeboek': 'The Master Mind of Mars',
#    'volgendeboek': 'Swords of Mars',
#    'extra portaal': 'Sciencefiction'},
#   'new': {'naam': 'A Fighting Man of Mars',
#    'auteur': 'Edgar Rice Burroughs',
#    'land': 'Verenigde Staten',
#    'taal': 'Engels',
#    'reeks': 'Barsoom',
#    'genre': 'Science fantasy',
#    'uitgever': 'Metropolitan Books',
#    'uitgiftedatum': '1931',
#    'medium': 'Print',
#    'paginas': '319',
#    'vorigeboek': 'The Master Mind of Mars',
#    'volgendeboek': 'Swords of Mars',
#    'extra portaal': 'Sciencefiction',
#    'poster-op-enwp': ('Fighting Man of Mars jpg', 'Door full_match'),
#    'afbeelding': ('Fighting Man of Mars jpg', 'Door full_match'),
#    'cover-op-enwp': ('Fighting Man of Mars jpg', 'Door full_match'),
#    'titel': ('dust jacket for A Fighting Man of Mars', 'Door full_match'),
#    'uitgiftedatum origineel': ('1930', 'Door full_match')}},
#  {'old': {'naam': 'A Christmas Carol',
#    'orig titel': 'A Christmas Carol in Prose Being a Ghost Story of Christmas',
#    'afbeelding': 'Charles Dickens A Christmas Carol Title page First edition 1843 jpg',
#    'auteur': 'Charles Dickens',
#    'land': 'Verenigd Koninkrijk',
#    'taal': 'Engels',
#    'genre': 'Kerstmis spookverhaal',
#    'uitgever': 'Chapman Hall',
#    'uitgiftedatum': '19 december 1843'},
#   'new': {'naam': 'A Christmas Carol',
#    'orig titel': 'A Christmas Carol in Prose Being a Ghost Story of Christmas',
#    'afbeelding': 'Charles Dickens A Christmas Carol Title page First edition 1843 jpg',
#    'auteur': 'Charles Dickens',
#    'land': 'Verenigd Koninkrijk',
#    'taal': 'Engels',
#    'genre': 'Kerstmis spookverhaal',
#    'uitgever': 'Chapman Hall',
#    'uitgiftedatum': '19 december 1843',
#    'poster-op-enwp': ('Charles Dickens A Christmas Carol Cloth First Edition 1843 jpg',
#     'Door full_match'),
#    'cover-op-enwp': ('Charles Dickens A Christmas Carol Cloth First Edition 1843 jpg',
#     'Door full_match'),
#    'titel': ('First edition cover 1843', 'Door full_match'),
#    'illustrator': ('John Leech caricaturist John Leech', 'Door exact_key'),
#    'kaftontwerp': ('John Leech caricaturist John Leech', 'Door full_match'),
#    'illustraties': ('John Leech caricaturist John Leech', 'Door full_match'),
#    'uitgiftedatum origineel': ('date and age 19 December 1843',
#     'Door full_match')}},
#  {'old': {'naam': 'Et Dukkehjem Een poppenhuis',
#    'afbeelding': 'A_Doll s_House jpeg',
#    'onderschrift': 'Titelpagina manuscript 1879',
#    'schrijver': 'Henrik Ibsen',
#    'taal': 'Noors',
#    'nederlandse vertaling door': 'Margaretha Meijboom',
#    'eerste opvoering datum': '21 december 1879',
#    'eerste opvoering waar': 'Kopenhagen',
#    'eerste opvoering NL': '1906',
#    'soort': 'Tendensroman'},
#   'new': {'naam': 'Et Dukkehjem Een poppenhuis',
#    'afbeelding': 'A_Doll s_House jpeg',
#    'onderschrift': 'Titelpagina manuscript 1879',
#    'schrijver': 'Henrik Ibsen',
#    'taal': 'Noors',
#    'nederlandse vertaling door': 'Margaretha Meijboom',
#    'eerste opvoering datum': '21 december 1879',
#    'eerste opvoering waar': 'Kopenhagen',
#    'eerste opvoering NL': '1906',
#    'soort': 'Tendensroman',
#    'name': ('A Doll s House', 'Door exact_key'),
#    'titel': ('A Doll s House', 'Door full_match'),
#    'extra portaal': ('A Doll s House', 'Door full_match'),
#    'film': ('A Doll s House', 'Door full_match'),
#    'band_naam': ('A Doll s House', 'Door full_match'),
#    'orig titel': ('A Doll s House', 'Door full_match'),
#    'w-naam': ('A Doll s House', 'Door full_match'),
#    'beter-bekend-als': ('A Doll s House', 'Door full_match'),
#    'titelweergave': ('A Doll s House', 'Door full_match'),
#    'portaal2': ('A Doll s House', 'Door full_match'),
#    'volledige naam': ('A Doll s House', 'Door full_match'),
#    'poster-op-enwp': ('A Doll s House jpeg', 'Door full_match'),
#    'cover-op-enwp': ('A Doll s House jpeg', 'Door full_match'),
#    'setting': ('The home of the Helmer family in an unspecified Norwegian town or city circa 1879',
#     'Door exact_key'),
#    'genre': ('Naturalism theatre Naturalistic Realism theatre realistic problem play Modern tragedy',
#     'Door exact_key')}},
#  {'old': {'naam': 'Een dans met draken',
#    'reeks': 'Het lied van ijs en vuur',
#    'auteur': 'George R R Martin',
#    'vertaler': 'Renée Vink',
#    'uitgever': 'Luitingh Sijthoff',
#    'orig titel': 'A Dance with Dragons',
#    'genre': 'High fantasy',
#    'voorafgegaan': 'Een feestmaal voor kraaien'},
#   'new': {'naam': 'Een dans met draken',
#    'reeks': 'Het lied van ijs en vuur',
#    'auteur': 'George R R Martin',
#    'vertaler': 'Renée Vink',
#    'uitgever': 'Luitingh Sijthoff',
#    'orig titel': 'A Dance with Dragons',
#    'genre': 'High fantasy',
#    'voorafgegaan': 'Een feestmaal voor kraaien',
#    'poster-op-enwp': ('A Dance With Dragons US jpg', 'Door full_match'),
#    'afbeelding': ('A Dance With Dragons US jpg', 'Door full_match'),
#    'cover-op-enwp': ('A Dance With Dragons US jpg', 'Door full_match'),
#    'kaftontwerp': ('Larry Rostant', 'Door full_match'),
#    'illustraties': ('Larry Rostant', 'Door full_match'),
#    'land': ('United States', 'Door full_match'),
#    'onderwerp': ('A Song of Ice and Fire', 'Door full_match'),
#    'extra portaal': ('A Song of Ice and Fire', 'Door full_match'),
#    'film': ('A Song of Ice and Fire', 'Door full_match'),
#    'uitgiftedatum origineel': ('July 12 2011', 'Door full_match'),
#    'uitgiftedatum': ('July 12 2011', 'Door full_match'),
#    'uitgeverij': ('Voyager Books UK Bantam Spectra US', 'Door full_match'),
#    'originele uitgever': ('Voyager Books UK Bantam Spectra US',
#     'Door full_match'),
#    'medium': ('Print hardback paperback', 'Door full_match'),
#    'paginas': ('1016 US hardcover', 'Door full_match'),
#    'isbn': ('978 0553801477', 'Door exact_key'),
#    'issn': ('978 0553801477', 'Door full_match'),
#    'vorigeboek': ('A Feast for Crows', 'Door full_match'),
#    'volgendeboek': ('The Winds of Winter forthcoming', 'Door full_match'),
#    'vervolg': ('The Winds of Winter forthcoming', 'Door full_match')}},
#  {'old': {'naam': 'A Moveable Feast',
#    'afbeelding': 'GertrudeStein JackHemingway Paris jpg',
#    'onderschrift': 'Gertrude Stein met Jack Hemingway in Parijs',
#    'auteur': 'Ernest Hemingway',
#    'land': 'US',
#    'originele taal': 'Engels',
#    'genre': 'biografie',
#    'originele uitgever': 'Scribner s',
#    'uitgiftedatum origineel': '1964',
#    'paginas': '211',
#    'grootte': '22 cm'},
#   'new': {'naam': 'A Moveable Feast',
#    'afbeelding': 'GertrudeStein JackHemingway Paris jpg',
#    'onderschrift': 'Gertrude Stein met Jack Hemingway in Parijs',
#    'auteur': 'Ernest Hemingway',
#    'land': 'US',
#    'originele taal': 'Engels',
#    'genre': 'biografie',
#    'originele uitgever': 'Scribner s',
#    'uitgiftedatum origineel': '1964',
#    'paginas': '211',
#    'grootte': '22 cm',
#    'poster-op-enwp': ('Image MoveableFeast jpg', 'Door full_match'),
#    'cover-op-enwp': ('Image MoveableFeast jpg', 'Door full_match'),
#    'titel': ('First American edition', 'Door full_match'),
#    'extra portaal': ('Memoir Autobiography', 'Door full_match'),
#    'uitgeverij': ('Scribner s USA Jonathan Cape UK', 'Door full_match'),
#    'uitgever': ('Scribner s USA Jonathan Cape UK', 'Door full_match')}},
#  {'old': {'titel': 'A Passage to India',
#    'regie': 'David Lean',
#    'producer': 'John Brabourne Richard B Goodwin',
#    'schrijver': 'David Lean',
#    'spelers': 'Judy Davis Victor Banerjee Peggy Ashcroft James Fox acteur James Fox Alec Guinness',
#    'muziek': 'Maurice Jarre',
#    'montage': 'David Lean',
#    'cinematografie': 'Ernest Day',
#    'distributeur': 'Columbia Pictures',
#    'première': '14 december 1984',
#    'lengte': '163 minuten',
#    'taal': 'Engels',
#    'land': 'UK US',
#    'opbrengst': '27 187 653 VS',
#    'imdb': '0087892',
#    'moviemeter': '2806',
#    'montager': 'David Lean',
#    'studio': 'Thorn EMI HBO',
#    'duur': '163 minuten'},
#   'new': {'titel': 'A Passage to India',
#    'regie': 'David Lean',
#    'producer': 'John Brabourne Richard B Goodwin',
#    'schrijver': 'David Lean',
#    'spelers': 'Judy Davis Victor Banerjee Peggy Ashcroft James Fox acteur James Fox Alec Guinness',
#    'muziek': 'Maurice Jarre',
#    'montage': 'David Lean',
#    'cinematografie': 'Ernest Day',
#    'distributeur': 'Columbia Pictures',
#    'première': '14 december 1984',
#    'lengte': '163 minuten',
#    'taal': 'Engels',
#    'land': 'UK US',
#    'opbrengst': '27 187 653 VS',
#    'imdb': '0087892',
#    'moviemeter': '2806',
#    'montager': 'David Lean',
#    'studio': 'Thorn EMI HBO',
#    'duur': '163 minuten',
#    'poster-op-enwp': ('APassageToIndia jpg', 'Door full_match'),
#    'afbeelding': ('APassageToIndia jpg', 'Door full_match'),
#    'cover-op-enwp': ('APassageToIndia jpg', 'Door full_match'),
#    'illustraties': ('E M Forster', 'Door full_match'),
#    'onderschrift': ('E M Forster', 'Door full_match'),
#    'auteur': ('E M Forster', 'Door full_match'),
#    'naam': ('E M Forster', 'Door full_match'),
#    'schrijfster': ('E M Forster', 'Door full_match'),
#    'uitgeverij': ('Edward Arnold publisher Edward Arnold UK Harcourt Brace US',
#     'Door full_match'),
#    'originele uitgever': ('Edward Arnold publisher Edward Arnold UK Harcourt Brace US',
#     'Door full_match'),
#    'uitgever': ('Edward Arnold publisher Edward Arnold UK Harcourt Brace US',
#     'Door full_match'),
#    'uitgiftedatum origineel': ('4 June 1924', 'Door full_match'),
#    'uitgiftedatum': ('4 June 1924', 'Door full_match'),
#    'medium': ('Print hardback paperback', 'Door full_match')}},
#  {'old': {'naam': 'Bidden wij voor Owen Meany',
#    'orig titel': 'A Prayer for Owen Meany',
#    'auteur': 'John Irving',
#    'vertaler': 'Cornelis Andries Gerardus van den Broek C A G van den Broek',
#    'land': 'Verenigde Staten',
#    'taal': 'Nederlands',
#    'originele taal': 'Engels',
#    'genre': 'Roman literatuur Roman',
#    'uitgever': 'De Bezige Bij',
#    'uitgiftedatum': '2012',
#    'uitgiftedatum origineel': '1989',
#    'isbn': '978 90 234 3859 5',
#    'film': 'Simon Birch 1998'},
#   'new': {'naam': 'Bidden wij voor Owen Meany',
#    'orig titel': 'A Prayer for Owen Meany',
#    'auteur': 'John Irving',
#    'vertaler': 'Cornelis Andries Gerardus van den Broek C A G van den Broek',
#    'land': 'Verenigde Staten',
#    'taal': 'Nederlands',
#    'originele taal': 'Engels',
#    'genre': 'Roman literatuur Roman',
#    'uitgever': 'De Bezige Bij',
#    'uitgiftedatum': '2012',
#    'uitgiftedatum origineel': '1989',
#    'isbn': '978 90 234 3859 5',
#    'film': 'Simon Birch 1998',
#    'poster-op-enwp': ('Image PrayerForOwenMeany JPG', 'Door full_match'),
#    'afbeelding': ('Image PrayerForOwenMeany JPG', 'Door full_match'),
#    'cover-op-enwp': ('Image PrayerForOwenMeany JPG', 'Door full_match'),
#    'titel': ('First edition', 'Door full_match'),
#    'kaftontwerp': ('Honi Werner', 'Door full_match'),
#    'illustraties': ('Honi Werner', 'Door full_match'),
#    'extra portaal': ('Bildungsroman', 'Door full_match'),
#    'uitgeverij': ('William Morrow and Company William Morrow',
#     'Door full_match'),
#    'originele uitgever': ('William Morrow and Company William Morrow',
#     'Door full_match'),
#    'paginas': ('617', 'Door full_match'),
#    'issn': ('0 688 07708 0', 'Door full_match'),
#    'voorafgegaan': ('The Cider House Rules', 'Door full_match'),
#    'vorigeboek': ('The Cider House Rules', 'Door full_match'),
#    'volgendeboek': ('A Son of the Circus', 'Door full_match'),
#    'vervolg': ('A Son of the Circus', 'Door full_match')}},
#  {'old': {'titel': 'A Ring of Endless Light',
#    'regie': 'Greg Beeman',
#    'producer': 'Greg Beeman',
#    'schrijver': 'Marita Giovanni Bruce Graham Madeleine L Engle roman',
#    'spelers': 'Mischa Barton Ryan Merriman',
#    'distributeur': 'Disney Channel',
#    'première': '23 augustus 2002 VS 26 februari 2005 NL',
#    'muziek': 'Phil Marshall als Philip Marshall',
#    'cinematografie': 'Rodney Charters',
#    'genre': 'Drama',
#    'lengte': '88 minuten',
#    'taal': 'Engels',
#    'land': 'US',
#    'imdb': '0282123',
#    'moviemeter': '22452'},
#   'new': {'titel': 'A Ring of Endless Light',
#    'regie': 'Greg Beeman',
#    'producer': 'Greg Beeman',
#    'schrijver': 'Marita Giovanni Bruce Graham Madeleine L Engle roman',
#    'spelers': 'Mischa Barton Ryan Merriman',
#    'distributeur': 'Disney Channel',
#    'première': '23 augustus 2002 VS 26 februari 2005 NL',
#    'muziek': 'Phil Marshall als Philip Marshall',
#    'cinematografie': 'Rodney Charters',
#    'genre': 'Drama',
#    'lengte': '88 minuten',
#    'taal': 'Engels',
#    'land': 'US',
#    'imdb': '0282123',
#    'moviemeter': '22452',
#    'poster-op-enwp': ('Ringendlesslight jpg', 'Door full_match'),
#    'afbeelding': ('Ringendlesslight jpg', 'Door full_match'),
#    'cover-op-enwp': ('Ringendlesslight jpg', 'Door full_match'),
#    'illustraties': ('Madeleine L Engle', 'Door full_match'),
#    'onderschrift': ('Madeleine L Engle', 'Door full_match'),
#    'auteur': ('Madeleine L Engle', 'Door full_match'),
#    'naam': ('Madeleine L Engle', 'Door full_match'),
#    'schrijfster': ('Madeleine L Engle', 'Door full_match'),
#    'kaftontwerp': ('Fred Marcellino hardback', 'Door full_match'),
#    'onderwerp': ('Austin family', 'Door full_match'),
#    'reeks': ('Austin family', 'Door full_match'),
#    'extra portaal': ('Austin family', 'Door full_match'),
#    'film': ('Austin family', 'Door full_match'),
#    'orig titel': ('Austin family', 'Door full_match'),
#    'uitgeverij': ('Farrar Straus Giroux', 'Door full_match'),
#    'originele uitgever': ('Farrar Straus Giroux', 'Door full_match'),
#    'uitgever': ('Farrar Straus Giroux', 'Door full_match'),
#    'uitgiftedatum origineel': ('1980', 'Door full_match'),
#    'uitgiftedatum': ('1980', 'Door full_match'),
#    'medium': ('Print hardback', 'Door full_match'),
#    'paginas': ('324 pp', 'Door full_match'),
#    'isbn': ('0 374 36299 8', 'Door exact_key'),
#    'issn': ('0 374 36299 8', 'Door full_match'),
#    'voorafgegaan': ('The Young Unicorns', 'Door full_match'),
#    'vorigeboek': ('The Young Unicorns', 'Door full_match'),
#    'volgendeboek': ('Troubling a Star', 'Door full_match'),
#    'vervolg': ('Troubling a Star', 'Door full_match')}},
#  {'old': {'titel': 'A Room with a View Kamer met uitzicht',
#    'regie': 'James Ivory regisseur James Ivory',
#    'producer': 'Ismail Merchant',
#    'schrijver': 'Ruth Prawer Jhabvala',
#    'spelers': 'Helena Bonham Carter Julian Sands',
#    'muziek': 'Richard Robbins',
#    'montage': 'Humphrey Dixon',
#    'cinematografie': 'Tony Pierce Roberts',
#    'distributeur': 'Curzon',
#    'première': '13 december 1985',
#    'genre': 'Romantische komedie',
#    'lengte': '117 minuten',
#    'taal': 'Engels',
#    'land': 'GB',
#    'budget': '3 000 000',
#    'opbrengst': '20 966 644',
#    'imdb': '0091867',
#    'moviemeter': '891'},
#   'new': {'titel': 'A Room with a View Kamer met uitzicht',
#    'regie': 'James Ivory regisseur James Ivory',
#    'producer': 'Ismail Merchant',
#    'schrijver': 'Ruth Prawer Jhabvala',
#    'spelers': 'Helena Bonham Carter Julian Sands',
#    'muziek': 'Richard Robbins',
#    'montage': 'Humphrey Dixon',
#    'cinematografie': 'Tony Pierce Roberts',
#    'distributeur': 'Curzon',
#    'première': '13 december 1985',
#    'genre': 'Romantische komedie',
#    'lengte': '117 minuten',
#    'taal': 'Engels',
#    'land': 'GB',
#    'budget': '3 000 000',
#    'opbrengst': '20 966 644',
#    'imdb': '0091867',
#    'moviemeter': '891',
#    'name': ('A Room with a View', 'Door exact_key'),
#    'onderschrift': ('A Room with a View', 'Door full_match'),
#    'naam': ('A Room with a View', 'Door full_match'),
#    'extra portaal': ('A Room with a View', 'Door full_match'),
#    'film': ('A Room with a View', 'Door full_match'),
#    'band_naam': ('A Room with a View', 'Door full_match'),
#    'orig titel': ('A Room with a View', 'Door full_match'),
#    'w-naam': ('A Room with a View', 'Door full_match'),
#    'beter-bekend-als': ('A Room with a View', 'Door full_match'),
#    'titelweergave': ('A Room with a View', 'Door full_match'),
#    'portaal2': ('A Room with a View', 'Door full_match'),
#    'volledige naam': ('A Room with a View', 'Door full_match'),
#    'poster-op-enwp': ('A Room with a View jpg', 'Door full_match'),
#    'afbeelding': ('A Room with a View jpg', 'Door full_match'),
#    'cover-op-enwp': ('A Room with a View jpg', 'Door full_match'),
#    'illustraties': ('E M Forster', 'Door full_match'),
#    'auteur': ('E M Forster', 'Door full_match'),
#    'schrijfster': ('E M Forster', 'Door full_match'),
#    'uitgeverij': ('Edward Arnold publisher Edward Arnold', 'Door full_match'),
#    'originele uitgever': ('Edward Arnold publisher Edward Arnold',
#     'Door full_match'),
#    'uitgever': ('Edward Arnold publisher Edward Arnold', 'Door full_match'),
#    'uitgiftedatum origineel': ('1908', 'Door full_match'),
#    'jaren-actief': ('1908', 'Door full_match'),
#    'uitgiftedatum': ('1908', 'Door full_match'),
#    'medium': ('Print hardcover', 'Door full_match'),
#    'paginas': ('321', 'Door full_match')}},
#  {'old': {'titel': 'A Shock to the System',
#    'première': '1990',
#    'regie': 'Jan Egleson',
#    'spelers': 'Michael Caine Elizabeth McGovern Peter Riegert Swoosie Kurtz',
#    'land': 'US',
#    'duur': '91 minuten',
#    'imdb': '0100602',
#    'moviemeter': '7744',
#    'taal': 'Engels',
#    'lengte': '91 minuten',
#    'tagline': 'Climbing the corporate ladder can be murder',
#    'montage': 'William M Anderson'},
#   'new': {'titel': 'A Shock to the System',
#    'première': '1990',
#    'regie': 'Jan Egleson',
#    'spelers': 'Michael Caine Elizabeth McGovern Peter Riegert Swoosie Kurtz',
#    'land': 'US',
#    'duur': '91 minuten',
#    'imdb': '0100602',
#    'moviemeter': '7744',
#    'taal': 'Engels',
#    'lengte': '91 minuten',
#    'tagline': 'Climbing the corporate ladder can be murder',
#    'montage': 'William M Anderson',
#    'poster-op-enwp': ('A Shock to the System poster jpg', 'Door full_match'),
#    'afbeelding': ('A Shock to the System poster jpg', 'Door full_match'),
#    'cover-op-enwp': ('A Shock to the System poster jpg', 'Door full_match'),
#    'producer': ('Patrick McCormick', 'Door exact_key'),
#    'schrijver': ('Andrew Klavan', 'Door full_match'),
#    'muziek': ('Gary Chang', 'Door full_match'),
#    'tekst': ('Gary Chang', 'Door full_match'),
#    'cinematografie': ('Paul Goldsmith', 'Door full_match'),
#    'editing': ('ubl William M Anderson Peter C Frank', 'Door exact_key'),
#    'prodmaatschappij': ('Corsair Pictures', 'Door full_match'),
#    'distributeur': ('Corsair Pictures', 'Door full_match'),
#    'budget': ('10 million', 'Door exact_key'),
#    'opbrengst': ('3 4 million', 'Door full_match')}},
#  {'old': {'naam': 'Prinses van Mars',
#    'afbeelding': 'Princess of Mars large jpg',
#    'orig titel': 'A Princess of Mars',
#    'auteur': 'Edgar Rice Burroughs',
#    'vertaler': 'Ton Stam',
#    'land': 'US',
#    'taal': 'Nederlands',
#    'originele taal': 'Engels',
#    'reeks': 'Barsoom',
#    'genre': 'Sciencefiction',
#    'uitgever': 'Hoorn West Friesland',
#    'originele uitgever': 'A C McClurg',
#    'uitgiftedatum': '1971',
#    'uitgiftedatum origineel': '1917',
#    'medium': 'Print',
#    'paginas': '160',
#    'isbn': 'ISBN 90 205 0588 2',
#    'film': 'Princess of Mars John Carter film John Carter',
#    'volgendeboek': 'Goden van Mars',
#    'extra portaal': 'Sciencefiction'},
#   'new': {'naam': 'Prinses van Mars',
#    'afbeelding': 'Princess of Mars large jpg',
#    'orig titel': 'A Princess of Mars',
#    'auteur': 'Edgar Rice Burroughs',
#    'vertaler': 'Ton Stam',
#    'land': 'US',
#    'taal': 'Nederlands',
#    'originele taal': 'Engels',
#    'reeks': 'Barsoom',
#    'genre': 'Sciencefiction',
#    'uitgever': 'Hoorn West Friesland',
#    'originele uitgever': 'A C McClurg',
#    'uitgiftedatum': '1971',
#    'uitgiftedatum origineel': '1917',
#    'medium': 'Print',
#    'paginas': '160',
#    'isbn': 'ISBN 90 205 0588 2',
#    'film': 'Princess of Mars John Carter film John Carter',
#    'volgendeboek': 'Goden van Mars',
#    'extra portaal': 'Sciencefiction',
#    'poster-op-enwp': ('File Princess of Mars large jpg', 'Door full_match'),
#    'cover-op-enwp': ('File Princess of Mars large jpg', 'Door full_match'),
#    'titel': ('Cover', 'Door full_match'),
#    'illustrator': ('Frank Schoonover Frank E Schoonover', 'Door exact_key'),
#    'kaftontwerp': ('Frank Schoonover Frank E Schoonover', 'Door full_match'),
#    'illustraties': ('Frank Schoonover Frank E Schoonover', 'Door full_match'),
#    'vervolg': ('The Gods of Mars', 'Door full_match')}},
#  {'old': {'naam': 'Een kleine geschiedenis van bijna alles',
#    'orig titel': 'A short history of nearly everything',
#    'auteur': 'Bill Bryson',
#    'vertaler': 'Servaas Goddijn',
#    'land': 'GB',
#    'taal': 'Nederlands',
#    'originele taal': 'Engels',
#    'onderwerp': 'Natuurwetenschap Geschiedenis',
#    'genre': 'Non fictie',
#    'uitgever': 'NL VLAG Atlas uitgeverij Atlas',
#    'originele uitgever': 'GB VLAG Doubleday US VLAG Broadway Books',
#    'uitgiftedatum': '2004',
#    'uitgiftedatum origineel': '2003',
#    'paginas': '512',
#    'isbn': '978 90 450 0970 4',
#    'isbntoelichting': 'Paperback'},
#   'new': {'naam': 'Een kleine geschiedenis van bijna alles',
#    'orig titel': 'A short history of nearly everything',
#    'auteur': 'Bill Bryson',
#    'vertaler': 'Servaas Goddijn',
#    'land': 'GB',
#    'taal': 'Nederlands',
#    'originele taal': 'Engels',
#    'onderwerp': 'Natuurwetenschap Geschiedenis',
#    'genre': 'Non fictie',
#    'uitgever': 'NL VLAG Atlas uitgeverij Atlas',
#    'originele uitgever': 'GB VLAG Doubleday US VLAG Broadway Books',
#    'uitgiftedatum': '2004',
#    'uitgiftedatum origineel': '2003',
#    'paginas': '512',
#    'isbn': '978 90 450 0970 4',
#    'isbntoelichting': 'Paperback',
#    'name': ('A Short History of Nearly Everything', 'Door exact_key'),
#    'onderschrift': ('A Short History of Nearly Everything', 'Door full_match'),
#    'titel': ('A Short History of Nearly Everything', 'Door full_match'),
#    'extra portaal': ('A Short History of Nearly Everything',
#     'Door full_match'),
#    'film': ('A Short History of Nearly Everything', 'Door full_match'),
#    'band_naam': ('A Short History of Nearly Everything', 'Door full_match'),
#    'w-naam': ('A Short History of Nearly Everything', 'Door full_match'),
#    'beter-bekend-als': ('A Short History of Nearly Everything',
#     'Door full_match'),
#    'titelweergave': ('A Short History of Nearly Everything',
#     'Door full_match'),
#    'portaal2': ('A Short History of Nearly Everything', 'Door full_match'),
#    'volledige naam': ('A Short History of Nearly Everything',
#     'Door full_match'),
#    'poster-op-enwp': ('File Bill bryson a short history jpg',
#     'Door full_match'),
#    'afbeelding': ('File Bill bryson a short history jpg', 'Door full_match'),
#    'cover-op-enwp': ('File Bill bryson a short history jpg',
#     'Door full_match'),
#    'uitgeverij': ('Doubleday publisher Doubleday UK Broadway Books US',
#     'Door full_match'),
#    'medium': ('Print Hardcover Paperback E Book', 'Door full_match'),
#    'issn': ('0 7679 0817 1', 'Door full_match')}},
#  {'old': {'titel': 'A Scanner Darkly',
#    'tagline': 'Everything Is Not Going To Be OK What Does A Scanner See',
#    'regie': 'Richard Linklater',
#    'producer': 'Tommy Pallotta Anne Walker McBay Palmer West Jonah Smith Erwin Stoff',
#    'schrijver': 'Richard Linklater',
#    'spelers': 'Keanu Reeves Robert Downey Jr Woody Harrelson Winona Ryder',
#    'muziek': 'Graham Reynolds',
#    'montage': 'Sandra Adair',
#    'cinematografie': 'Shane F Kelly',
#    'distributeur': 'Warner Home Video',
#    'première': '7 juli 2006',
#    'genre': 'Sciencefictionfilm Animatiefilm',
#    'lengte': '100 minuten',
#    'taal': 'Engels',
#    'land': 'US',
#    'budget': '8 7 miljoen dollar',
#    'imdb': '0405296',
#    'moviemeter': '28490'},
#   'new': {'titel': 'A Scanner Darkly',
#    'tagline': 'Everything Is Not Going To Be OK What Does A Scanner See',
#    'regie': 'Richard Linklater',
#    'producer': 'Tommy Pallotta Anne Walker McBay Palmer West Jonah Smith Erwin Stoff',
#    'schrijver': 'Richard Linklater',
#    'spelers': 'Keanu Reeves Robert Downey Jr Woody Harrelson Winona Ryder',
#    'muziek': 'Graham Reynolds',
#    'montage': 'Sandra Adair',
#    'cinematografie': 'Shane F Kelly',
#    'distributeur': 'Warner Home Video',
#    'première': '7 juli 2006',
#    'genre': 'Sciencefictionfilm Animatiefilm',
#    'lengte': '100 minuten',
#    'taal': 'Engels',
#    'land': 'US',
#    'budget': '8 7 miljoen dollar',
#    'imdb': '0405296',
#    'moviemeter': '28490',
#    'poster-op-enwp': ('AScannerDarkly 1stEd jpg', 'Door full_match'),
#    'afbeelding': ('AScannerDarkly 1stEd jpg', 'Door full_match'),
#    'cover-op-enwp': ('AScannerDarkly 1stEd jpg', 'Door full_match'),
#    'illustraties': ('Philip K Dick', 'Door full_match'),
#    'onderschrift': ('Philip K Dick', 'Door full_match'),
#    'auteur': ('Philip K Dick', 'Door full_match'),
#    'naam': ('Philip K Dick', 'Door full_match'),
#    'schrijfster': ('Philip K Dick', 'Door full_match'),
#    'extra portaal': ('Science fiction paranoid fiction philosophical literature',
#     'Door full_match'),
#    'uitgeverij': ('Doubleday publisher Doubleday', 'Door full_match'),
#    'originele uitgever': ('Doubleday publisher Doubleday', 'Door full_match'),
#    'uitgever': ('Doubleday publisher Doubleday', 'Door full_match'),
#    'uitgiftedatum origineel': ('1977', 'Door full_match'),
#    'uitgiftedatum': ('1977', 'Door full_match'),
# ...
#    'schrijver': ('Robert Jordan', 'Door full_match'),
#    'schrijfster': ('Robert Jordan', 'Door full_match'),
#    'land': ('United States', 'Door full_match'),
#    'onderwerp': ('The Wheel of Time', 'Door full_match'),
#    'extra portaal': ('The Wheel of Time', 'Door full_match'),
#    'film': ('The Wheel of Time', 'Door full_match'),
#    'uitgeverij': ('Tor Books U S Orbit UK', 'Door full_match'),
#    'medium': ('Print Hardcover Hardback Paperback', 'Door full_match'),
#    'issn': ('0 312 86425 6', 'Door full_match'),
#    'vorigeboek': ('The Path of Daggers', 'Door full_match'),
#    'volgendeboek': ('Crossroads of Twilight', 'Door full_match')}},
#  {'old': {'titel': 'Wise Blood',
#    'regie': 'John Huston regisseur John Huston',
#    'producer': 'Kathy Fitzgerald Michael Fitzgerald filmproducent Michael Fitzgerald',
#    'schrijver': 'Benedict Fitzgerald Flannery O Connor roman',
#    'spelers': 'Brad Dourif John Huston regisseur John Huston Dan Shor',
#    'muziek': 'Alex North',
#    'montage': 'Roberto Silvi',
#    'cinematografie': 'Gerry Fisher',
#    'distributeur': 'New Line Cinema',
#    'première': '24 oktober 1979',
#    'genre': 'Drama',
#    'lengte': '108 minuten',
#    'taal': 'Engels',
#    'land': 'US DE 1949 WD',
#    'budget': '1 000 000',
#    'imdb': '0080140',
#    'moviemeter': '3313'},
#   'new': {'titel': 'Wise Blood',
#    'regie': 'John Huston regisseur John Huston',
#    'producer': 'Kathy Fitzgerald Michael Fitzgerald filmproducent Michael Fitzgerald',
#    'schrijver': 'Benedict Fitzgerald Flannery O Connor roman',
#    'spelers': 'Brad Dourif John Huston regisseur John Huston Dan Shor',
#    'muziek': 'Alex North',
#    'montage': 'Roberto Silvi',
#    'cinematografie': 'Gerry Fisher',
#    'distributeur': 'New Line Cinema',
#    'première': '24 oktober 1979',
#    'genre': 'Drama',
#    'lengte': '108 minuten',
#    'taal': 'Engels',
#    'land': 'US DE 1949 WD',
#    'budget': '1 000 000',
#    'imdb': '0080140',
#    'moviemeter': '3313',
#    'poster-op-enwp': ('Wise Blood novel 1st edition cover jpg',
#     'Door full_match'),
#    'afbeelding': ('Wise Blood novel 1st edition cover jpg', 'Door full_match'),
#    'cover-op-enwp': ('Wise Blood novel 1st edition cover jpg',
#     'Door full_match'),
#    'illustraties': ('Flannery O Connor', 'Door full_match'),
#    'onderschrift': ('Flannery O Connor', 'Door full_match'),
#    'auteur': ('Flannery O Connor', 'Door full_match'),
#    'naam': ('Flannery O Connor', 'Door full_match'),
#    'schrijfster': ('Flannery O Connor', 'Door full_match'),
#    'extra portaal': ('Southern Gothic novel', 'Door full_match'),
#    'uitgeverij': ('Harcourt Trade Publishers Harcourt Brace Company',
#     'Door full_match'),
#    'originele uitgever': ('Harcourt Trade Publishers Harcourt Brace Company',
#     'Door full_match'),
#    'uitgever': ('Harcourt Trade Publishers Harcourt Brace Company',
#     'Door full_match'),
#    'uitgiftedatum origineel': ('May 15 1952', 'Door full_match'),
#    'uitgiftedatum': ('May 15 1952', 'Door full_match'),
#    'medium': ('Print hardback paperback', 'Door full_match'),
#    'paginas': ('238', 'Door full_match')}},
#  {'old': {'naam': 'Het zwaard van de waarheid',
#    'reeks': 'De wetten van de magie',
#    'auteur': 'Terry Goodkind',
#    'vertaler': 'Max Schuchart',
#    'uitgever': 'Luitingh Sijthoff',
#    'orig titel': 'Wizard s First Rule',
#    'uitgiftedatum': '1996 Origineel 1995',
#    'genre': 'Fantasy genre Fantasy',
#    'paginas': '784 blz',
#    'isbn': '9024523427',
#    'voorafgegaan': 'De aflossing',
#    'vervolg': 'Steen der tranen'},
#   'new': {'naam': 'Het zwaard van de waarheid',
#    'reeks': 'De wetten van de magie',
#    'auteur': 'Terry Goodkind',
#    'vertaler': 'Max Schuchart',
#    'uitgever': 'Luitingh Sijthoff',
#    'orig titel': 'Wizard s First Rule',
#    'uitgiftedatum': '1996 Origineel 1995',
#    'genre': 'Fantasy genre Fantasy',
#    'paginas': '784 blz',
#    'isbn': '9024523427',
#    'voorafgegaan': 'De aflossing',
#    'vervolg': 'Steen der tranen',
#    'poster-op-enwp': ('Wizard s First Rule jpg', 'Door full_match'),
#    'afbeelding': ('Wizard s First Rule jpg', 'Door full_match'),
#    'cover-op-enwp': ('Wizard s First Rule jpg', 'Door full_match'),
#    'kaftontwerp': ('Doug Beekman', 'Door full_match'),
#    'illustraties': ('Doug Beekman', 'Door full_match'),
#    'land': ('United States', 'Door full_match'),
#    'onderwerp': ('The Sword of Truth', 'Door full_match'),
#    'extra portaal': ('The Sword of Truth', 'Door full_match'),
#    'film': ('The Sword of Truth', 'Door full_match'),
#    'uitgeverij': ('Tor Books Tor Fantasy', 'Door full_match'),
#    'originele uitgever': ('Tor Books Tor Fantasy', 'Door full_match'),
#    'uitgiftedatum origineel': ('August 1994', 'Door full_match'),
#    'medium': ('Print Hardback', 'Door full_match'),
#    'issn': ('0 312 85705 5', 'Door full_match'),
#    'vorigeboek': ('Debt of Bones', 'Door full_match'),
#    'volgendeboek': ('Stone of Tears', 'Door full_match')}},
#  {'old': {'naam': 'De plaagzusters',
#    'reeks': 'Schijfwereld',
#    'auteur': 'Terry Pratchett',
#    'vertaler': 'Venugopalan Ittekot',
#    'uitgever': 'Het Spectrum',
#    'orig titel': 'Wyrd Sisters',
#    'uitgiftedatum': '1988 1993',
#    'genre': 'Fantasy genre Fantasy',
#    'paginas': '233 blz',
#    'isbn': '9027431639',
#    'voorafgegaan': 'Betoverkind',
#    'vervolg': 'Pyramides'},
#   'new': {'naam': 'De plaagzusters',
#    'reeks': 'Schijfwereld',
#    'auteur': 'Terry Pratchett',
#    'vertaler': 'Venugopalan Ittekot',
#    'uitgever': 'Het Spectrum',
#    'orig titel': 'Wyrd Sisters',
#    'uitgiftedatum': '1988 1993',
#    'genre': 'Fantasy genre Fantasy',
#    'paginas': '233 blz',
#    'isbn': '9027431639',
#    'voorafgegaan': 'Betoverkind',
#    'vervolg': 'Pyramides',
#    'poster-op-enwp': ('Wyrd sisters cover jpg', 'Door full_match'),
#    'afbeelding': ('Wyrd sisters cover jpg', 'Door full_match'),
#    'cover-op-enwp': ('Wyrd sisters cover jpg', 'Door full_match'),
#    'titel': ('First edition', 'Door full_match'),
#    'kaftontwerp': ('Josh Kirby', 'Door full_match'),
#    'illustraties': ('Josh Kirby', 'Door full_match'),
#    'onderwerp': ('Discworld 6th novel 2nd Witches story', 'Door full_match'),
#    'extra portaal': ('Discworld 6th novel 2nd Witches story',
#     'Door full_match'),
#    'film': ('Discworld 6th novel 2nd Witches story', 'Door full_match'),
#    'uitgiftedatum origineel': ('start date 1988 11 10 df y Victor Gollancz',
#     'Door full_match'),
#    'awards': ('Came 135th in the Big Read', 'Door exact_key'),
#    'issn': ('0 575 04363 6', 'Door full_match')}},
#  {'old': {'titel': 'World War Z',
#    'poster-op-enwp': 'World War Z poster jpg',
#    'tagline': 'Remember Philly',
#    'regie': 'Marc Forster',
#    'producer': 'Ian Bryce Dede Gardner Jeremy Kleiner Brad Pitt',
#    'prodmaatschappij': 'Paramount Pictures Skydance Media',
#    'schrijver': 'Boek Max Brooks Scenario Matthew Michael Carnahan J Michael Straczynski Draaiboek Matthew Michael Carnahan Drew Goddard Damon Lindelof',
#    'spelers': 'Brad Pitt',
#    'muziek': 'Marco Beltrami',
#    'cinematografie': 'Ben Seresin',
#    'distributeur': 'Paramount Pictures United International Pictures',
#    'première': 'UK VLAG 2 juni 2013 wereldpremière BE VLAG 3 juli 2013 NL VLAG 4 juli 2013',
#    'genre': 'Horrorfilm Horror Actiefilm actie',
#    'lengte': '116 min',
#    'taal': 'Engels Spaans Hebreeuws',
#    'land': 'US',
#    'budget': 'Amerikaanse dollar US 190 miljoen',
#    'opbrengst': 'US 540 miljoen',
#    'nominaties': '18',
#    'prijzen': '4',
#    'imdb': '0816711',
#    'moviemeter': '90206'},
#   'new': {'titel': 'World War Z',
#    'poster-op-enwp': 'World War Z poster jpg',
#    'tagline': 'Remember Philly',
#    'regie': 'Marc Forster',
#    'producer': 'Ian Bryce Dede Gardner Jeremy Kleiner Brad Pitt',
#    'prodmaatschappij': 'Paramount Pictures Skydance Media',
#    'schrijver': 'Boek Max Brooks Scenario Matthew Michael Carnahan J Michael Straczynski Draaiboek Matthew Michael Carnahan Drew Goddard Damon Lindelof',
#    'spelers': 'Brad Pitt',
#    'muziek': 'Marco Beltrami',
#    'cinematografie': 'Ben Seresin',
#    'distributeur': 'Paramount Pictures United International Pictures',
#    'première': 'UK VLAG 2 juni 2013 wereldpremière BE VLAG 3 juli 2013 NL VLAG 4 juli 2013',
#    'genre': 'Horrorfilm Horror Actiefilm actie',
#    'lengte': '116 min',
#    'taal': 'Engels Spaans Hebreeuws',
#    'land': 'US',
#    'budget': 'Amerikaanse dollar US 190 miljoen',
#    'opbrengst': 'US 540 miljoen',
#    'nominaties': '18',
#    'prijzen': '4',
#    'imdb': '0816711',
#    'moviemeter': '90206',
#    'afbeelding': ('World War Z book cover jpg', 'Door full_match'),
#    'cover-op-enwp': ('World War Z book cover jpg', 'Door full_match'),
#    'illustraties': ('Max Brooks', 'Door full_match'),
#    'onderschrift': ('Max Brooks', 'Door full_match'),
#    'auteur': ('Max Brooks', 'Door full_match'),
#    'naam': ('Max Brooks', 'Door full_match'),
#    'schrijfster': ('Max Brooks', 'Door full_match'),
#    'onderwerp': ('2', 'Door full_match'),
#    'reeks': ('2', 'Door full_match'),
#    'extra portaal': ('2', 'Door full_match'),
#    'film': ('2', 'Door full_match'),
#    'orig titel': ('2', 'Door full_match'),
#    'uitgiftedatum origineel': ('September 12 2006', 'Door full_match'),
#    'uitgiftedatum': ('September 12 2006', 'Door full_match'),
#    'uitgeverij': ('Crown Publishing Group Crown', 'Door full_match'),
#    'originele uitgever': ('Crown Publishing Group Crown', 'Door full_match'),
#    'uitgever': ('Crown Publishing Group Crown', 'Door full_match'),
#    'medium': ('Print hardback and paperback e book audiobook',
#     'Door full_match'),
#    'paginas': ('342', 'Door full_match'),
#    'isbn': ('0 307 34660 9', 'Door exact_key'),
#    'issn': ('0 307 34660 9', 'Door full_match'),
#    'voorafgegaan': ('The Zombie Survival Guide', 'Door full_match'),
#    'vorigeboek': ('The Zombie Survival Guide', 'Door full_match')}},
#  {'old': {'titel': 'Your Name',
#    'afbeelding': 'Your name movie logo svg',
#    'beschrijving': 'Titel van Your Name',
#    'ja_naam': '君の名は',
#    'ja_naam_trans': 'Kimi no Na wa',
#    'genre': 'Drama genre Drama Fantasy genre Fantasy'},
#   'new': {'titel': 'Your Name',
#    'afbeelding': 'Your name movie logo svg',
#    'beschrijving': 'Titel van Your Name',
#    'ja_naam': '君の名は',
#    'ja_naam_trans': 'Kimi no Na wa',
#    'genre': 'Drama genre Drama Fantasy genre Fantasy',
#    'illustraties': ('Makoto Shinkai', 'Door full_match'),
#    'onderschrift': ('Makoto Shinkai', 'Door full_match'),
#    'auteur': ('Makoto Shinkai', 'Door full_match'),
#    'naam': ('Makoto Shinkai', 'Door full_match'),
#    'schrijver': ('Makoto Shinkai', 'Door full_match'),
#    'schrijfster': ('Makoto Shinkai', 'Door full_match'),
#    'land': ('Japan', 'Door full_match'),
#    'uitgeverij': ('Kadokawa Corporation Kadokawa', 'Door full_match'),
#    'originele uitgever': ('Kadokawa Corporation Kadokawa', 'Door full_match'),
#    'uitgever': ('Kadokawa Corporation Kadokawa', 'Door full_match'),
#    'poster-op-enwp': ('File Your Name novel cover jpg', 'Door full_match'),
#    'cover-op-enwp': ('File Your Name novel cover jpg', 'Door full_match'),
#    'orig titel': ('noitalic nihongo2 君の名は Kimi no Na wa nihongo2 君の名は',
#     'Door full_match'),
#    'uitgiftedatum origineel': ('June 18 2016', 'Door full_match'),
#    'jaren-actief': ('June 18 2016', 'Door full_match'),
#    'uitgiftedatum': ('June 18 2016', 'Door full_match'),
#    'english_pub_date': ('May 23 2017', 'Door exact_key'),
#    'paginas': ('262', 'Door full_match')}},
#  {'old': {'naam': 'Woeste hoogten',
#    'orig titel': 'Wuthering Heights',
#    'afbeelding': 'Houghton Lowell 1238 5 A Wuthering Heights 1847 jpg',
#    'onderschrift': 'Titelpagina',
#    'auteur': 'Emily Brontë',
#    'land': 'Verenigd Koninkrijk',
#    'taal': 'Engels',
#    'genre': 'Roman literatuur Roman gothic novel',
#    'uitgever': 'Thomas Cautley Newby',
#    'uitgiftedatum': '1847',
#    'paginas': '416',
#    'isbn': '0141023546'},
#   'new': {'naam': 'Woeste hoogten',
#    'orig titel': 'Wuthering Heights',
#    'afbeelding': 'Houghton Lowell 1238 5 A Wuthering Heights 1847 jpg',
#    'onderschrift': 'Titelpagina',
#    'auteur': 'Emily Brontë',
#    'land': 'Verenigd Koninkrijk',
#    'taal': 'Engels',
#    'genre': 'Roman literatuur Roman gothic novel',
#    'uitgever': 'Thomas Cautley Newby',
#    'uitgiftedatum': '1847',
#    'paginas': '416',
#    'isbn': '0141023546',
#    'titel': ('Title page of the first edition', 'Door full_match'),
#    'extra portaal': ('Tragedy Gothic fiction gothic', 'Door full_match'),
#    'uitgiftedatum origineel': ('December 1847', 'Door full_match'),
#    'issn': ('0 486 29256 8', 'Door full_match')}},
#  {'old': {'naam': 'You Only Live Twice Je Leeft Maar Twee Maal',
#    'cover-op-enwp': 'You_Only_Live_Twice Ian_Fleming jpg',
#    'auteur': 'Ian Fleming',
#    'vertaler': 'O Falk',
#    'kaftontwerp': 'Richard Chopping',
#    'land': 'Verenigd Koninkrijk Groot Brittannië',
#    'taal': 'Engels',
#    'reeks': 'James Bond mediafranchise James Bond',
#    'paginas': '224',
#    'genre': 'Spionage',
#    'uitgever': 'Glidrose Productions',
#    'originele uitgever': 'Jonathan Cape',
#    'uitgiftedatum': '16 maart 1964',
#    'voorafgegaan': 'On Her Majesty s Secret Service roman On Her Majesty s Secret Service',
#    'vervolg': 'The Man with the Golden Gun roman The Man With The Golden Gun',
#    'film': 'You Only Live Twice film You Only Live Twice'},
#   'new': {'naam': 'You Only Live Twice Je Leeft Maar Twee Maal',
#    'cover-op-enwp': 'You_Only_Live_Twice Ian_Fleming jpg',
#    'auteur': 'Ian Fleming',
#    'vertaler': 'O Falk',
#    'kaftontwerp': 'Richard Chopping',
#    'land': 'Verenigd Koninkrijk Groot Brittannië',
#    'taal': 'Engels',
#    'reeks': 'James Bond mediafranchise James Bond',
#    'paginas': '224',
#    'genre': 'Spionage',
#    'uitgever': 'Glidrose Productions',
#    'originele uitgever': 'Jonathan Cape',
#    'uitgiftedatum': '16 maart 1964',
#    'voorafgegaan': 'On Her Majesty s Secret Service roman On Her Majesty s Secret Service',
#    'vervolg': 'The Man with the Golden Gun roman The Man With The Golden Gun',
#    'film': 'You Only Live Twice film You Only Live Twice',
#    'name': ('You Only Live Twice', 'Door exact_key'),
#    'onderschrift': ('You Only Live Twice', 'Door full_match'),
#    'titel': ('You Only Live Twice', 'Door full_match'),
#    'extra portaal': ('You Only Live Twice', 'Door full_match'),
#    'band_naam': ('You Only Live Twice', 'Door full_match'),
#    'orig titel': ('You Only Live Twice', 'Door full_match'),
#    'w-naam': ('You Only Live Twice', 'Door full_match'),
#    'beter-bekend-als': ('You Only Live Twice', 'Door full_match'),
#    'titelweergave': ('You Only Live Twice', 'Door full_match'),
#    'portaal2': ('You Only Live Twice', 'Door full_match'),
#    'volledige naam': ('You Only Live Twice', 'Door full_match'),
#    'poster-op-enwp': ('You Only Live Twice Ian Fleming jpg',
#     'Door full_match'),
#    'afbeelding': ('You Only Live Twice Ian Fleming jpg', 'Door full_match'),
#    'onderwerp': ('James Bond', 'Door full_match'),
#    'uitgiftedatum origineel': ('26 March 1964 Jonathan Cape',
#     'Door full_match'),
#    'medium': ('Print hardback paperback', 'Door full_match'),
#    'vorigeboek': ('On Her Majesty s Secret Service novel On Her Majesty s Secret Service',
#     'Door full_match'),
#    'volgendeboek': ('The Man with the Golden Gun novel The Man with the Golden Gun',
#     'Door full_match')}},
#  {'old': {'titel': 'Zero no Tsukaima',
#    'afbeelding': 'Zero no Tsukaima logo png',
#    'beschrijving': 'Japans Logo',
#    'ja_naam': 'ゼロの使い魔',
#    'ja_naam_trans': 'Zero no Tsukaima',
#    'doelgroep': 'Seinen manga Seinen',
#    'genre': 'Avonturenroman Avontuur Fantasy genre Fantasie Romantische komedie'},
#   'new': {'titel': 'Zero no Tsukaima',
#    'afbeelding': 'Zero no Tsukaima logo png',
#    'beschrijving': 'Japans Logo',
#    'ja_naam': 'ゼロの使い魔',
#    'ja_naam_trans': 'Zero no Tsukaima',
#    'doelgroep': 'Seinen manga Seinen',
#    'genre': 'Avonturenroman Avontuur Fantasy genre Fantasie Romantische komedie',
#    'poster-op-enwp': ('ZnT novel01 png', 'Door full_match'),
#    'cover-op-enwp': ('ZnT novel01 png', 'Door full_match'),
#    'extra portaal': ('Fantasy comedy Harem genre harem', 'Door full_match')}}]

# %%
for d in expanded_boxes:
# Out:
# {'old': {'titel': 'A Scanner Darkly',
#   'tagline': 'Everything Is Not Going To Be OK What Does A Scanner See',
#   'regie': 'Richard Linklater',
#   'producer': 'Tommy Pallotta Anne Walker McBay Palmer West Jonah Smith Erwin Stoff',
#   'schrijver': 'Richard Linklater',
#   'spelers': 'Keanu Reeves Robert Downey Jr Woody Harrelson Winona Ryder',
#   'muziek': 'Graham Reynolds',
#   'montage': 'Sandra Adair',
#   'cinematografie': 'Shane F Kelly',
#   'distributeur': 'Warner Home Video',
#   'première': '7 juli 2006',
#   'genre': 'Sciencefictionfilm Animatiefilm',
#   'lengte': '100 minuten',
#   'taal': 'Engels',
#   'land': 'US',
#   'budget': '8 7 miljoen dollar',
#   'imdb': '0405296',
#   'moviemeter': '28490'},
#  'new': {'titel': 'A Scanner Darkly',
#   'tagline': 'Everything Is Not Going To Be OK What Does A Scanner See',
#   'regie': 'Richard Linklater',
#   'producer': 'Tommy Pallotta Anne Walker McBay Palmer West Jonah Smith Erwin Stoff',
#   'schrijver': 'Richard Linklater',
#   'spelers': 'Keanu Reeves Robert Downey Jr Woody Harrelson Winona Ryder',
#   'muziek': 'Graham Reynolds',
#   'montage': 'Sandra Adair',
#   'cinematografie': 'Shane F Kelly',
#   'distributeur': 'Warner Home Video',
#   'première': '7 juli 2006',
#   'genre': 'Sciencefictionfilm Animatiefilm',
#   'lengte': '100 minuten',
#   'taal': 'Engels',
#   'land': 'US',
#   'budget': '8 7 miljoen dollar',
#   'imdb': '0405296',
#   'moviemeter': '28490',
#   'isbn': '0 385 01613 1',
#   'name': 'A Scanner Darkly'}}

# %%
# total = []
# with open('data/titlesAE.txt') as f:
#     total.extend(f.readlines())

# with open('data/titlesFZ.txt') as f:
#     total.extend(f.readlines())

# with open('data/sf_fantasy_light_mostpop.txt') as f:
#     total.extend(f.readlines())

# total = sorted(list(set(total)))

# with open('titles.txt', 'w') as f:
#     f.write(''.join(total))

# # Handmatig checken op:
# #   - wikipediadump xml blabla
# #   - Dingen die bovenaan staan (punct marks etc.)
# #   - &amp; vervangen
